# %% [markdown]
# ## Learning objectives
# - Learn how to use `WrapCalibratedExplainer` to wrap a model and produce calibrated predictions;
# - Generate factual and alternative explanations and plot uncertainty;
# - Understand when OOB vs explicit calibration is appropriate.
#
# ## Time to run
# ~2–10 min depending on dataset and environment (use smaller datasets for a faster run).

# %% [markdown]
# # Getting started with calibrated-explanations - using the WrapCalibratedExplainer class
# Author: Tuwe Löfström (tuwe.lofstrom@ju.se)
# Copyright 2023 Tuwe Löfström
# License: BSD 3 clause
# ## Classification
# Let us illustrate how we may use `calibrated_explanations` to generate explanations from a classifier trained on a dataset from
# [www.openml.org](https://www.openml.org), which we first split into a
# training and a test set using `train_test_split` from
# [sklearn](https://scikit-learn.org), and then further split the
# training set into a proper training set and a calibration set:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

dataset = fetch_openml(name="wine", version=7, as_frame=True, parser="auto")

X = dataset.data.values.astype(float)
y = (dataset.target.values == "True").astype(int)

feature_names = dataset.feature_names

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=2, stratify=y)

X_prop_train, x_cal, y_prop_train, y_cal = train_test_split(x_train, y_train, test_size=0.25)

# %% [markdown]
# We now create our wrapper object, using a `RandomForestClassifier` as learner.

# %%
from sklearn.ensemble import RandomForestClassifier

from calibrated_explanations import WrapCalibratedExplainer, __version__

print(f"calibrated_explanations {__version__}")

classifier = WrapCalibratedExplainer(RandomForestClassifier())
display(classifier)
# Out:
# calibrated_explanations 1.0.0rc1
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=False, calibrated=False)

# %% [markdown]
# We now fit our model using the proper training set.

# %%
classifier.fit(X_prop_train, y_prop_train)
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=False)

# %% [markdown]
# The `WrapCalibratedExplainer` class has a `predict` and a `predict_proba` method that returns the predictions and probability estimates of the underlying classifier. If the model is not yet calibrated, then the underlying models `predict` and `predict_proba` methods are used. If the model is calibrated, then the `predict` and `predict_proba` method of the calibration model is used.

# %%
prediction = classifier.predict(x_test)
proba = classifier.predict_proba(x_test)
print("Uncalibrated prediction (probability estimates):")
print(f"{prediction} ({proba})")
# Out:
# Uncalibrated prediction (probability estimates):
# [1 1] ([[0.48 0.52]
#  [0.29 0.71]])
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_15536\1092592062.py:1: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated predictions.
#   prediction = classifier.predict(x_test)
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_15536\1092592062.py:2: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated probabilities.
#   proba = classifier.predict_proba(x_test)

# %% [markdown]
# Before we can generate explanations, we need to calibrate our model using the calibration set.

# %%
classifier.calibrate(x_cal, y_cal, feature_names=feature_names)
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, learner=RandomForestClassifier()))

# %% [markdown]
# Once the model is calibrated, the `predict` and `predict_proba` methods produce calibrated predictions and probability estimates.

# %%
prediction = classifier.predict(x_test)
proba, (low, high) = classifier.predict_proba(x_test, uq_interval=True)
print("Calibrated prediction (probability estimates):")
print(f"{prediction} ({proba})")
print("Calibrated uncertainty interval for the positive class:")
print([(low[i], high[i]) for i in range(len(low))])
# Out:
# Calibrated prediction (probability estimates):
# [1 1] ([[0.45454545 0.54545455]
#  [0.35714286 0.64285714]])
# Calibrated uncertainty interval for the positive class:
# [(np.float64(0.5), np.float64(0.6)), (np.float64(0.6341463414634146), np.float64(0.6585365853658537))]

# %% [markdown]
# #### Factual Explanations
# Let us explain a test instance using our `WrapCalibratedExplainer` object. The method used to get factual explanations is `explain_factual` with `guarded_options=GuardedOptions()`.

# %%
from calibrated_explanations import GuardedOptions

factual_explanations = classifier.explain_factual(x_test, guarded_options=GuardedOptions())
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %%
from calibrated_explanations.ce_agent_utils import print_guarded_audit_table

guarded_audit = factual_explanations.get_guarded_audit()
print_guarded_audit_table(guarded_audit, max_rows=20)
display(classifier)
# Out:
# Guarded Audit Summary
# instances=2 tested=160 conforming=138 removed_guard=22 emitted=21
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 fixed acidity      (-inf, 4.95]             0.5455  Y    N    N   design_excluded
#    0    0 fixed acidity      (4.95, 5.85]             0.8135  Y    N    N   design_excluded
#    0    0 fixed acidity      (5.85, 7.25]             0.8824  Y    Y    N   emitted
#    0    0 fixed acidity      (7.25, 7.45]             0.7947  Y    N    N   design_excluded
#    0    0 fixed acidity      (7.45, 9.5]              0.5204  Y    N    N   design_excluded
#    0    0 fixed acidity      (9.5, 9.85]              0.1614  Y    N    N   design_excluded
#    0    0 fixed acidity      (9.85, 9.95]              0.127  Y    N    N   design_excluded
#    0    0 fixed acidity      (9.95, inf]              0.0392  N    N    N   removed_guard
#    0    1 volatile acidity   (-inf, 0.135]            0.7837  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.135, 0.2225]          0.8464  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.2225, 0.2575]         0.8683  Y    Y    N   emitted
#    0    1 volatile acidity   (0.2575, 0.545]          0.8464  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.545, 0.8325]          0.2194  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.8325, 0.8375]         0.0266  N    N    N   removed_guard
#    0    1 volatile acidity   (0.8375, inf]            0.0157  N    N    N   removed_guard
#    0    2 citric acid        (-inf, 0.165]            0.3448  Y    N    N   design_excluded
#    0    2 citric acid        (0.165, 0.215]           0.8103  Y    N    N   design_excluded
#    0    2 citric acid        (0.215, 0.245]           0.8464  Y    N    N   design_excluded
#    0    2 citric acid        (0.245, 0.265]           0.8683  Y    N    N   design_excluded
#    0    2 citric acid        (0.265, 0.325]           0.8746  Y    Y    N   emitted
# ... truncated 140 row(s)
# reason_counts: emitted=21, removed_guard=22, design_excluded=116, zero_impact=1
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %% [markdown]
# #### Merge adjacent conforming bins
# Passing `merge_adjacent=True` collapses adjacent conforming bins into wider rules (re-tested by the guard).  Rows with `mrg=Y` in the audit table came from a merge; the displayed interval shows the emitted bounds.

# %%
merged_factual_cls = classifier.explain_factual(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
merged_audit_cls = merged_factual_cls.get_guarded_audit()
print_guarded_audit_table(merged_audit_cls, max_rows=30)
# Out:
# Guarded Audit Summary
# instances=2 tested=44 conforming=22 removed_guard=22 emitted=17
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 fixed acidity      (-inf, 9.95]             0.8699  Y    Y    Y   emitted
#    0    0 fixed acidity      (9.95, inf]              0.0392  N    N    N   removed_guard
#    0    1 volatile acidity   (-inf, 0.8325]           0.8589  Y    Y    Y   emitted
#    0    1 volatile acidity   (0.8325, 0.8375]         0.0266  N    N    N   removed_guard
#    0    1 volatile acidity   (0.8375, inf]            0.0157  N    N    N   removed_guard
#    0    2 citric acid        (-inf, inf]              0.8668  Y    Y    Y   emitted
#    0    3 residual sugar     (-inf, 13.65]            0.8683  Y    Y    Y   emitted
#    0    3 residual sugar     (13.65, 15.55]           0.0925  N    N    N   removed_guard
#    0    3 residual sugar     (15.55, 17.525]          0.0439  N    N    N   removed_guard
#    0    3 residual sugar     (17.525, inf]            0.0219  N    N    N   removed_guard
#    0    4 chlorides          (-inf, inf]              0.8683  Y    Y    Y   emitted
#    0    5 free sulfur dioxid (-inf, inf]              0.9013  Y    Y    Y   emitted
#    0    6 total sulfur dioxi (-inf, 229.5]            0.8966  Y    Y    Y   emitted
#    0    6 total sulfur dioxi (229.5, inf]              0.069  N    N    N   removed_guard
#    0    7 density            (-inf, 0.9958]           0.8307  Y    Y    Y   emitted
#    0    7 density            (0.9958, inf]            0.0533  N    N    N   removed_guard
#    0    8 pH                 (-inf, 3.73]              0.884  Y    Y    Y   emitted
#    0    8 pH                 (3.73, inf]              0.0549  N    N    N   removed_guard
#    0    9 sulphates          (-inf, inf]              0.9044  Y    Y    Y   emitted
#    0   10 alcohol            (-inf, inf]              0.8135  Y    Y    Y   emitted
#    1    0 fixed acidity      (-inf, 9.85]             0.7367  Y    N    Y   zero_impact
#    1    0 fixed acidity      (9.85, 9.95]             0.0878  N    N    N   removed_guard
#    1    0 fixed acidity      (9.95, inf]              0.0188  N    N    N   removed_guard
#    1    1 volatile acidity   (-inf, 0.8325]           0.7147  Y    Y    Y   emitted
#    1    1 volatile acidity   (0.8325, 0.8375]         0.0251  N    N    N   removed_guard
#    1    1 volatile acidity   (0.8375, inf]            0.0125  N    N    N   removed_guard
#    1    2 citric acid        (-inf, inf]              0.6599  Y    Y    Y   emitted
#    1    3 residual sugar     (-inf, 13.65]            0.8824  Y    N    Y   zero_impact
#    1    3 residual sugar     (13.65, 15.55]           0.0925  N    N    N   removed_guard
#    1    3 residual sugar     (15.55, 17.525]          0.0502  N    N    N   removed_guard
# ... truncated 14 row(s)
# reason_counts: emitted=17, removed_guard=22, zero_impact=5
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown

# %% [markdown]
# Once we have the explanations, we can plot all of them using `plot`. Default, a regular plot, without uncertainty intervals included, is created. To include uncertainty intervals, change the parameter `uncertainty=True`.

# %%
factual_explanations.plot()
factual_explanations.plot(uncertainty=True)

# %% [markdown]
# You can also add and remove conjunctive rules.

# %%
factual_explanations.add_conjunctions().plot()
factual_explanations.remove_conjunctions().plot(uncertainty=True)

# %% [markdown]
# All explanations support indexing using integer indexing, slices or boolean indexing.

# %%
factual_explanations[0].plot(uncertainty=True)
factual_explanations[:1].plot(uncertainty=True)

# %% [markdown]
# #### Explore Alternative Explanations
# An alternative to factual rules is to extract alternative rules, which is done using `explore_alternatives` with `guarded_options=GuardedOptions()`. Alternative explanations provides insights on how predicted outcomes would change if specific input features were modified, including uncertainty estimates for these alternative outcomes.

# %%
alternative_explanations = classifier.explore_alternatives(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %% [markdown]
# Alternatives are also visualized using the `plot` function. Plotting an individual alternative explanation is easiest done using indexing. Adding or removing conjunctions is done as before.

# %%
alternative_explanations.plot()
alternative_explanations.add_conjunctions().plot()
alternative_explanations.add_conjunctions().plot(style="ensured")
print(alternative_explanations.to_narrative(output_format="text"))
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# ================================================================================
# Instance 0
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.545
# Prediction Interval: [0.500, 0.600]
#
# Alternatives to increase the calibrated probability for class 1:
# - If (density <= 0.9897 AND 2.05 < residual sugar <= 13.65)             then 0.848 [0.847, 0.857]
# - If (fixed acidity <= 5.85 AND 2.05 < residual sugar <= 13.65)         then 0.848 [0.847, 0.857]
# - If (volatile acidity <= 0.2225 AND 2.05 < residual sugar <= 13.65)    then 0.848 [0.847, 0.857]
# - If residual sugar 2.05 < residual sugar <= 13.65                      then 0.844 [0.842, 0.857]
# - If (sulphates <= 0.335 AND 2.05 < residual sugar <= 13.65)            then 0.844 [0.842, 0.857]
# - If (chlorides <= 0.0385 AND 2.05 < residual sugar <= 13.65)           then 0.800 [0.794, 0.824]
# - If alcohol > 13.35                                                    then 0.643 [0.634, 0.659]
# - If volatile acidity <= 0.2225                                         then 0.643 [0.634, 0.659]
# - If (2.05 < residual sugar <= 13.65 AND pH <= 2.91)                    then 0.598 [0.586, 0.615]
# - If (citric acid <= 0.265 AND 2.05 < residual sugar <= 13.65)          then 0.598 [0.586, 0.615]
# - If volatile acidity 0.2575 < volatile acidity <= 0.8325               then 0.592 [0.586, 0.600]
# - If density 0.992 < density <= 0.9958                                  then 0.592 [0.586, 0.600]
# - If (2.05 < residual sugar <= 13.65 AND free sulfur dioxide <= 16.5)   then 0.592 [0.586, 0.600]
# - If (2.05 < residual sugar <= 13.65 AND total sulfur dioxide <= 107.5) then 0.592 [0.586, 0.600]
# - If fixed acidity 7.25 < fixed acidity <= 9.95                         then 0.592 [0.586, 0.600]
# - If citric acid > 0.325                                                then 0.592 [0.586, 0.600]
# - If density <= 0.9897                                                  then 0.592 [0.586, 0.600]
# - If fixed acidity <= 5.85                                              then 0.592 [0.586, 0.600]
# - If free sulfur dioxide > 27.5                                         then 0.592 [0.586, 0.600]
# - If sulphates > 0.415                                                  then 0.592 [0.586, 0.600]
# - If (volatile acidity <= 0.2225 AND total sulfur dioxide <= 107.5)     then 0.592 [0.586, 0.600]
#
# Alternatives to decrease the calibrated probability for class 1:
# - If (citric acid <= 0.265 AND alcohol <= 11.45)                        then 0.062 [0.053, 0.062]
# - If (total sulfur dioxide <= 107.5 AND alcohol <= 11.45)               then 0.062 [0.053, 0.062]
# - If alcohol <= 11.45                                                   then 0.075 [0.053, 0.077]
# - If (chlorides <= 0.0385 AND alcohol <= 11.45)                         then 0.075 [0.053, 0.077]
# - If (density <= 0.9897 AND alcohol <= 11.45)                           then 0.075 [0.053, 0.077]
# - If (fixed acidity <= 5.85 AND alcohol <= 11.45)                       then 0.075 [0.053, 0.077]
# - If (pH <= 2.91 AND alcohol <= 11.45)                                  then 0.075 [0.053, 0.077]
# - If (sulphates <= 0.335 AND alcohol <= 11.45)                          then 0.075 [0.053, 0.077]
# - If (free sulfur dioxide <= 16.5 AND alcohol <= 11.45)                 then 0.150 [0.053, 0.167]
# - If (free sulfur dioxide <= 16.5 AND total sulfur dioxide <= 107.5)    then 0.172 [0.111, 0.185]
# - If (citric acid <= 0.265 AND pH <= 2.91)                              then 0.200 [0.158, 0.211]
# - If (free sulfur dioxide <= 16.5 AND pH <= 2.91)                       then 0.200 [0.158, 0.211]
# - If (volatile acidity <= 0.2225 AND alcohol <= 11.45)                  then 0.200 [0.158, 0.211]
# - If (citric acid <= 0.265 AND free sulfur dioxide <= 16.5)             then 0.244 [0.200, 0.258]
# - If (2.05 < residual sugar <= 13.65 AND alcohol <= 11.45)              then 0.271 [0.211, 0.294]
# - If (chlorides <= 0.0385 AND pH <= 2.91)                               then 0.271 [0.211, 0.294]
# - If (citric acid <= 0.265 AND total sulfur dioxide <= 107.5)           then 0.271 [0.211, 0.294]
# - If (chlorides <= 0.0385 AND total sulfur dioxide <= 107.5)            then 0.287 [0.235, 0.308]
# - If (density <= 0.9897 AND free sulfur dioxide <= 16.5)                then 0.287 [0.235, 0.308]
# - If free sulfur dioxide <= 16.5                                        then 0.287 [0.235, 0.308]
# - If (sulphates <= 0.335 AND free sulfur dioxide <= 16.5)               then 0.287 [0.235, 0.308]
# - If (total sulfur dioxide <= 107.5 AND pH <= 2.91)                     then 0.287 [0.235, 0.308]
# - If (chlorides <= 0.0385 AND free sulfur dioxide <= 16.5)              then 0.381 [0.370, 0.387]
# - If chlorides > 0.0455                                                 then 0.381 [0.370, 0.387]
# - If citric acid <= 0.265                                               then 0.381 [0.370, 0.387]
# - If (density <= 0.9897 AND pH <= 2.91)                                 then 0.381 [0.370, 0.387]
# - If (density <= 0.9897 AND total sulfur dioxide <= 107.5)              then 0.381 [0.370, 0.387]
# - If (fixed acidity <= 5.85 AND free sulfur dioxide <= 16.5)            then 0.381 [0.370, 0.387]
# - If (fixed acidity <= 5.85 AND pH <= 2.91)                             then 0.381 [0.370, 0.387]
# - If pH <= 2.91                                                         then 0.381 [0.370, 0.387]
# - If (sulphates <= 0.335 AND pH <= 2.91)                                then 0.381 [0.370, 0.387]
# - If (sulphates <= 0.335 AND total sulfur dioxide <= 107.5)             then 0.381 [0.370, 0.387]
# - If total sulfur dioxide <= 107.5                                      then 0.381 [0.370, 0.387]
# - If total sulfur dioxide 156.5 < total sulfur dioxide <= 229.5         then 0.462 [0.417, 0.500] [[!] uncertain]
# - If chlorides <= 0.0385                                                then 0.462 [0.417, 0.500] [[!] uncertain]
# - If (fixed acidity <= 5.85 AND total sulfur dioxide <= 107.5)          then 0.462 [0.417, 0.500] [[!] uncertain]
# - If sulphates <= 0.335                                                 then 0.462 [0.417, 0.500] [[!] uncertain]
# - If (volatile acidity <= 0.2225 AND free sulfur dioxide <= 16.5)       then 0.462 [0.417, 0.500] [[!] uncertain]
#
# Alternative Explanation (Beginner):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.545
#
# Alternatives to increase the calibrated probability for class 1:
# - (density <= 0.9897 AND 2.05 < residual sugar <= 13.65)
# - (fixed acidity <= 5.85 AND 2.05 < residual sugar <= 13.65)
# - (volatile acidity <= 0.2225 AND 2.05 < residual sugar <= 13.65)
# - residual sugar 2.05 < residual sugar <= 13.65
# - (sulphates <= 0.335 AND 2.05 < residual sugar <= 13.65)
# - (chlorides <= 0.0385 AND 2.05 < residual sugar <= 13.65)
# - alcohol > 13.35
# - volatile acidity <= 0.2225
# - (2.05 < residual sugar <= 13.65 AND pH <= 2.91)
# - (citric acid <= 0.265 AND 2.05 < residual sugar <= 13.65)
# - volatile acidity 0.2575 < volatile acidity <= 0.8325
# - density 0.992 < density <= 0.9958
# - (2.05 < residual sugar <= 13.65 AND free sulfur dioxide <= 16.5)
# - (2.05 < residual sugar <= 13.65 AND total sulfur dioxide <= 107.5)
# - fixed acidity 7.25 < fixed acidity <= 9.95
# - citric acid > 0.325
# - density <= 0.9897
# - fixed acidity <= 5.85
# - free sulfur dioxide > 27.5
# - sulphates > 0.415
# - (volatile acidity <= 0.2225 AND total sulfur dioxide <= 107.5)
#
# Alternatives to decrease the calibrated probability for class 1:
# - (citric acid <= 0.265 AND alcohol <= 11.45)
# - (total sulfur dioxide <= 107.5 AND alcohol <= 11.45)
# - alcohol <= 11.45
# - (chlorides <= 0.0385 AND alcohol <= 11.45)
# - (density <= 0.9897 AND alcohol <= 11.45)
# - (fixed acidity <= 5.85 AND alcohol <= 11.45)
# - (pH <= 2.91 AND alcohol <= 11.45)
# - (sulphates <= 0.335 AND alcohol <= 11.45)
# - (free sulfur dioxide <= 16.5 AND alcohol <= 11.45)
# - (free sulfur dioxide <= 16.5 AND total sulfur dioxide <= 107.5)
# - (citric acid <= 0.265 AND pH <= 2.91)
# - (free sulfur dioxide <= 16.5 AND pH <= 2.91)
# - (volatile acidity <= 0.2225 AND alcohol <= 11.45)
# - (citric acid <= 0.265 AND free sulfur dioxide <= 16.5)
# - (2.05 < residual sugar <= 13.65 AND alcohol <= 11.45)
# - (chlorides <= 0.0385 AND pH <= 2.91)
# - (citric acid <= 0.265 AND total sulfur dioxide <= 107.5)
# - (chlorides <= 0.0385 AND total sulfur dioxide <= 107.5)
# - (density <= 0.9897 AND free sulfur dioxide <= 16.5)
# - free sulfur dioxide <= 16.5
# - (sulphates <= 0.335 AND free sulfur dioxide <= 16.5)
# - (total sulfur dioxide <= 107.5 AND pH <= 2.91)
# - (chlorides <= 0.0385 AND free sulfur dioxide <= 16.5)
# - chlorides > 0.0455
# - citric acid <= 0.265
# - (density <= 0.9897 AND pH <= 2.91)
# - (density <= 0.9897 AND total sulfur dioxide <= 107.5)
# - (fixed acidity <= 5.85 AND free sulfur dioxide <= 16.5)
# - (fixed acidity <= 5.85 AND pH <= 2.91)
# - pH <= 2.91
# - (sulphates <= 0.335 AND pH <= 2.91)
# - (sulphates <= 0.335 AND total sulfur dioxide <= 107.5)
# - total sulfur dioxide <= 107.5
# - total sulfur dioxide 156.5 < total sulfur dioxide <= 229.5 [[!] uncertain]
# - chlorides <= 0.0385 [[!] uncertain]
# - (fixed acidity <= 5.85 AND total sulfur dioxide <= 107.5) [[!] uncertain]
# - sulphates <= 0.335 [[!] uncertain]
# - (volatile acidity <= 0.2225 AND free sulfur dioxide <= 16.5) [[!] uncertain]
#
# ================================================================================
# Instance 1
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.643
# Prediction Interval: [0.634, 0.659]
#
# Alternatives to increase the calibrated probability for class 1:
# - If (0.2575 < volatile acidity <= 0.8325 AND 107.5 < total sulfur dioxide <= 227) then 0.907 [0.905, 0.933]
# - If volatile acidity 0.2575 < volatile acidity <= 0.8325                          then 0.848 [0.847, 0.857]
# - If (0.2575 < volatile acidity <= 0.8325 AND alcohol > 13.35)                     then 0.848 [0.847, 0.857]
# - If (0.2575 < volatile acidity <= 0.8325 AND density <= 0.992)                    then 0.848 [0.847, 0.857]
# - If (0.2575 < volatile acidity <= 0.8325 AND sulphates > 0.645)                   then 0.848 [0.847, 0.857]
# - If total sulfur dioxide 107.5 < total sulfur dioxide <= 227                      then 0.848 [0.847, 0.857]
# - If (107.5 < total sulfur dioxide <= 227 AND alcohol > 13.35)                     then 0.848 [0.847, 0.857]
# - If (107.5 < total sulfur dioxide <= 227 AND density <= 0.992)                    then 0.848 [0.847, 0.857]
# - If (107.5 < total sulfur dioxide <= 227 AND sulphates > 0.645)                   then 0.848 [0.847, 0.857]
# - If (chlorides > 0.0355 AND 0.2575 < volatile acidity <= 0.8325)                  then 0.848 [0.847, 0.857]
# - If (chlorides > 0.0355 AND 107.5 < total sulfur dioxide <= 227)                  then 0.848 [0.847, 0.857]
# - If (chlorides > 0.0355 AND sulphates > 0.645)                                    then 0.848 [0.847, 0.857]
# - If (citric acid <= 0.325 AND 0.2575 < volatile acidity <= 0.8325)                then 0.848 [0.847, 0.857]
# - If (citric acid <= 0.325 AND 107.5 < total sulfur dioxide <= 227)                then 0.848 [0.847, 0.857]
# - If (citric acid <= 0.325 AND density <= 0.992)                                   then 0.848 [0.847, 0.857]
# - If (citric acid <= 0.325 AND sulphates > 0.645)                                  then 0.848 [0.847, 0.857]
# - If density <= 0.992                                                              then 0.848 [0.847, 0.857]
# - If (density <= 0.992 AND alcohol > 13.35)                                        then 0.848 [0.847, 0.857]
# - If (density <= 0.992 AND sulphates > 0.645)                                      then 0.848 [0.847, 0.857]
# - If (fixed acidity <= 5.85 AND 0.2575 < volatile acidity <= 0.8325)               then 0.848 [0.847, 0.857]
# - If (fixed acidity <= 5.85 AND density <= 0.992)                                  then 0.848 [0.847, 0.857]
# - If (residual sugar <= 6.95 AND 0.2575 < volatile acidity <= 0.8325)              then 0.848 [0.847, 0.857]
# - If (residual sugar <= 6.95 AND 107.5 < total sulfur dioxide <= 227)              then 0.848 [0.847, 0.857]
# - If (residual sugar <= 6.95 AND density <= 0.992)                                 then 0.848 [0.847, 0.857]
# - If (residual sugar <= 6.95 AND sulphates > 0.645)                                then 0.848 [0.847, 0.857]
# - If sulphates > 0.645                                                             then 0.848 [0.847, 0.857]
# - If (sulphates > 0.645 AND alcohol > 13.35)                                       then 0.848 [0.847, 0.857]
# - If alcohol > 13.35                                                               then 0.844 [0.842, 0.857]
# - If chlorides > 0.0355                                                            then 0.844 [0.842, 0.857]
# - If (citric acid <= 0.325 AND alcohol > 13.35)                                    then 0.844 [0.842, 0.857]
# - If citric acid > 0.425                                                           then 0.844 [0.842, 0.857]
# - If (fixed acidity <= 5.85 AND 107.5 < total sulfur dioxide <= 227)               then 0.844 [0.842, 0.857]
# - If (fixed acidity <= 5.85 AND sulphates > 0.645)                                 then 0.844 [0.842, 0.857]
# - If (residual sugar <= 6.95 AND alcohol > 13.35)                                  then 0.844 [0.842, 0.857]
# - If (chlorides > 0.0355 AND alcohol > 13.35)                                      then 0.800 [0.794, 0.824]
# - If citric acid <= 0.325                                                          then 0.800 [0.794, 0.824]
# - If density 0.9924 < density <= 0.9958                                            then 0.788 [0.778, 0.824]
# - If (chlorides > 0.0355 AND density <= 0.992)                                     then 0.788 [0.778, 0.824]
# - If residual sugar <= 6.95                                                        then 0.788 [0.778, 0.824]
#
# Alternatives to decrease the calibrated probability for class 1:
# - If alcohol <= 11.45                                                              then 0.592 [0.586, 0.600]
# - If fixed acidity <= 5.85                                                         then 0.592 [0.586, 0.600]
# - If pH <= 2.91                                                                    then 0.592 [0.586, 0.600]
# - If (pH <= 2.91 AND 107.5 < total sulfur dioxide <= 227)                          then 0.592 [0.586, 0.600]
# - If (pH <= 2.91 AND alcohol > 13.35)                                              then 0.592 [0.586, 0.600]
# - If (pH <= 2.91 AND sulphates > 0.645)                                            then 0.592 [0.586, 0.600]
# - If (pH <= 2.91 AND 0.2575 < volatile acidity <= 0.8325)                          then 0.598 [0.586, 0.615]
#
# Alternative Explanation (Beginner):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.643
#
# Alternatives to increase the calibrated probability for class 1:
# - (0.2575 < volatile acidity <= 0.8325 AND 107.5 < total sulfur dioxide <= 227)
# - volatile acidity 0.2575 < volatile acidity <= 0.8325
# - (0.2575 < volatile acidity <= 0.8325 AND alcohol > 13.35)
# - (0.2575 < volatile acidity <= 0.8325 AND density <= 0.992)
# - (0.2575 < volatile acidity <= 0.8325 AND sulphates > 0.645)
# - total sulfur dioxide 107.5 < total sulfur dioxide <= 227
# - (107.5 < total sulfur dioxide <= 227 AND alcohol > 13.35)
# - (107.5 < total sulfur dioxide <= 227 AND density <= 0.992)
# - (107.5 < total sulfur dioxide <= 227 AND sulphates > 0.645)
# - (chlorides > 0.0355 AND 0.2575 < volatile acidity <= 0.8325)
# - (chlorides > 0.0355 AND 107.5 < total sulfur dioxide <= 227)
# - (chlorides > 0.0355 AND sulphates > 0.645)
# - (citric acid <= 0.325 AND 0.2575 < volatile acidity <= 0.8325)
# - (citric acid <= 0.325 AND 107.5 < total sulfur dioxide <= 227)
# - (citric acid <= 0.325 AND density <= 0.992)
# - (citric acid <= 0.325 AND sulphates > 0.645)
# - density <= 0.992
# - (density <= 0.992 AND alcohol > 13.35)
# - (density <= 0.992 AND sulphates > 0.645)
# - (fixed acidity <= 5.85 AND 0.2575 < volatile acidity <= 0.8325)
# - (fixed acidity <= 5.85 AND density <= 0.992)
# - (residual sugar <= 6.95 AND 0.2575 < volatile acidity <= 0.8325)
# - (residual sugar <= 6.95 AND 107.5 < total sulfur dioxide <= 227)
# - (residual sugar <= 6.95 AND density <= 0.992)
# - (residual sugar <= 6.95 AND sulphates > 0.645)
# - sulphates > 0.645
# - (sulphates > 0.645 AND alcohol > 13.35)
# - alcohol > 13.35
# - chlorides > 0.0355
# - (citric acid <= 0.325 AND alcohol > 13.35)
# - citric acid > 0.425
# - (fixed acidity <= 5.85 AND 107.5 < total sulfur dioxide <= 227)
# - (fixed acidity <= 5.85 AND sulphates > 0.645)
# - (residual sugar <= 6.95 AND alcohol > 13.35)
# - (chlorides > 0.0355 AND alcohol > 13.35)
# - citric acid <= 0.325
# - density 0.9924 < density <= 0.9958
# - (chlorides > 0.0355 AND density <= 0.992)
# - residual sugar <= 6.95
#
# Alternatives to decrease the calibrated probability for class 1:
# - alcohol <= 11.45
# - fixed acidity <= 5.85
# - pH <= 2.91
# - (pH <= 2.91 AND 107.5 < total sulfur dioxide <= 227)
# - (pH <= 2.91 AND alcohol > 13.35)
# - (pH <= 2.91 AND sulphates > 0.645)
# - (pH <= 2.91 AND 0.2575 < volatile acidity <= 0.8325)

# %% [markdown]
# `calibrated_explanations` supports multiclass which is demonstrated in [demo_multiclass](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_multiclass.ipynb). That notebook also demonstrates how both feature names and target and categorical labels can be added to improve the interpretability.
# ## Regression
# Extracting explanations for regression is very similar to how it is done for classification. First we load and divide the dataset. The target is divided by 1000, meaning that the target is in thousands of dollars.

# %%
dataset = fetch_openml(name="house_sales", version=3)

X = dataset.data.values.astype(float)
y = dataset.target.values / 1000
y_filter = y < 500
X = X[y_filter, :]
y = y[y_filter]

feature_names = dataset.feature_names
categorical_labels = {5: {0: "False", 1: "True"}}

x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=2, random_state=42, stratify=X[:, 5]
)

X_prop_train, x_cal, y_prop_train, y_cal = train_test_split(
    x_train, y_train, random_state=42, test_size=500, stratify=x_train[:, 5]
)

# %% [markdown]
# We now create our wrapper object, using a `RandomForestRegressor` as learner.

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = WrapCalibratedExplainer(RandomForestRegressor())
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=False, calibrated=False)

# %% [markdown]
# We now fit our model using the proper training set.

# %%
regressor.fit(X_prop_train, y_prop_train)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=False)

# %% [markdown]
# The `WrapCalibratedExplainer` class has a `predict` method that returns the predictions and probability estimates of the underlying classifier. If the model is not yet calibrated, then the underlying models `predict` method is used. If the model is calibrated, then the `predict` method of the calibration model is used.

# %%
prediction = regressor.predict(x_test)
print(f"Uncalibrated model prediction: \n{prediction}")
# Out:
# Uncalibrated model prediction:
# [292.40088 409.24436]
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_15536\1346691177.py:1: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated predictions.
#   prediction = regressor.predict(x_test)

# %% [markdown]
# Before we can generate explanations, we need to calibrate our model using the calibration set.

# %%
regressor.calibrate(
    x_cal, y_cal, feature_names=feature_names, categorical_labels=categorical_labels
)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, learner=RandomForestRegressor(), difficulty_estimator=None))

# %% [markdown]
# We can easily add a difficulty estimator by assigning a `DifficultyEstimator` to the `difficulty_estimator` attribute when calibrating the model.

# %%
from crepes.extras import DifficultyEstimator

de = DifficultyEstimator().fit(X=X_prop_train, learner=regressor.learner, scaler=True)
regressor.calibrate(
    x_cal,
    y_cal,
    feature_names=feature_names,
    difficulty_estimator=de,
    categorical_labels=categorical_labels,
)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# Once the model is calibrated, the `predict`  method produce calibrated predictions with uncertainties. The default confidence is 90 per cent, which can be altered using the `low_high_percentiles` parameter.

# %%
prediction, (low, high) = regressor.predict(
    x_test, uq_interval=True
)  # default low_high_percentiles=(5, 95)
print(f"Calibrated prediction: \n{prediction}")
print("Calibrated uncertainty interval:")
print([(low[i], high[i]) for i in range(len(low))])
# Out:
# Calibrated prediction:
# [293.09423639 409.73206188]
# Calibrated uncertainty interval:
# [(np.float64(246.78936542479823), np.float64(326.31271734344807)), (np.float64(377.1615494639481), np.float64(433.09770191491106))]

# %% [markdown]
# You can also get the probability of the prediction being below a certain threshold using `predict_proba` by assigning the `threshold` parameter.

# %%
import numpy as np

prediction = regressor.predict(x_test, threshold=200)
print("Calibrated probabilistic prediction:")
print(prediction)

proba, (low, high) = regressor.predict_proba(x_test, uq_interval=True, threshold=200)
print("Calibrated probabilistic probability estimate [y_hat > threshold, y_hat <= threshold]:")
print(proba)
print(
    "Calibrated probabilistic uncertainty interval for y_hat <= threshold ([lower_bound, upper_bound]):"
)
print(np.array([(low[i], high[i]) for i in range(len(low))]))
# Out:
# Calibrated probabilistic prediction:
# ['y_hat > 200', 'y_hat > 200']
# Calibrated probabilistic probability estimate [y_hat > threshold, y_hat <= threshold]:
# [[0.984375   0.015625  ]
#  [0.99056604 0.00943396]]
# Calibrated probabilistic uncertainty interval for y_hat <= threshold ([lower_bound, upper_bound]):
# [[0.         0.01587302]
#  [0.         0.00952381]]

# %% [markdown]
# #### Factual Explanations
# Let us explain a test instance using our `WrapCalibratedExplainer` object. The method used to get factual explanations is `explain_factual` with `guarded_options=GuardedOptions()`.

# %%
factual_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions())
from calibrated_explanations.ce_agent_utils import print_guarded_audit_table

guarded_audit = factual_explanations.get_guarded_audit()
print_guarded_audit_table(guarded_audit, max_rows=20)
display(regressor)
# Out:
# Guarded Audit Summary
# instances=2 tested=262 conforming=237 removed_guard=25 emitted=35
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 bedrooms           (-inf, 1.5]                 0.5  Y    N    N   design_excluded
#    0    0 bedrooms           (1.5, 2.5]                0.878  Y    N    N   design_excluded
#    0    0 bedrooms           (2.5, 3.5]                0.986  Y    Y    N   emitted
#    0    0 bedrooms           (3.5, 4.5]                 0.95  Y    N    N   design_excluded
#    0    0 bedrooms           (4.5, 5.5]                0.692  Y    N    N   design_excluded
#    0    0 bedrooms           (5.5, inf]                 0.37  Y    N    N   design_excluded
#    0    1 bathrooms          (-inf, 0.875]              0.77  Y    N    N   design_excluded
#    0    1 bathrooms          (0.875, 1.25]             0.886  Y    N    N   design_excluded
#    0    1 bathrooms          (1.25, 1.625]              0.98  Y    N    N   design_excluded
#    0    1 bathrooms          (1.625, 1.875]            0.986  Y    N    N   design_excluded
#    0    1 bathrooms          (1.875, 2.375]             0.99  Y    Y    N   emitted
#    0    1 bathrooms          (2.375, inf]              0.956  Y    N    N   design_excluded
#    0    2 sqft_living        (-inf, 730]               0.892  Y    N    N   design_excluded
#    0    2 sqft_living        (730, 745]                0.914  Y    N    N   design_excluded
#    0    2 sqft_living        (745, 1145]               0.956  Y    N    N   design_excluded
#    0    2 sqft_living        (1145, 1205]              0.984  Y    N    N   design_excluded
#    0    2 sqft_living        (1205, 1545]               0.99  Y    Y    N   emitted
#    0    2 sqft_living        (1545, 2283]               0.98  Y    N    N   design_excluded
#    0    2 sqft_living        (2283, 2990]              0.886  Y    N    N   design_excluded
#    0    2 sqft_living        (2990, inf]                 0.5  Y    N    N   design_excluded
# ... truncated 242 row(s)
# reason_counts: emitted=35, removed_guard=25, design_excluded=195, zero_impact=7
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# #### Merge adjacent conforming bins
# By default, guarded explanations keep each bin as a separate rule.  Passing `GuardedOptions(merge_adjacent=True)` allows adjacent conforming bins to be collapsed into a single wider rule.  The merged rule is re-tested by the guard; if the re-test fails, the original bins are kept.  The `mrg` column in the audit table shows which emitted rules came from a merge.

# %%
merged_factual = regressor.explain_factual(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
merged_audit = merged_factual.get_guarded_audit()
print_guarded_audit_table(merged_audit, max_rows=30)
# Out:
# Guarded Audit Summary
# instances=2 tested=67 conforming=42 removed_guard=25 emitted=27
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 bedrooms           (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0    1 bathrooms          (-inf, inf]                0.99  Y    Y    Y   emitted
#    0    2 sqft_living        (-inf, inf]                0.98  Y    Y    Y   emitted
#    0    3 sqft_lot           (-inf, inf]               0.986  Y    Y    Y   emitted
#    0    4 floors             (-inf, 2.75]              0.986  Y    N    Y   zero_impact
#    0    4 floors             (2.75, inf]               0.098  N    N    N   removed_guard
#    0    5 waterfront         (-inf, inf]               0.986  Y    N    N   zero_impact
#    0    5 waterfront         (-inf, inf]               0.004  N    N    N   removed_guard
#    0    6 view               (-inf, 2.5]               0.986  Y    N    N   zero_impact
#    0    6 view               (2.5, 3.5]                0.078  N    N    N   removed_guard
#    0    6 view               (3.5, inf]                0.042  N    N    N   removed_guard
#    0    7 condition          (-inf, inf]               0.846  Y    Y    Y   emitted
#    0    8 grade              (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0    9 sqft_above         (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   10 sqft_basement      (-inf, inf]               0.996  Y    Y    Y   emitted
#    0   11 yr_built           (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   12 yr_renovated       (-inf, 976.5]             0.986  Y    N    N   zero_impact
#    0   12 yr_renovated       (976.5, 1960.5]           0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1960.5, 1972.5]          0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1972.5, 1988]            0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1988, 1992]              0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1992, 2006]              0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (2006, inf]               0.038  N    N    N   removed_guard
#    0   13 zipcode            (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   14 lat                (-inf, inf]                0.96  Y    Y    Y   emitted
#    0   15 long               (-inf, inf]               0.976  Y    Y    Y   emitted
#    0   16 sqft_living15      (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   17 sqft_lot15         (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   18 date_year          (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0   19 date_month         (-inf, inf]               0.986  Y    Y    Y   emitted
# ... truncated 37 row(s)
# reason_counts: emitted=27, removed_guard=25, zero_impact=15
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown

# %% [markdown]
# Regression also offer both regular and uncertainty plots for factual explanations with or without conjunctive rules, in almost exactly the same way as for classification.

# %%
factual_explanations.plot()
factual_explanations.plot(uncertainty=True)

factual_explanations.add_conjunctions().plot(uncertainty=True)

# %% [markdown]
# Default, the confidence interval is set to a symmetric interval of 90% (defined as `low_high_percentiles=(5,95)`). The intervals can cover any user specified interval, including one-sided intervals. To define a one-sided upper-bounded 90% interval, set `low_high_percentiles=(-np.inf,90)`, and to define a one-sided lower-bounded 95% interval, set `low_high_percentiles=(5,np.inf)`. Percentiles can also be set to any other values in the range (0,100) (exclusive), and intervals do not have to be symmetric.

# %%
lower_bounded_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), low_high_percentiles=(5, np.inf))
asymmetric_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), low_high_percentiles=(5, 75))

# %% [markdown]
# #### Explore Alternative Explanations
# `explore_alternatives` with `guarded_options=GuardedOptions()` works exactly the same as for classification.

# %%
alternative_explanations = regressor.explore_alternatives(x_test, guarded_options=GuardedOptions())
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# Alternative plots work as for classification.

# %%
alternative_explanations.plot(rnk_metric="ensured", rnk_weight=0.9)
alternative_explanations.add_conjunctions().plot()
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(

# %% [markdown]
# ## Probabilistic Regression
# The difference between probabilistic regression and regular regression is that the former returns a probability of the prediction being below a certain threshold. This could for example be useful when the prediction is a time to an event, such as time to death or time to failure.

# %%
probabilistic_factual_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), threshold=y_test + 20)
probabilistic_factual_explanations.plot()
probabilistic_factual_explanations.plot(uncertainty=True)

# %%
probabilistic_alternative_explanations = regressor.explore_alternatives(x_test, guarded_options=GuardedOptions(), threshold=y_test + 20)
probabilistic_alternative_explanations.plot()
probabilistic_alternative_explanations.plot(style="ensured")
print(probabilistic_alternative_explanations.to_narrative(expertise_level="advanced",output_format="text"))
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# ================================================================================
# Instance 0
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Calibrated Probability (target <= 310.000): 0.833
# Prediction Interval: [0.818, 0.905]
#
# Alternatives to increase the Calibrated Probability for target <= 310.000:
# - If lat 47.33 < lat <= 47.43                       then P(target <= 310.000) = 0.976 [0.975, 1.000]
# - If lat <= 47.33                                   then P(target <= 310.000) = 0.976 [0.975, 1.000]
# - If sqft_living 745 < sqft_living <= 1145          then P(target <= 310.000) = 0.950 [0.947, 1.000]
# - If sqft_living 730 < sqft_living <= 745           then P(target <= 310.000) = 0.941 [0.938, 1.000]
# - If sqft_living 1145 < sqft_living <= 1205         then P(target <= 310.000) = 0.906 [0.897, 1.000]
# - If sqft_living <= 730                             then P(target <= 310.000) = 0.906 [0.897, 1.000]
# - If date_day 4.5 < date_day <= 8.5                 then P(target <= 310.000) = 0.864 [0.857, 0.909]
# - If sqft_living15 1035 < sqft_living15 <= 1195     then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If sqft_living15 1195 < sqft_living15 <= 1205     then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If date_day 15.5 < date_day <= 16.5               then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If date_day 16.5 < date_day <= 18.5               then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If grade 4.5 < grade <= 6.5                       then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If date_day 8.5 < date_day <= 10.5                then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If sqft_living15 955 < sqft_living15 <= 1035      then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If date_day <= 4.5                                then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If date_month > 11.5                              then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If grade <= 4.5                                   then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If sqft_living15 <= 955                           then P(target <= 310.000) = 0.855 [0.846, 0.909]
# - If sqft_lot 1268 < sqft_lot <= 4082               then P(target <= 310.000) = 0.833 [0.818, 0.909]
# - If yr_built 1918 < yr_built <= 1966               then P(target <= 310.000) = 0.833 [0.818, 0.909]
#
# Alternatives to decrease the Calibrated Probability for target <= 310.000:
# - If lat 47.57 < lat <= 47.7                        then P(target <= 310.000) = 0.032 [0.000, 0.033]
# - If lat 47.53 < lat <= 47.54                       then P(target <= 310.000) = 0.033 [0.017, 0.033]
# - If lat 47.54 < lat <= 47.57                       then P(target <= 310.000) = 0.033 [0.017, 0.033]
# - If lat > 47.7                                     then P(target <= 310.000) = 0.098 [0.017, 0.107]
# - If sqft_living > 2990                             then P(target <= 310.000) = 0.186 [0.125, 0.200]
# - If long -122.4 < long <= -122.4                   then P(target <= 310.000) = 0.429 [0.400, 0.450]
# - If long -122.4 < long <= -122.4                   then P(target <= 310.000) = 0.429 [0.400, 0.450]
# - If sqft_living 2283 < sqft_living <= 2990         then P(target <= 310.000) = 0.429 [0.400, 0.450]
# - If lat 47.52 < lat <= 47.53                       then P(target <= 310.000) = 0.429 [0.400, 0.450]
# - If long <= -122.4                                 then P(target <= 310.000) = 0.429 [0.400, 0.450]
# - If sqft_above 1535 < sqft_above <= 2125           then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If sqft_living 1545 < sqft_living <= 2283         then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If sqft_above 2125 < sqft_above <= 2365           then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If sqft_above 2365 < sqft_above <= 3000           then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If sqft_above 3000 < sqft_above <= 3186           then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If sqft_above > 3186                              then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If sqft_lot > 1.001e+04                           then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If sqft_lot15 > 1.512e+04                         then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If yr_built <= 1908                               then P(target <= 310.000) = 0.625 [0.609, 0.652]
# - If sqft_living15 > 2765                           then P(target <= 310.000) = 0.630 [0.609, 0.667]
# - If long -122.1 < long <= -122.1                   then P(target <= 310.000) = 0.653 [0.621, 0.714]
# - If sqft_living15 2305 < sqft_living15 <= 2765     then P(target <= 310.000) = 0.653 [0.621, 0.714]
# - If long > -122.1                                  then P(target <= 310.000) = 0.653 [0.621, 0.714]
# - If bathrooms 0.875 < bathrooms <= 1.25            then P(target <= 310.000) = 0.784 [0.750, 0.905]
# - If date_month 2.5 < date_month <= 7.5             then P(target <= 310.000) = 0.784 [0.750, 0.905]
# - If bedrooms 3.5 < bedrooms <= 4.5                 then P(target <= 310.000) = 0.784 [0.750, 0.905]
# - If bathrooms <= 0.875                             then P(target <= 310.000) = 0.784 [0.750, 0.905]
# - If bedrooms 1.5 < bedrooms <= 2.5                 then P(target <= 310.000) = 0.819 [0.800, 0.905]
# - If bedrooms <= 1.5                                then P(target <= 310.000) = 0.819 [0.800, 0.905]
# - If condition <= 2.5                               then P(target <= 310.000) = 0.819 [0.800, 0.905]
#
# ================================================================================
# Instance 1
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Calibrated Probability (target <= 417.500): 0.690
# Prediction Interval: [0.667, 0.741]
#
# Alternatives to increase the Calibrated Probability for target <= 417.500:
# - If lat 47.33 < lat <= 47.43                       then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat 47.43 < lat <= 47.52                       then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat 47.52 < lat <= 47.53                       then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat <= 47.33                                   then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat > 47.7                                     then P(target <= 417.500) = 0.938 [0.933, 1.000]
# - If sqft_living 1145 < sqft_living <= 1205         then P(target <= 417.500) = 0.717 [0.704, 0.750]
# - If lat 47.53 < lat <= 47.54                       then P(target <= 417.500) = 0.717 [0.704, 0.750]
# - If lat 47.54 < lat <= 47.57                       then P(target <= 417.500) = 0.703 [0.688, 0.741]
# - If sqft_living 730 < sqft_living <= 745           then P(target <= 417.500) = 0.703 [0.688, 0.741]
# - If sqft_living <= 730                             then P(target <= 417.500) = 0.703 [0.688, 0.741]
#
# Alternatives to decrease the Calibrated Probability for target <= 417.500:
# - If sqft_living 2283 < sqft_living <= 2990         then P(target <= 417.500) = 0.344 [0.308, 0.364]
# - If long <= -122.4                                 then P(target <= 417.500) = 0.344 [0.308, 0.364]
# - If long -122.1 < long <= -122.1                   then P(target <= 417.500) = 0.497 [0.455, 0.538] [[!] uncertain]
# - If sqft_lot15 1.033e+04 < sqft_lot15 <= 1.512e+04 then P(target <= 417.500) = 0.497 [0.455, 0.538] [[!] uncertain]
# - If sqft_living 1545 < sqft_living <= 2283         then P(target <= 417.500) = 0.497 [0.455, 0.538] [[!] uncertain]
# - If sqft_lot15 6030 < sqft_lot15 <= 6044           then P(target <= 417.500) = 0.497 [0.455, 0.538] [[!] uncertain]
# - If sqft_lot15 6044 < sqft_lot15 <= 7108           then P(target <= 417.500) = 0.497 [0.455, 0.538] [[!] uncertain]
# - If sqft_lot15 7108 < sqft_lot15 <= 1.033e+04      then P(target <= 417.500) = 0.497 [0.455, 0.538] [[!] uncertain]
# - If long > -122.1                                  then P(target <= 417.500) = 0.571 [0.500, 0.667] [[!] uncertain]
# - If sqft_lot15 > 1.512e+04                         then P(target <= 417.500) = 0.571 [0.500, 0.667] [[!] uncertain]
# - If long -122.4 < long <= -122.4                   then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If long -122.4 < long <= -122.4                   then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If bathrooms 0.875 < bathrooms <= 1.25            then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If bedrooms 1.5 < bedrooms <= 2.5                 then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_month 1.5 < date_month <= 2.5             then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_day 10.5 < date_day <= 15.5               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_living15 1035 < sqft_living15 <= 1195     then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_above 1075 < sqft_above <= 1135           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_living15 1195 < sqft_living15 <= 1205     then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_living15 1205 < sqft_living15 <= 1365     then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_basement 135 < sqft_basement <= 155       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_day 15.5 < date_day <= 16.5               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_above 1535 < sqft_above <= 2125           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_basement 155 < sqft_basement <= 165       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_day 16.5 < date_day <= 18.5               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_basement 165 < sqft_basement <= 245       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_day 18.5 < date_day <= 27.5               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If yr_built 1918 < yr_built <= 1966               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_month 2.5 < date_month <= 7.5             then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_above 2125 < sqft_above <= 2365           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_living15 2305 < sqft_living15 <= 2765     then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_above 2365 < sqft_above <= 3000           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_basement 245 < sqft_basement <= 665       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If bedrooms 3.5 < bedrooms <= 4.5                 then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If condition 3.5 < condition <= 4.5               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_above 3000 < sqft_above <= 3186           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If bedrooms 4.5 < bedrooms <= 5.5                 then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If grade 4.5 < grade <= 6.5                       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_lot 4082 < sqft_lot <= 6479               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If grade 6.5 < grade <= 7.5                       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_lot 6479 < sqft_lot <= 9858               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_basement 665 < sqft_basement <= 965       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_day 8.5 < date_day <= 10.5                then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If grade 8.5 < grade <= 9.5                       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If zipcode 9.801e+04 < zipcode <= 9.802e+04       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If zipcode 9.802e+04 < zipcode <= 9.803e+04       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If zipcode 9.8e+04 < zipcode <= 9.801e+04         then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If zipcode 9.8e+04 < zipcode <= 9.8e+04           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If zipcode 9.8e+04 < zipcode <= 9.8e+04           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_living15 955 < sqft_living15 <= 1035      then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_basement 965 < sqft_basement <= 995       then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_lot 9858 < sqft_lot <= 1.001e+04          then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If bedrooms <= 1.5                                then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If condition <= 2.5                               then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If condition > 4.5                                then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_day > 27.5                                then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_month <= 1.5                              then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If date_month > 11.5                              then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If grade <= 4.5                                   then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If grade > 9.5                                    then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_above <= 1075                             then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_living15 <= 955                           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_living15 > 2765                           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_lot <= 692                                then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_lot > 1.001e+04                           then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If sqft_lot15 <= 1238                             then P(target <= 417.500) = 0.647 [0.636, 0.667]
# - If zipcode <= 9.8e+04                             then P(target <= 417.500) = 0.647 [0.636, 0.667]

# %% [markdown]
# Regression offers many more options but to learn more about them, see the [demo_regression](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_regression.ipynb) or the [demo_probabilistic_regression](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_probabilistic_regression.ipynb) notebooks.
#
# A `WrapCalibratedExplainer` can also be initialized with a trained model or with a `WrapCalibratedExplainer` object, as is examplified below. We use the `learner` and `explainer` from the previously initialized `classifier` and `regressor` instances, as we know that these are fitted and calibrated.

# %%
new_classifier = WrapCalibratedExplainer(classifier.learner)
display(new_classifier)
new_classifier_explainer = WrapCalibratedExplainer(classifier.explainer)
display(new_classifier_explainer)

new_regressor = WrapCalibratedExplainer(regressor.learner)
display(new_regressor)
new_regressor_explainer = WrapCalibratedExplainer(regressor.explainer)
display(new_regressor_explainer)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=False)
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=False)
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# When a calibrated explainer is re-fitted, the explainer is reinitialized.
