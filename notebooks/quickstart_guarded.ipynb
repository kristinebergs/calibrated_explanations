# %% [markdown]
# ## Learning objectives
# - Learn how to use `WrapCalibratedExplainer` to wrap a model and produce calibrated predictions;
# - Generate factual and alternative explanations and plot uncertainty;
# - Understand when OOB vs explicit calibration is appropriate.
#
# ## Time to run
# ~2–10 min depending on dataset and environment (use smaller datasets for a faster run).

# %% [markdown]
# # Getting started with calibrated-explanations - using the WrapCalibratedExplainer class
# Author: Tuwe Löfström (tuwe.lofstrom@ju.se)
# Copyright 2023 Tuwe Löfström
# License: BSD 3 clause
# ## Classification
# Let us illustrate how we may use `calibrated_explanations` to generate explanations from a classifier trained on a dataset from
# [www.openml.org](https://www.openml.org), which we first split into a
# training and a test set using `train_test_split` from
# [sklearn](https://scikit-learn.org), and then further split the
# training set into a proper training set and a calibration set:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

dataset = fetch_openml(name="wine", version=7, as_frame=True, parser="auto")

X = dataset.data.values.astype(float)
y = (dataset.target.values == "True").astype(int)

feature_names = dataset.feature_names

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=2, stratify=y)

X_prop_train, x_cal, y_prop_train, y_cal = train_test_split(x_train, y_train, test_size=0.25)

# %% [markdown]
# We now create our wrapper object, using a `RandomForestClassifier` as learner.

# %%
from sklearn.ensemble import RandomForestClassifier

from calibrated_explanations import WrapCalibratedExplainer, __version__

print(f"calibrated_explanations {__version__}")

classifier = WrapCalibratedExplainer(RandomForestClassifier())
display(classifier)
# Out:
# calibrated_explanations 1.0.0rc1
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=False, calibrated=False)

# %% [markdown]
# We now fit our model using the proper training set.

# %%
classifier.fit(X_prop_train, y_prop_train)
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=False)

# %% [markdown]
# The `WrapCalibratedExplainer` class has a `predict` and a `predict_proba` method that returns the predictions and probability estimates of the underlying classifier. If the model is not yet calibrated, then the underlying models `predict` and `predict_proba` methods are used. If the model is calibrated, then the `predict` and `predict_proba` method of the calibration model is used.

# %%
prediction = classifier.predict(x_test)
proba = classifier.predict_proba(x_test)
print("Uncalibrated prediction (probability estimates):")
print(f"{prediction} ({proba})")
# Out:
# Uncalibrated prediction (probability estimates):
# [0 1] ([[0.68 0.32]
#  [0.25 0.75]])
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_3068\1092592062.py:1: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated predictions.
#   prediction = classifier.predict(x_test)
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_3068\1092592062.py:2: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated probabilities.
#   proba = classifier.predict_proba(x_test)

# %% [markdown]
# Before we can generate explanations, we need to calibrate our model using the calibration set.

# %%
classifier.calibrate(x_cal, y_cal, feature_names=feature_names)
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, learner=RandomForestClassifier()))

# %% [markdown]
# Once the model is calibrated, the `predict` and `predict_proba` methods produce calibrated predictions and probability estimates.

# %%
prediction = classifier.predict(x_test)
proba, (low, high) = classifier.predict_proba(x_test, uq_interval=True)
print("Calibrated prediction (probability estimates):")
print(f"{prediction} ({proba})")
print("Calibrated uncertainty interval for the positive class:")
print([(low[i], high[i]) for i in range(len(low))])
# Out:
# Calibrated prediction (probability estimates):
# [0 1] ([[0.61764706 0.38235294]
#  [0.11787072 0.88212928]])
# Calibrated uncertainty interval for the positive class:
# [(np.float64(0.36363636363636365), np.float64(0.3939393939393939)), (np.float64(0.875), np.float64(0.9354838709677419))]

# %% [markdown]
# #### Factual Explanations
# Let us explain a test instance using our `WrapCalibratedExplainer` object. The method used to get factual explanations is `explain_factual` with `guarded_options=GuardedOptions()`.

# %%
from calibrated_explanations import GuardedOptions

factual_explanations = classifier.explain_factual(x_test, guarded_options=GuardedOptions())
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %%
from calibrated_explanations.ce_agent_utils import print_guarded_audit_table

guarded_audit = factual_explanations.get_guarded_audit()
print_guarded_audit_table(guarded_audit, max_rows=20)
display(classifier)
# Out:
# Guarded Audit Summary
# instances=2 tested=172 conforming=147 removed_guard=25 emitted=22
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 fixed acidity      (-inf, 4.9]              0.3793  Y    N    N   design_excluded
#    0    0 fixed acidity      (4.9, 5.15]              0.4843  Y    N    N   design_excluded
#    0    0 fixed acidity      (5.15, 6.15]             0.7508  Y    N    N   design_excluded
#    0    0 fixed acidity      (6.15, 6.85]             0.8574  Y    Y    N   emitted
#    0    0 fixed acidity      (6.85, 9.1]              0.7304  Y    N    N   design_excluded
#    0    0 fixed acidity      (9.1, 9.95]               0.326  Y    N    N   design_excluded
#    0    0 fixed acidity      (9.95, 11.3]             0.1473  Y    N    N   design_excluded
#    0    0 fixed acidity      (11.3, inf]              0.0455  N    N    N   removed_guard
#    0    1 volatile acidity   (-inf, 0.1075]           0.7586  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.1075, 0.1825]         0.8574  Y    Y    N   emitted
#    0    1 volatile acidity   (0.1825, 0.1875]         0.8762  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.1875, 0.525]          0.8119  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.525, 0.665]           0.1426  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.665, 0.755]           0.0643  N    N    N   removed_guard
#    0    1 volatile acidity   (0.755, 0.8625]          0.0376  N    N    N   removed_guard
#    0    1 volatile acidity   (0.8625, inf]            0.0125  N    N    N   removed_guard
#    0    2 citric acid        (-inf, 0.135]            0.2978  Y    N    N   design_excluded
#    0    2 citric acid        (0.135, 0.175]           0.7069  Y    N    N   design_excluded
#    0    2 citric acid        (0.175, 0.185]           0.8166  Y    N    N   design_excluded
#    0    2 citric acid        (0.185, 0.235]           0.8762  Y    Y    N   emitted
# ... truncated 152 row(s)
# reason_counts: emitted=22, removed_guard=25, design_excluded=125
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %% [markdown]
# #### Merge adjacent conforming bins
# Passing `merge_adjacent=True` collapses adjacent conforming bins into wider rules (re-tested by the guard).  Rows with `mrg=Y` in the audit table came from a merge; the displayed interval shows the emitted bounds.

# %%
merged_factual_cls = classifier.explain_factual(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
merged_audit_cls = merged_factual_cls.get_guarded_audit()
print_guarded_audit_table(merged_audit_cls, max_rows=30)
# Out:
# Guarded Audit Summary
# instances=2 tested=47 conforming=22 removed_guard=25 emitted=13
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 fixed acidity      (-inf, 11.3]             0.8433  Y    N    Y   zero_impact
#    0    0 fixed acidity      (11.3, inf]              0.0455  N    N    N   removed_guard
#    0    1 volatile acidity   (-inf, 0.665]             0.826  Y    Y    Y   emitted
#    0    1 volatile acidity   (0.665, 0.755]           0.0643  N    N    N   removed_guard
#    0    1 volatile acidity   (0.755, 0.8625]          0.0376  N    N    N   removed_guard
#    0    1 volatile acidity   (0.8625, inf]            0.0125  N    N    N   removed_guard
#    0    2 citric acid        (-inf, inf]              0.9498  Y    Y    Y   emitted
#    0    3 residual sugar     (-inf, 15.6]              0.663  Y    N    Y   zero_impact
#    0    3 residual sugar     (15.6, inf]              0.0658  N    N    N   removed_guard
#    0    4 chlorides          (-inf, 0.1255]           0.8589  Y    N    Y   zero_impact
#    0    4 chlorides          (0.1255, inf]            0.0141  N    N    N   removed_guard
#    0    5 free sulfur dioxid (-inf, 90]               0.6583  Y    Y    Y   emitted
#    0    5 free sulfur dioxid (90, 97]                 0.0705  N    N    N   removed_guard
#    0    5 free sulfur dioxid (97, inf]                0.0329  N    N    N   removed_guard
#    0    6 total sulfur dioxi (-inf, 24.5]             0.0658  N    N    N   removed_guard
#    0    6 total sulfur dioxi (24.5, inf]              0.8652  Y    N    Y   zero_impact
#    0    7 density            (-inf, inf]              0.8762  Y    N    Y   zero_impact
#    0    8 pH                 (-inf, 2.805]            0.0799  N    N    N   removed_guard
#    0    8 pH                 (2.805, inf]             0.8292  Y    Y    Y   emitted
#    0    9 sulphates          (-inf, 0.835]            0.8292  Y    N    Y   zero_impact
#    0    9 sulphates          (0.835, 1.11]            0.0658  N    N    N   removed_guard
#    0    9 sulphates          (1.11, inf]              0.0078  N    N    N   removed_guard
#    0   10 alcohol            (-inf, inf]              0.8574  Y    N    Y   zero_impact
#    1    0 fixed acidity      (-inf, 11.3]             0.6661  Y    Y    Y   emitted
#    1    0 fixed acidity      (11.3, inf]              0.0517  N    N    N   removed_guard
#    1    1 volatile acidity   (-inf, 0.755]            0.5627  Y    Y    Y   emitted
#    1    1 volatile acidity   (0.755, 0.8625]          0.0643  N    N    N   removed_guard
#    1    1 volatile acidity   (0.8625, inf]            0.0172  N    N    N   removed_guard
#    1    2 citric acid        (-inf, 0.685]            0.5721  Y    N    Y   zero_impact
#    1    2 citric acid        (0.685, inf]             0.0752  N    N    N   removed_guard
# ... truncated 17 row(s)
# reason_counts: emitted=13, removed_guard=25, zero_impact=9
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown

# %% [markdown]
# Once we have the explanations, we can plot all of them using `plot`. Default, a regular plot, without uncertainty intervals included, is created. To include uncertainty intervals, change the parameter `uncertainty=True`.

# %%
factual_explanations.plot()
factual_explanations.plot(uncertainty=True)

# %% [markdown]
# You can also add and remove conjunctive rules.

# %%
factual_explanations.add_conjunctions().plot()
factual_explanations.remove_conjunctions().plot(uncertainty=True)

# %% [markdown]
# All explanations support indexing using integer indexing, slices or boolean indexing.

# %%
factual_explanations[0].plot(uncertainty=True)
factual_explanations[:1].plot(uncertainty=True)

# %% [markdown]
# #### Explore Alternative Explanations
# An alternative to factual rules is to extract alternative rules, which is done using `explore_alternatives` with `guarded_options=GuardedOptions()`. Alternative explanations provides insights on how predicted outcomes would change if specific input features were modified, including uncertainty estimates for these alternative outcomes.

# %%
alternative_explanations = classifier.explore_alternatives(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %% [markdown]
# Alternatives are also visualized using the `plot` function. Plotting an individual alternative explanation is easiest done using indexing. Adding or removing conjunctions is done as before.

# %%
alternative_explanations.plot()
alternative_explanations.add_conjunctions().plot()
alternative_explanations.add_conjunctions().plot(style="ensured")
print(alternative_explanations.to_narrative(output_format="text"))
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# ================================================================================
# Instance 0
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Prediction: 0
# Calibrated probability: 0.382
# Prediction Interval: [0.364, 0.394]
#
# Alternatives to increase the calibrated probability for class 1:
# - If sulphates 0.625 < sulphates <= 0.835                                  then 0.404 [0.391, 0.413]
# - If total sulfur dioxide 24.5 < total sulfur dioxide <= 101.5             then 0.404 [0.391, 0.413]
# - If alcohol > 11.15                                                       then 0.404 [0.391, 0.413]
# - If chlorides <= 0.0465                                                   then 0.404 [0.391, 0.413]
# - If (chlorides <= 0.0465 AND density > 0.9954)                            then 0.404 [0.391, 0.413]
# - If (chlorides <= 0.0465 AND free sulfur dioxide <= 25.5)                 then 0.404 [0.391, 0.413]
# - If (chlorides <= 0.0465 AND total sulfur dioxide > 158.5)                then 0.404 [0.391, 0.413]
# - If citric acid > 0.235                                                   then 0.404 [0.391, 0.413]
# - If (citric acid > 0.235 AND density > 0.9954)                            then 0.404 [0.391, 0.413]
# - If (citric acid > 0.235 AND free sulfur dioxide <= 25.5)                 then 0.404 [0.391, 0.413]
# - If density <= 0.9926                                                     then 0.404 [0.391, 0.413]
# - If pH > 3.395                                                            then 0.404 [0.391, 0.413]
# - If (pH > 3.395 AND density > 0.9954)                                     then 0.404 [0.391, 0.413]
#
# Alternatives to decrease the calibrated probability for class 1:
# - If (0.1825 < volatile acidity <= 0.665 AND alcohol <= 10.65)             then 0.021 [0.000, 0.021]
# - If volatile acidity 0.1825 < volatile acidity <= 0.665                   then 0.051 [0.034, 0.052]
# - If (0.1825 < volatile acidity <= 0.665 AND free sulfur dioxide <= 25.5)  then 0.051 [0.034, 0.052]
# - If (0.1825 < volatile acidity <= 0.665 AND total sulfur dioxide > 158.5) then 0.051 [0.034, 0.052]
# - If (fixed acidity <= 6.15 AND 0.1825 < volatile acidity <= 0.665)        then 0.051 [0.034, 0.052]
# - If (free sulfur dioxide <= 25.5 AND alcohol <= 10.65)                    then 0.051 [0.034, 0.052]
# - If (sulphates <= 0.445 AND 0.1825 < volatile acidity <= 0.665)           then 0.051 [0.034, 0.052]
# - If (sulphates <= 0.445 AND alcohol <= 10.65)                             then 0.051 [0.034, 0.052]
# - If alcohol <= 10.65                                                      then 0.057 [0.034, 0.059]
# - If (fixed acidity <= 6.15 AND alcohol <= 10.65)                          then 0.079 [0.034, 0.083]
# - If (0.1825 < volatile acidity <= 0.665 AND density > 0.9954)             then 0.123 [0.111, 0.125]
# - If (24.5 < total sulfur dioxide <= 101.5 AND alcohol <= 10.65)           then 0.123 [0.111, 0.125]
# - If (chlorides <= 0.0465 AND alcohol <= 10.65)                            then 0.123 [0.111, 0.125]
# - If (citric acid > 0.235 AND 0.1825 < volatile acidity <= 0.665)          then 0.123 [0.111, 0.125]
# - If (sulphates <= 0.445 AND density > 0.9954)                             then 0.123 [0.111, 0.125]
# - If (sulphates <= 0.445 AND free sulfur dioxide <= 25.5)                  then 0.123 [0.111, 0.125]
# - If (fixed acidity <= 6.15 AND density > 0.9954)                          then 0.130 [0.111, 0.133]
# - If (fixed acidity <= 6.15 AND total sulfur dioxide > 158.5)              then 0.130 [0.111, 0.133]
# - If (density <= 0.9926 AND alcohol <= 10.65)                              then 0.178 [0.111, 0.192]
# - If (fixed acidity <= 6.15 AND free sulfur dioxide <= 25.5)               then 0.178 [0.111, 0.192]
# - If (sulphates <= 0.445 AND total sulfur dioxide > 158.5)                 then 0.178 [0.111, 0.192]
# - If (chlorides <= 0.0465 AND 0.1825 < volatile acidity <= 0.665)          then 0.222 [0.176, 0.235]
# - If density > 0.9954                                                      then 0.222 [0.176, 0.235]
# - If fixed acidity <= 6.15                                                 then 0.222 [0.176, 0.235]
# - If free sulfur dioxide <= 25.5                                           then 0.222 [0.176, 0.235]
# - If (free sulfur dioxide <= 25.5 AND density > 0.9954)                    then 0.222 [0.176, 0.235]
# - If (free sulfur dioxide <= 25.5 AND total sulfur dioxide > 158.5)        then 0.222 [0.176, 0.235]
# - If (pH > 3.395 AND alcohol <= 10.65)                                     then 0.222 [0.176, 0.235]
# - If total sulfur dioxide > 158.5                                          then 0.222 [0.176, 0.235]
# - If sulphates <= 0.445                                                    then 0.300 [0.222, 0.333]
#
# Alternative Explanation (Beginner):
# --------------------------------------------------------------------------------
# Prediction: 0
# Calibrated probability: 0.382
#
# Alternatives to increase the calibrated probability for class 1:
# - sulphates 0.625 < sulphates <= 0.835
# - total sulfur dioxide 24.5 < total sulfur dioxide <= 101.5
# - alcohol > 11.15
# - chlorides <= 0.0465
# - (chlorides <= 0.0465 AND density > 0.9954)
# - (chlorides <= 0.0465 AND free sulfur dioxide <= 25.5)
# - (chlorides <= 0.0465 AND total sulfur dioxide > 158.5)
# - citric acid > 0.235
# - (citric acid > 0.235 AND density > 0.9954)
# - (citric acid > 0.235 AND free sulfur dioxide <= 25.5)
# - density <= 0.9926
# - pH > 3.395
# - (pH > 3.395 AND density > 0.9954)
#
# Alternatives to decrease the calibrated probability for class 1:
# - (0.1825 < volatile acidity <= 0.665 AND alcohol <= 10.65)
# - volatile acidity 0.1825 < volatile acidity <= 0.665
# - (0.1825 < volatile acidity <= 0.665 AND free sulfur dioxide <= 25.5)
# - (0.1825 < volatile acidity <= 0.665 AND total sulfur dioxide > 158.5)
# - (fixed acidity <= 6.15 AND 0.1825 < volatile acidity <= 0.665)
# - (free sulfur dioxide <= 25.5 AND alcohol <= 10.65)
# - (sulphates <= 0.445 AND 0.1825 < volatile acidity <= 0.665)
# - (sulphates <= 0.445 AND alcohol <= 10.65)
# - alcohol <= 10.65
# - (fixed acidity <= 6.15 AND alcohol <= 10.65)
# - (0.1825 < volatile acidity <= 0.665 AND density > 0.9954)
# - (24.5 < total sulfur dioxide <= 101.5 AND alcohol <= 10.65)
# - (chlorides <= 0.0465 AND alcohol <= 10.65)
# - (citric acid > 0.235 AND 0.1825 < volatile acidity <= 0.665)
# - (sulphates <= 0.445 AND density > 0.9954)
# - (sulphates <= 0.445 AND free sulfur dioxide <= 25.5)
# - (fixed acidity <= 6.15 AND density > 0.9954)
# - (fixed acidity <= 6.15 AND total sulfur dioxide > 158.5)
# - (density <= 0.9926 AND alcohol <= 10.65)
# - (fixed acidity <= 6.15 AND free sulfur dioxide <= 25.5)
# - (sulphates <= 0.445 AND total sulfur dioxide > 158.5)
# - (chlorides <= 0.0465 AND 0.1825 < volatile acidity <= 0.665)
# - density > 0.9954
# - fixed acidity <= 6.15
# - free sulfur dioxide <= 25.5
# - (free sulfur dioxide <= 25.5 AND density > 0.9954)
# - (free sulfur dioxide <= 25.5 AND total sulfur dioxide > 158.5)
# - (pH > 3.395 AND alcohol <= 10.65)
# - total sulfur dioxide > 158.5
# - sulphates <= 0.445
#
# ================================================================================
# Instance 1
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.882
# Prediction Interval: [0.875, 0.935]
#
# Alternatives to increase the calibrated probability for class 1:
# - If free sulfur dioxide 25.5 < free sulfur dioxide <= 90                 then 0.925 [0.923, 0.945]
# - If alcohol > 12.55                                                      then 0.925 [0.923, 0.945]
# - If fixed acidity <= 6.85                                                then 0.921 [0.919, 0.935]
# - If pH > 3.005                                                           then 0.921 [0.919, 0.935]
# - If volatile acidity <= 0.1875                                           then 0.921 [0.919, 0.935]
#
# Alternatives to decrease the calibrated probability for class 1:
# - If (0.0295 < chlorides <= 0.1255 AND alcohol <= 11.75)                  then 0.123 [0.111, 0.125]
# - If (0.0295 < chlorides <= 0.1255 AND pH <= 2.805)                       then 0.382 [0.364, 0.394]
# - If chlorides 0.0295 < chlorides <= 0.1255                               then 0.404 [0.391, 0.413]
# - If (0.0295 < chlorides <= 0.1255 AND 0.9923 < density <= 0.9954)        then 0.404 [0.391, 0.413]
# - If (0.9923 < density <= 0.9954 AND alcohol <= 11.75)                    then 0.404 [0.391, 0.413]
# - If (citric acid <= 0.265 AND 0.0295 < chlorides <= 0.1255)              then 0.404 [0.391, 0.413]
# - If (citric acid <= 0.265 AND 0.525 < volatile acidity <= 0.755)         then 0.404 [0.391, 0.413]
# - If (citric acid <= 0.265 AND 0.9923 < density <= 0.9954)                then 0.404 [0.391, 0.413]
# - If (fixed acidity <= 6.85 AND alcohol <= 11.75)                         then 0.404 [0.391, 0.413]
# - If (free sulfur dioxide <= 17.5 AND 0.0295 < chlorides <= 0.1255)       then 0.404 [0.391, 0.413]
# - If (free sulfur dioxide <= 17.5 AND 0.9923 < density <= 0.9954)         then 0.404 [0.391, 0.413]
# - If (free sulfur dioxide <= 17.5 AND alcohol <= 11.75)                   then 0.404 [0.391, 0.413]
# - If (residual sugar <= 3.475 AND 0.0295 < chlorides <= 0.1255)           then 0.404 [0.391, 0.413]
# - If (residual sugar <= 3.475 AND 0.525 < volatile acidity <= 0.755)      then 0.404 [0.391, 0.413]
# - If (residual sugar <= 3.475 AND 0.9923 < density <= 0.9954)             then 0.404 [0.391, 0.413]
# - If (sulphates <= 0.445 AND 0.0295 < chlorides <= 0.1255)                then 0.404 [0.391, 0.413]
# - If (total sulfur dioxide <= 71.5 AND alcohol <= 11.75)                  then 0.404 [0.391, 0.413]
# - If density 0.9923 < density <= 0.9954                                   then 0.436 [0.396, 0.467]
# - If alcohol <= 11.75                                                     then 0.436 [0.396, 0.467]
# - If (free sulfur dioxide <= 17.5 AND 0.525 < volatile acidity <= 0.755)  then 0.436 [0.396, 0.467]
# - If (sulphates <= 0.445 AND 0.525 < volatile acidity <= 0.755)           then 0.436 [0.396, 0.467]
# - If (sulphates <= 0.445 AND alcohol <= 11.75)                            then 0.436 [0.396, 0.467]
# - If (total sulfur dioxide <= 71.5 AND 0.525 < volatile acidity <= 0.755) then 0.436 [0.396, 0.467]
# - If (citric acid <= 0.265 AND alcohol <= 11.75)                          then 0.455 [0.400, 0.500] [[!] uncertain]
# - If (pH <= 2.805 AND alcohol <= 11.75)                                   then 0.455 [0.400, 0.500] [[!] uncertain]
# - If (residual sugar <= 3.475 AND alcohol <= 11.75)                       then 0.455 [0.400, 0.500] [[!] uncertain]
# - If volatile acidity 0.525 < volatile acidity <= 0.755                   then 0.567 [0.545, 0.595]
# - If (sulphates <= 0.445 AND 0.9923 < density <= 0.9954)                  then 0.567 [0.545, 0.595]
# - If (total sulfur dioxide <= 71.5 AND 0.9923 < density <= 0.9954)        then 0.567 [0.545, 0.595]
# - If (volatile acidity <= 0.1875 AND alcohol <= 11.75)                    then 0.567 [0.545, 0.595]
# - If (citric acid <= 0.265 AND pH <= 2.805)                               then 0.581 [0.571, 0.595]
# - If (fixed acidity <= 6.85 AND 0.0295 < chlorides <= 0.1255)             then 0.581 [0.571, 0.595]
# - If (fixed acidity <= 6.85 AND 0.525 < volatile acidity <= 0.755)        then 0.581 [0.571, 0.595]
# - If (fixed acidity <= 6.85 AND 0.9923 < density <= 0.9954)               then 0.581 [0.571, 0.595]
# - If (free sulfur dioxide <= 17.5 AND pH <= 2.805)                        then 0.581 [0.571, 0.595]
# - If pH <= 2.805                                                          then 0.581 [0.571, 0.595]
# - If (residual sugar <= 3.475 AND pH <= 2.805)                            then 0.581 [0.571, 0.595]
# - If (sulphates <= 0.445 AND pH <= 2.805)                                 then 0.581 [0.571, 0.595]
# - If (total sulfur dioxide <= 71.5 AND 0.0295 < chlorides <= 0.1255)      then 0.581 [0.571, 0.595]
# - If (volatile acidity <= 0.1875 AND 0.0295 < chlorides <= 0.1255)        then 0.581 [0.571, 0.595]
# - If (volatile acidity <= 0.1875 AND 0.9923 < density <= 0.9954)          then 0.581 [0.571, 0.595]
# - If (volatile acidity <= 0.1875 AND pH <= 2.805)                         then 0.581 [0.571, 0.595]
# - If citric acid 0.405 < citric acid <= 0.685                             then 0.595 [0.574, 0.625]
# - If (fixed acidity <= 6.85 AND pH <= 2.805)                              then 0.595 [0.574, 0.625]
# - If fixed acidity 9.1 < fixed acidity <= 11.3                            then 0.625 [0.609, 0.653]
# - If free sulfur dioxide <= 17.5                                          then 0.625 [0.609, 0.653]
# - If total sulfur dioxide 101.5 < total sulfur dioxide <= 228.5           then 0.629 [0.615, 0.653]
# - If citric acid <= 0.265                                                 then 0.629 [0.615, 0.653]
# - If residual sugar <= 3.475                                              then 0.629 [0.615, 0.653]
# - If sulphates <= 0.445                                                   then 0.645 [0.633, 0.667]
# - If total sulfur dioxide <= 71.5                                         then 0.645 [0.633, 0.667]
# - If sulphates 0.625 < sulphates <= 0.835                                 then 0.700 [0.684, 0.737]
#
# Alternative Explanation (Beginner):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.882
#
# Alternatives to increase the calibrated probability for class 1:
# - free sulfur dioxide 25.5 < free sulfur dioxide <= 90
# - alcohol > 12.55
# - fixed acidity <= 6.85
# - pH > 3.005
# - volatile acidity <= 0.1875
#
# Alternatives to decrease the calibrated probability for class 1:
# - (0.0295 < chlorides <= 0.1255 AND alcohol <= 11.75)
# - (0.0295 < chlorides <= 0.1255 AND pH <= 2.805)
# - chlorides 0.0295 < chlorides <= 0.1255
# - (0.0295 < chlorides <= 0.1255 AND 0.9923 < density <= 0.9954)
# - (0.9923 < density <= 0.9954 AND alcohol <= 11.75)
# - (citric acid <= 0.265 AND 0.0295 < chlorides <= 0.1255)
# - (citric acid <= 0.265 AND 0.525 < volatile acidity <= 0.755)
# - (citric acid <= 0.265 AND 0.9923 < density <= 0.9954)
# - (fixed acidity <= 6.85 AND alcohol <= 11.75)
# - (free sulfur dioxide <= 17.5 AND 0.0295 < chlorides <= 0.1255)
# - (free sulfur dioxide <= 17.5 AND 0.9923 < density <= 0.9954)
# - (free sulfur dioxide <= 17.5 AND alcohol <= 11.75)
# - (residual sugar <= 3.475 AND 0.0295 < chlorides <= 0.1255)
# - (residual sugar <= 3.475 AND 0.525 < volatile acidity <= 0.755)
# - (residual sugar <= 3.475 AND 0.9923 < density <= 0.9954)
# - (sulphates <= 0.445 AND 0.0295 < chlorides <= 0.1255)
# - (total sulfur dioxide <= 71.5 AND alcohol <= 11.75)
# - density 0.9923 < density <= 0.9954
# - alcohol <= 11.75
# - (free sulfur dioxide <= 17.5 AND 0.525 < volatile acidity <= 0.755)
# - (sulphates <= 0.445 AND 0.525 < volatile acidity <= 0.755)
# - (sulphates <= 0.445 AND alcohol <= 11.75)
# - (total sulfur dioxide <= 71.5 AND 0.525 < volatile acidity <= 0.755)
# - (citric acid <= 0.265 AND alcohol <= 11.75) [[!] uncertain]
# - (pH <= 2.805 AND alcohol <= 11.75) [[!] uncertain]
# - (residual sugar <= 3.475 AND alcohol <= 11.75) [[!] uncertain]
# - volatile acidity 0.525 < volatile acidity <= 0.755
# - (sulphates <= 0.445 AND 0.9923 < density <= 0.9954)
# - (total sulfur dioxide <= 71.5 AND 0.9923 < density <= 0.9954)
# - (volatile acidity <= 0.1875 AND alcohol <= 11.75)
# - (citric acid <= 0.265 AND pH <= 2.805)
# - (fixed acidity <= 6.85 AND 0.0295 < chlorides <= 0.1255)
# - (fixed acidity <= 6.85 AND 0.525 < volatile acidity <= 0.755)
# - (fixed acidity <= 6.85 AND 0.9923 < density <= 0.9954)
# - (free sulfur dioxide <= 17.5 AND pH <= 2.805)
# - pH <= 2.805
# - (residual sugar <= 3.475 AND pH <= 2.805)
# - (sulphates <= 0.445 AND pH <= 2.805)
# - (total sulfur dioxide <= 71.5 AND 0.0295 < chlorides <= 0.1255)
# - (volatile acidity <= 0.1875 AND 0.0295 < chlorides <= 0.1255)
# - (volatile acidity <= 0.1875 AND 0.9923 < density <= 0.9954)
# - (volatile acidity <= 0.1875 AND pH <= 2.805)
# - citric acid 0.405 < citric acid <= 0.685
# - (fixed acidity <= 6.85 AND pH <= 2.805)
# - fixed acidity 9.1 < fixed acidity <= 11.3
# - free sulfur dioxide <= 17.5
# - total sulfur dioxide 101.5 < total sulfur dioxide <= 228.5
# - citric acid <= 0.265
# - residual sugar <= 3.475
# - sulphates <= 0.445
# - total sulfur dioxide <= 71.5
# - sulphates 0.625 < sulphates <= 0.835

# %% [markdown]
# `calibrated_explanations` supports multiclass which is demonstrated in [demo_multiclass](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_multiclass.ipynb). That notebook also demonstrates how both feature names and target and categorical labels can be added to improve the interpretability.
# ## Regression
# Extracting explanations for regression is very similar to how it is done for classification. First we load and divide the dataset. The target is divided by 1000, meaning that the target is in thousands of dollars.

# %%
dataset = fetch_openml(name="house_sales", version=3)

X = dataset.data.values.astype(float)
y = dataset.target.values / 1000
y_filter = y < 500
X = X[y_filter, :]
y = y[y_filter]

feature_names = dataset.feature_names
categorical_labels = {5: {0: "False", 1: "True"}}

x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=2, random_state=42, stratify=X[:, 5]
)

X_prop_train, x_cal, y_prop_train, y_cal = train_test_split(
    x_train, y_train, random_state=42, test_size=500, stratify=x_train[:, 5]
)

# %% [markdown]
# We now create our wrapper object, using a `RandomForestRegressor` as learner.

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = WrapCalibratedExplainer(RandomForestRegressor())
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=False, calibrated=False)

# %% [markdown]
# We now fit our model using the proper training set.

# %%
regressor.fit(X_prop_train, y_prop_train)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=False)

# %% [markdown]
# The `WrapCalibratedExplainer` class has a `predict` method that returns the predictions and probability estimates of the underlying classifier. If the model is not yet calibrated, then the underlying models `predict` method is used. If the model is calibrated, then the `predict` method of the calibration model is used.

# %%
prediction = regressor.predict(x_test)
print(f"Uncalibrated model prediction: \n{prediction}")
# Out:
# Uncalibrated model prediction:
# [297.6925  409.47365]
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_3068\1346691177.py:1: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated predictions.
#   prediction = regressor.predict(x_test)

# %% [markdown]
# Before we can generate explanations, we need to calibrate our model using the calibration set.

# %%
regressor.calibrate(
    x_cal, y_cal, feature_names=feature_names, categorical_labels=categorical_labels
)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, learner=RandomForestRegressor(), difficulty_estimator=None))

# %% [markdown]
# We can easily add a difficulty estimator by assigning a `DifficultyEstimator` to the `difficulty_estimator` attribute when calibrating the model.

# %%
from crepes.extras import DifficultyEstimator

de = DifficultyEstimator().fit(X=X_prop_train, learner=regressor.learner, scaler=True)
regressor.calibrate(
    x_cal,
    y_cal,
    feature_names=feature_names,
    difficulty_estimator=de,
    categorical_labels=categorical_labels,
)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# Once the model is calibrated, the `predict`  method produce calibrated predictions with uncertainties. The default confidence is 90 per cent, which can be altered using the `low_high_percentiles` parameter.

# %%
prediction, (low, high) = regressor.predict(
    x_test, uq_interval=True
)  # default low_high_percentiles=(5, 95)
print(f"Calibrated prediction: \n{prediction}")
print("Calibrated uncertainty interval:")
print([(low[i], high[i]) for i in range(len(low))])
# Out:
# Calibrated prediction:
# [298.75653818 410.4523973 ]
# Calibrated uncertainty interval:
# [(np.float64(260.22571126831053), np.float64(324.5453393172664)), (np.float64(375.0101137442372), np.float64(434.17402685930733))]

# %% [markdown]
# You can also get the probability of the prediction being below a certain threshold using `predict_proba` by assigning the `threshold` parameter.

# %%
import numpy as np

prediction = regressor.predict(x_test, threshold=200)
print("Calibrated probabilistic prediction:")
print(prediction)

proba, (low, high) = regressor.predict_proba(x_test, uq_interval=True, threshold=200)
print("Calibrated probabilistic probability estimate [y_hat > threshold, y_hat <= threshold]:")
print(proba)
print(
    "Calibrated probabilistic uncertainty interval for y_hat <= threshold ([lower_bound, upper_bound]):"
)
print(np.array([(low[i], high[i]) for i in range(len(low))]))
# Out:
# Calibrated probabilistic prediction:
# ['y_hat > 200', 'y_hat > 200']
# Calibrated probabilistic probability estimate [y_hat > threshold, y_hat <= threshold]:
# [[0.98780488 0.01219512]
#  [0.99056604 0.00943396]]
# Calibrated probabilistic uncertainty interval for y_hat <= threshold ([lower_bound, upper_bound]):
# [[0.         0.01234568]
#  [0.         0.00952381]]

# %% [markdown]
# #### Factual Explanations
# Let us explain a test instance using our `WrapCalibratedExplainer` object. The method used to get factual explanations is `explain_factual` with `guarded_options=GuardedOptions()`.

# %%
factual_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions())
from calibrated_explanations.ce_agent_utils import print_guarded_audit_table

guarded_audit = factual_explanations.get_guarded_audit()
print_guarded_audit_table(guarded_audit, max_rows=20)
display(regressor)
# Out:
# Guarded Audit Summary
# instances=2 tested=260 conforming=236 removed_guard=24 emitted=35
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 bedrooms           (-inf, 1.5]                 0.5  Y    N    N   design_excluded
#    0    0 bedrooms           (1.5, 2.5]                0.878  Y    N    N   design_excluded
#    0    0 bedrooms           (2.5, 3.5]                0.986  Y    Y    N   emitted
#    0    0 bedrooms           (3.5, 4.5]                 0.95  Y    N    N   design_excluded
#    0    0 bedrooms           (4.5, 5.5]                0.692  Y    N    N   design_excluded
#    0    0 bedrooms           (5.5, inf]                 0.37  Y    N    N   design_excluded
#    0    1 bathrooms          (-inf, 0.875]              0.77  Y    N    N   design_excluded
#    0    1 bathrooms          (0.875, 1.25]             0.886  Y    N    N   design_excluded
#    0    1 bathrooms          (1.25, 1.625]              0.98  Y    N    N   design_excluded
#    0    1 bathrooms          (1.625, 1.875]            0.986  Y    N    N   design_excluded
#    0    1 bathrooms          (1.875, 2.375]             0.99  Y    Y    N   emitted
#    0    1 bathrooms          (2.375, inf]              0.956  Y    N    N   design_excluded
#    0    2 sqft_living        (-inf, 680]               0.854  Y    N    N   design_excluded
#    0    2 sqft_living        (680, 710]                0.892  Y    N    N   design_excluded
#    0    2 sqft_living        (710, 1145]               0.956  Y    N    N   design_excluded
#    0    2 sqft_living        (1145, 1205]              0.984  Y    N    N   design_excluded
#    0    2 sqft_living        (1205, 1447]              0.986  Y    N    N   design_excluded
#    0    2 sqft_living        (1447, 2283]               0.98  Y    Y    N   emitted
#    0    2 sqft_living        (2283, 2990]              0.886  Y    N    N   design_excluded
#    0    2 sqft_living        (2990, inf]                 0.5  Y    N    N   design_excluded
# ... truncated 240 row(s)
# reason_counts: emitted=35, removed_guard=24, design_excluded=194, zero_impact=7
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# #### Merge adjacent conforming bins
# By default, guarded explanations keep each bin as a separate rule.  Passing `GuardedOptions(merge_adjacent=True)` allows adjacent conforming bins to be collapsed into a single wider rule.  The merged rule is re-tested by the guard; if the re-test fails, the original bins are kept.  The `mrg` column in the audit table shows which emitted rules came from a merge.

# %%
merged_factual = regressor.explain_factual(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
merged_audit = merged_factual.get_guarded_audit()
print_guarded_audit_table(merged_audit, max_rows=30)
# Out:
# Guarded Audit Summary
# instances=2 tested=66 conforming=42 removed_guard=24 emitted=28
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 bedrooms           (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0    1 bathrooms          (-inf, inf]                0.99  Y    Y    Y   emitted
#    0    2 sqft_living        (-inf, inf]                0.98  Y    Y    Y   emitted
#    0    3 sqft_lot           (-inf, inf]               0.986  Y    Y    Y   emitted
#    0    4 floors             (-inf, 2.75]              0.986  Y    N    Y   zero_impact
#    0    4 floors             (2.75, inf]               0.098  N    N    N   removed_guard
#    0    5 waterfront         (-inf, inf]               0.986  Y    N    N   zero_impact
#    0    5 waterfront         (-inf, inf]               0.004  N    N    N   removed_guard
#    0    6 view               (-inf, 2.5]               0.986  Y    N    N   zero_impact
#    0    6 view               (2.5, 3.5]                0.078  N    N    N   removed_guard
#    0    6 view               (3.5, inf]                0.042  N    N    N   removed_guard
#    0    7 condition          (-inf, inf]               0.846  Y    Y    Y   emitted
#    0    8 grade              (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0    9 sqft_above         (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   10 sqft_basement      (-inf, inf]               0.996  Y    Y    Y   emitted
#    0   11 yr_built           (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   12 yr_renovated       (-inf, 976.5]             0.986  Y    N    N   zero_impact
#    0   12 yr_renovated       (976.5, 1960.5]           0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1960.5, 1972.5]          0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1972.5, 1988]            0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1988, 1992]              0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1992, 2003.5]            0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (2003.5, inf]             0.038  N    N    N   removed_guard
#    0   13 zipcode            (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   14 lat                (-inf, inf]                0.96  Y    Y    Y   emitted
#    0   15 long               (-inf, inf]               0.976  Y    Y    Y   emitted
#    0   16 sqft_living15      (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   17 sqft_lot15         (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   18 date_year          (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0   19 date_month         (-inf, inf]               0.986  Y    Y    Y   emitted
# ... truncated 36 row(s)
# reason_counts: emitted=28, removed_guard=24, zero_impact=14
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown

# %% [markdown]
# Regression also offer both regular and uncertainty plots for factual explanations with or without conjunctive rules, in almost exactly the same way as for classification.

# %%
factual_explanations.plot()
factual_explanations.plot(uncertainty=True)

factual_explanations.add_conjunctions().plot(uncertainty=True)

# %% [markdown]
# Default, the confidence interval is set to a symmetric interval of 90% (defined as `low_high_percentiles=(5,95)`). The intervals can cover any user specified interval, including one-sided intervals. To define a one-sided upper-bounded 90% interval, set `low_high_percentiles=(-np.inf,90)`, and to define a one-sided lower-bounded 95% interval, set `low_high_percentiles=(5,np.inf)`. Percentiles can also be set to any other values in the range (0,100) (exclusive), and intervals do not have to be symmetric.

# %%
lower_bounded_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), low_high_percentiles=(5, np.inf))
asymmetric_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), low_high_percentiles=(5, 75))

# %% [markdown]
# #### Explore Alternative Explanations
# `explore_alternatives` with `guarded_options=GuardedOptions()` works exactly the same as for classification.

# %%
alternative_explanations = regressor.explore_alternatives(x_test, guarded_options=GuardedOptions())
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# Alternative plots work as for classification.

# %%
alternative_explanations.plot(rnk_metric="ensured", rnk_weight=0.9)
alternative_explanations.add_conjunctions().plot()
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(

# %% [markdown]
# ## Probabilistic Regression
# The difference between probabilistic regression and regular regression is that the former returns a probability of the prediction being below a certain threshold. This could for example be useful when the prediction is a time to an event, such as time to death or time to failure.

# %%
probabilistic_factual_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), threshold=y_test + 20)
probabilistic_factual_explanations.plot()
probabilistic_factual_explanations.plot(uncertainty=True)

# %%
probabilistic_alternative_explanations = regressor.explore_alternatives(x_test, guarded_options=GuardedOptions(), threshold=y_test + 20)
probabilistic_alternative_explanations.plot()
probabilistic_alternative_explanations.plot(style="ensured")
print(probabilistic_alternative_explanations.to_narrative(expertise_level="advanced",output_format="text"))
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# ================================================================================
# Instance 0
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Calibrated Probability (target <= 310.000): 0.706
# Prediction Interval: [0.667, 0.800]
#
# Alternatives to increase the Calibrated Probability for target <= 310.000:
# - If lat 47.33 < lat <= 47.43                       then P(target <= 310.000) = 0.980 [0.980, 1.000]
# - If lat <= 47.33                                   then P(target <= 310.000) = 0.980 [0.980, 1.000]
# - If sqft_living 1145 < sqft_living <= 1205         then P(target <= 310.000) = 0.938 [0.933, 1.000]
# - If sqft_living 710 < sqft_living <= 1145          then P(target <= 310.000) = 0.938 [0.933, 1.000]
# - If sqft_living 680 < sqft_living <= 710           then P(target <= 310.000) = 0.929 [0.923, 1.000]
# - If sqft_living <= 680                             then P(target <= 310.000) = 0.900 [0.889, 1.000]
# - If long -122.4 < long <= -122.3                   then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If bathrooms 0.875 < bathrooms <= 1.25            then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If sqft_lot15 1.011e+04 < sqft_lot15 <= 1.026e+04 then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If floors 1.25 < floors <= 1.75                   then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If floors 1.75 < floors <= 2.25                   then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If sqft_lot15 1168 < sqft_lot15 <= 6030           then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If date_day 12.5 < date_day <= 13.5               then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If sqft_living15 1359 < sqft_living15 <= 1365     then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If yr_built 1944 < yr_built <= 1948               then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If yr_built 1948 < yr_built <= 1966               then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If floors 2.25 < floors <= 2.75                   then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If date_day 4.5 < date_day <= 12.5                then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If grade 4.5 < grade <= 6.5                       then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If date_month 9.5 < date_month <= 11.5            then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If bathrooms <= 0.875                             then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If date_day <= 4.5                                then P(target <= 310.000) = 0.727 [0.700, 0.800]
# - If grade <= 4.5                                   then P(target <= 310.000) = 0.727 [0.700, 0.800]
#
# Alternatives to decrease the Calibrated Probability for target <= 310.000:
# - If lat 47.57 < lat <= 47.74                       then P(target <= 310.000) = 0.051 [0.028, 0.052]
# - If lat 47.54 < lat <= 47.57                       then P(target <= 310.000) = 0.062 [0.028, 0.064]
# - If lat 47.53 < lat <= 47.54                       then P(target <= 310.000) = 0.091 [0.048, 0.095]
# - If lat > 47.74                                    then P(target <= 310.000) = 0.091 [0.048, 0.095]
# - If sqft_living 2283 < sqft_living <= 2990         then P(target <= 310.000) = 0.286 [0.250, 0.300]
# - If lat 47.52 < lat <= 47.53                       then P(target <= 310.000) = 0.286 [0.250, 0.300]
# - If sqft_living > 2990                             then P(target <= 310.000) = 0.286 [0.250, 0.300]
# - If long -122.5 < long <= -122.4                   then P(target <= 310.000) = 0.326 [0.261, 0.357]
# - If long <= -122.5                                 then P(target <= 310.000) = 0.336 [0.294, 0.357]
# - If sqft_above 1535 < sqft_above <= 2125           then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If sqft_above 2125 < sqft_above <= 2365           then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If sqft_above 2365 < sqft_above <= 3000           then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If sqft_above 3000 < sqft_above <= 3186           then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If grade 8.5 < grade <= 9.5                       then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If grade > 9.5                                    then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If sqft_above > 3186                              then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If sqft_lot > 1.491e+04                           then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If sqft_lot15 > 1.512e+04                         then P(target <= 310.000) = 0.618 [0.600, 0.647]
# - If zipcode 9.801e+04 < zipcode <= 9.802e+04       then P(target <= 310.000) = 0.625 [0.600, 0.667]
# - If zipcode 9.802e+04 < zipcode <= 9.803e+04       then P(target <= 310.000) = 0.625 [0.600, 0.667]
# - If zipcode 9.8e+04 < zipcode <= 9.801e+04         then P(target <= 310.000) = 0.625 [0.600, 0.667]
# - If zipcode 9.8e+04 < zipcode <= 9.8e+04           then P(target <= 310.000) = 0.625 [0.600, 0.667]
# - If zipcode 9.8e+04 < zipcode <= 9.8e+04           then P(target <= 310.000) = 0.625 [0.600, 0.667]
# - If zipcode <= 9.8e+04                             then P(target <= 310.000) = 0.625 [0.600, 0.667]
# - If long -121.9 < long <= -121.8                   then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If long -122.1 < long <= -121.9                   then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If sqft_lot 1.076e+04 < sqft_lot <= 1.491e+04     then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If date_month 2.5 < date_month <= 7.5             then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If sqft_living15 2305 < sqft_living15 <= 2765     then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If bedrooms 4.5 < bedrooms <= 5.5                 then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If grade 7.5 < grade <= 8.5                       then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If bedrooms > 5.5                                 then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If condition > 4.5                                then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If date_day > 29.5                                then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If date_month <= 2.5                              then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If date_year > 2014                               then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If long > -121.8                                  then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If sqft_living15 > 2765                           then P(target <= 310.000) = 0.634 [0.615, 0.667]
# - If long -122.2 < long <= -122.1                   then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If bedrooms 1.5 < bedrooms <= 2.5                 then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If bathrooms 1.625 < bathrooms <= 1.875           then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If yr_built 1998 < yr_built <= 2000               then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If condition 2.5 < condition <= 3.5               then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If yr_built 2000 < yr_built <= 2004               then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If sqft_lot 3266 < sqft_lot <= 3605               then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If sqft_lot 3605 < sqft_lot <= 3621               then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If sqft_lot 3621 < sqft_lot <= 4082               then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If sqft_lot 4082 < sqft_lot <= 4161               then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If bedrooms <= 1.5                                then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If condition <= 2.5                               then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If sqft_lot15 <= 1168                             then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If yr_built > 2004                                then P(target <= 310.000) = 0.636 [0.618, 0.667]
# - If sqft_lot15 1.026e+04 < sqft_lot15 <= 1.512e+04 then P(target <= 310.000) = 0.677 [0.618, 0.800]
# - If bathrooms 1.25 < bathrooms <= 1.625            then P(target <= 310.000) = 0.677 [0.618, 0.800]
# - If date_day 27.5 < date_day <= 29.5               then P(target <= 310.000) = 0.677 [0.618, 0.800]
# - If sqft_basement <= 135                           then P(target <= 310.000) = 0.677 [0.618, 0.800]
# - If sqft_basement 665 < sqft_basement <= 965       then P(target <= 310.000) = 0.683 [0.629, 0.800]
# - If sqft_basement 965 < sqft_basement <= 995       then P(target <= 310.000) = 0.683 [0.629, 0.800]
# - If sqft_basement > 995                            then P(target <= 310.000) = 0.683 [0.629, 0.800]
#
# ================================================================================
# Instance 1
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Calibrated Probability (target <= 417.500): 0.620
# Prediction Interval: [0.591, 0.667]
#
# Alternatives to increase the Calibrated Probability for target <= 417.500:
# - If lat 47.33 < lat <= 47.43                       then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat 47.43 < lat <= 47.52                       then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat <= 47.33                                   then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If sqft_living 1145 < sqft_living <= 1205         then P(target <= 417.500) = 0.938 [0.933, 1.000]
# - If lat > 47.74                                    then P(target <= 417.500) = 0.923 [0.917, 1.000]
# - If long -121.9 < long <= -121.8                   then P(target <= 417.500) = 0.731 [0.720, 0.760]
# - If yr_built 1998 < yr_built <= 2000               then P(target <= 417.500) = 0.731 [0.720, 0.760]
# - If yr_built 2000 < yr_built <= 2004               then P(target <= 417.500) = 0.731 [0.720, 0.760]
# - If lat 47.54 < lat <= 47.57                       then P(target <= 417.500) = 0.731 [0.720, 0.760]
# - If sqft_living 680 < sqft_living <= 710           then P(target <= 417.500) = 0.731 [0.720, 0.760]
# - If sqft_living 710 < sqft_living <= 1145          then P(target <= 417.500) = 0.731 [0.720, 0.760]
# - If long > -121.8                                  then P(target <= 417.500) = 0.731 [0.720, 0.760]
# - If sqft_living <= 680                             then P(target <= 417.500) = 0.731 [0.720, 0.760]
# - If yr_built 1966 < yr_built <= 1998               then P(target <= 417.500) = 0.660 [0.609, 0.760]
# - If date_month 9.5 < date_month <= 11.5            then P(target <= 417.500) = 0.660 [0.609, 0.760]
# - If condition <= 2.5                               then P(target <= 417.500) = 0.660 [0.609, 0.760]
#
# Alternatives to decrease the Calibrated Probability for target <= 417.500:
# - If long -122.3 < long <= -122.2                   then P(target <= 417.500) = 0.529 [0.500, 0.562] [[!] uncertain]
# - If long -122.5 < long <= -122.4                   then P(target <= 417.500) = 0.529 [0.500, 0.562] [[!] uncertain]
# - If sqft_living 2283 < sqft_living <= 2990         then P(target <= 417.500) = 0.529 [0.500, 0.562] [[!] uncertain]
# - If long <= -122.5                                 then P(target <= 417.500) = 0.529 [0.500, 0.562] [[!] uncertain]
# - If sqft_living > 2990                             then P(target <= 417.500) = 0.529 [0.500, 0.562] [[!] uncertain]
# - If long -122.2 < long <= -122.1                   then P(target <= 417.500) = 0.533 [0.500, 0.571] [[!] uncertain]
# - If sqft_lot15 1.011e+04 < sqft_lot15 <= 1.026e+04 then P(target <= 417.500) = 0.537 [0.500, 0.579] [[!] uncertain]
# - If sqft_lot15 6044 < sqft_lot15 <= 1.011e+04      then P(target <= 417.500) = 0.537 [0.500, 0.579] [[!] uncertain]
# - If long -122.1 < long <= -121.9                   then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot 1.076e+04 < sqft_lot <= 1.491e+04     then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_living 1447 < sqft_living <= 2283         then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot 3266 < sqft_lot <= 3605               then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot 3605 < sqft_lot <= 3621               then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot 3621 < sqft_lot <= 4082               then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot 4082 < sqft_lot <= 4161               then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot 4161 < sqft_lot <= 1.076e+04          then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot15 6030 < sqft_lot15 <= 6044           then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot > 1.491e+04                           then P(target <= 417.500) = 0.553 [0.524, 0.588]
# - If sqft_lot15 1.026e+04 < sqft_lot15 <= 1.512e+04 then P(target <= 417.500) = 0.557 [0.531, 0.588]
# - If sqft_lot15 > 1.512e+04                         then P(target <= 417.500) = 0.557 [0.531, 0.588]
# - If bathrooms 0.875 < bathrooms <= 1.25            then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If bathrooms 1.25 < bathrooms <= 1.625            then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If bedrooms 1.5 < bedrooms <= 2.5                 then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If bathrooms 1.625 < bathrooms <= 1.875           then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_living15 1035 < sqft_living15 <= 1359     then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If date_day 13.5 < date_day <= 22.5               then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_basement 135 < sqft_basement <= 155       then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_living15 1359 < sqft_living15 <= 1365     then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_living15 1475 < sqft_living15 <= 2305     then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_above 1535 < sqft_above <= 2125           then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_basement 155 < sqft_basement <= 165       then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_basement 165 < sqft_basement <= 245       then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If yr_built 1944 < yr_built <= 1948               then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If date_month 2.5 < date_month <= 7.5             then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_above 2125 < sqft_above <= 2365           then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If date_day 22.5 < date_day <= 27.5               then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_living15 2305 < sqft_living15 <= 2765     then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_above 2365 < sqft_above <= 3000           then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_basement 245 < sqft_basement <= 665       then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If date_day 27.5 < date_day <= 29.5               then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If bedrooms 3.5 < bedrooms <= 4.5                 then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If condition 3.5 < condition <= 4.5               then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_above 3000 < sqft_above <= 3186           then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If bedrooms 4.5 < bedrooms <= 5.5                 then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If grade 4.5 < grade <= 6.5                       then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If grade 6.5 < grade <= 7.5                       then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_basement 665 < sqft_basement <= 965       then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_above 765 < sqft_above <= 1135            then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_living15 840 < sqft_living15 <= 1035      then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_basement 965 < sqft_basement <= 995       then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If bathrooms <= 0.875                             then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If bathrooms > 2.375                              then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If bedrooms <= 1.5                                then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If condition > 4.5                                then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If date_day > 29.5                                then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If date_month <= 2.5                              then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If date_month > 11.5                              then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If grade <= 4.5                                   then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_above <= 765                              then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_living15 <= 840                           then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_living15 > 2765                           then P(target <= 417.500) = 0.609 [0.591, 0.636]
# - If sqft_lot15 <= 1168                             then P(target <= 417.500) = 0.609 [0.591, 0.636]

# %% [markdown]
# Regression offers many more options but to learn more about them, see the [demo_regression](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_regression.ipynb) or the [demo_probabilistic_regression](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_probabilistic_regression.ipynb) notebooks.
#
# A `WrapCalibratedExplainer` can also be initialized with a trained model or with a `WrapCalibratedExplainer` object, as is examplified below. We use the `learner` and `explainer` from the previously initialized `classifier` and `regressor` instances, as we know that these are fitted and calibrated.

# %%
new_classifier = WrapCalibratedExplainer(classifier.learner)
display(new_classifier)
new_classifier_explainer = WrapCalibratedExplainer(classifier.explainer)
display(new_classifier_explainer)

new_regressor = WrapCalibratedExplainer(regressor.learner)
display(new_regressor)
new_regressor_explainer = WrapCalibratedExplainer(regressor.explainer)
display(new_regressor_explainer)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=False)
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=False)
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# When a calibrated explainer is re-fitted, the explainer is reinitialized.
