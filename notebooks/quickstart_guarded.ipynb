# %% [markdown]
# ## Learning objectives
# - Learn how to use `WrapCalibratedExplainer` to wrap a model and produce calibrated predictions;
# - Generate factual and alternative explanations and plot uncertainty;
# - Understand when OOB vs explicit calibration is appropriate.
#
# ## Time to run
# ~2–10 min depending on dataset and environment (use smaller datasets for a faster run).

# %% [markdown]
# # Getting started with calibrated-explanations - using the WrapCalibratedExplainer class
# Author: Tuwe Löfström (tuwe.lofstrom@ju.se)
# Copyright 2023 Tuwe Löfström
# License: BSD 3 clause
# ## Classification
# Let us illustrate how we may use `calibrated_explanations` to generate explanations from a classifier trained on a dataset from
# [www.openml.org](https://www.openml.org), which we first split into a
# training and a test set using `train_test_split` from
# [sklearn](https://scikit-learn.org), and then further split the
# training set into a proper training set and a calibration set:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

dataset = fetch_openml(name="wine", version=7, as_frame=True, parser="auto")

X = dataset.data.values.astype(float)
y = (dataset.target.values == "True").astype(int)

feature_names = dataset.feature_names

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=2, stratify=y)

X_prop_train, x_cal, y_prop_train, y_cal = train_test_split(x_train, y_train, test_size=0.25)

# %% [markdown]
# We now create our wrapper object, using a `RandomForestClassifier` as learner.

# %%
from sklearn.ensemble import RandomForestClassifier

from calibrated_explanations import WrapCalibratedExplainer, __version__

print(f"calibrated_explanations {__version__}")

classifier = WrapCalibratedExplainer(RandomForestClassifier())
display(classifier)
# Out:
# calibrated_explanations v0.11.5
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=False, calibrated=False)

# %% [markdown]
# We now fit our model using the proper training set.

# %%
classifier.fit(X_prop_train, y_prop_train)
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=False)

# %% [markdown]
# The `WrapCalibratedExplainer` class has a `predict` and a `predict_proba` method that returns the predictions and probability estimates of the underlying classifier. If the model is not yet calibrated, then the underlying models `predict` and `predict_proba` methods are used. If the model is calibrated, then the `predict` and `predict_proba` method of the calibration model is used.

# %%
prediction = classifier.predict(x_test)
proba = classifier.predict_proba(x_test)
print("Uncalibrated prediction (probability estimates):")
print(f"{prediction} ({proba})")
# Out:
# Uncalibrated prediction (probability estimates):
# [0 0] ([[0.54 0.46]
#  [0.63 0.37]])
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_2868\1092592062.py:1: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated predictions.
#   prediction = classifier.predict(x_test)
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_2868\1092592062.py:2: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated probabilities.
#   proba = classifier.predict_proba(x_test)

# %% [markdown]
# Before we can generate explanations, we need to calibrate our model using the calibration set.

# %%
classifier.calibrate(x_cal, y_cal, feature_names=feature_names)
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, learner=RandomForestClassifier()))

# %% [markdown]
# Once the model is calibrated, the `predict` and `predict_proba` methods produce calibrated predictions and probability estimates.

# %%
prediction = classifier.predict(x_test)
proba, (low, high) = classifier.predict_proba(x_test, uq_interval=True)
print("Calibrated prediction (probability estimates):")
print(f"{prediction} ({proba})")
print("Calibrated uncertainty interval for the positive class:")
print([(low[i], high[i]) for i in range(len(low))])
# Out:
# Calibrated prediction (probability estimates):
# ['0' '0'] ([[0.67924528 0.32075472]
#  [0.72941176 0.27058824]])
# Calibrated uncertainty interval for the positive class:
# [(np.float64(0.29411764705882354), np.float64(0.3333333333333333)), (np.float64(0.2619047619047619), np.float64(0.27380952380952384))]

# %% [markdown]
# #### Factual Explanations
# Let us explain a test instance using our `WrapCalibratedExplainer` object. The method used to get factual explanations is `explain_factual` with `guarded_options=GuardedOptions()`.

# %%
from calibrated_explanations import GuardedOptions

factual_explanations = classifier.explain_factual(x_test, guarded_options=GuardedOptions())
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %%
from calibrated_explanations.ce_agent_utils import print_guarded_audit_table

guarded_audit = factual_explanations.get_guarded_audit()
print_guarded_audit_table(guarded_audit, max_rows=20)
display(classifier)
# Out:
# Guarded Audit Summary
# instances=2 tested=160 conforming=124 removed_guard=36 emitted=19
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 fixed acidity      (-inf, 5.75]             0.2398  Y    Y    N   emitted
#    0    0 fixed acidity      (5.75, 6.05]             0.3354  Y    N    N   design_excluded
#    0    0 fixed acidity      (6.05, 7.15]              0.395  Y    N    N   design_excluded
#    0    0 fixed acidity      (7.15, 7.45]             0.3542  Y    N    N   design_excluded
#    0    0 fixed acidity      (7.45, 11.75]            0.2633  Y    N    N   design_excluded
#    0    0 fixed acidity      (11.75, 13.35]           0.0172  N    N    N   removed_guard
#    0    0 fixed acidity      (13.35, inf]             0.0078  N    N    N   removed_guard
#    0    1 volatile acidity   (-inf, 0.125]            0.3182  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.125, 0.225]           0.3103  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.225, 0.475]           0.1928  Y    Y    N   emitted
#    0    1 volatile acidity   (0.475, 0.585]           0.0721  N    N    N   removed_guard
#    0    1 volatile acidity   (0.585, 0.6075]          0.0392  N    N    N   removed_guard
#    0    1 volatile acidity   (0.6075, 0.665]          0.0282  N    N    N   removed_guard
#    0    1 volatile acidity   (0.665, inf]              0.011  N    N    N   removed_guard
#    0    2 citric acid        (-inf, 0.025]            0.0611  N    N    N   removed_guard
#    0    2 citric acid        (0.025, 0.035]           0.0862  N    N    N   removed_guard
#    0    2 citric acid        (0.035, 0.085]           0.1207  Y    N    N   design_excluded
#    0    2 citric acid        (0.085, 0.235]           0.2398  Y    N    N   design_excluded
#    0    2 citric acid        (0.235, 0.265]           0.4091  Y    N    N   design_excluded
#    0    2 citric acid        (0.265, 0.445]           0.4185  Y    N    N   design_excluded
# ... truncated 140 row(s)
# reason_counts: emitted=19, removed_guard=36, design_excluded=102, zero_impact=3
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %% [markdown]
# #### Merge adjacent conforming bins
# Passing `merge_adjacent=True` collapses adjacent conforming bins into wider rules (re-tested by the guard).  Rows with `mrg=Y` in the audit table came from a merge; the displayed interval shows the emitted bounds.

# %%
merged_factual_cls = classifier.explain_factual(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
merged_audit_cls = merged_factual_cls.get_guarded_audit()
print_guarded_audit_table(merged_audit_cls, max_rows=30)
# Out:
# Guarded Audit Summary
# instances=2 tested=58 conforming=22 removed_guard=36 emitted=12
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 fixed acidity      (-inf, 11.75]            0.4169  Y    Y    Y   emitted
#    0    0 fixed acidity      (11.75, 13.35]           0.0172  N    N    N   removed_guard
#    0    0 fixed acidity      (13.35, inf]             0.0078  N    N    N   removed_guard
#    0    1 volatile acidity   (-inf, 0.475]            0.2273  Y    Y    Y   emitted
#    0    1 volatile acidity   (0.475, 0.585]           0.0721  N    N    N   removed_guard
#    0    1 volatile acidity   (0.585, 0.6075]          0.0392  N    N    N   removed_guard
#    0    1 volatile acidity   (0.6075, 0.665]          0.0282  N    N    N   removed_guard
#    0    1 volatile acidity   (0.665, inf]              0.011  N    N    N   removed_guard
#    0    2 citric acid        (-inf, 0.025]            0.0611  N    N    N   removed_guard
#    0    2 citric acid        (0.025, 0.035]           0.0862  N    N    N   removed_guard
#    0    2 citric acid        (0.035, 0.735]           0.4514  Y    N    Y   zero_impact
#    0    2 citric acid        (0.735, inf]             0.0219  N    N    N   removed_guard
#    0    3 residual sugar     (-inf, 15.55]            0.1959  Y    N    Y   zero_impact
#    0    3 residual sugar     (15.55, inf]             0.0298  N    N    N   removed_guard
#    0    4 chlorides          (-inf, 0.1565]           0.1928  Y    Y    Y   emitted
#    0    4 chlorides          (0.1565, inf]            0.0078  N    N    N   removed_guard
#    0    5 free sulfur dioxid (-inf, 83.5]             0.1944  Y    Y    Y   emitted
#    0    5 free sulfur dioxid (83.5, inf]              0.0188  N    N    N   removed_guard
#    0    6 total sulfur dioxi (-inf, 28.5]             0.0549  N    N    N   removed_guard
#    0    6 total sulfur dioxi (28.5, 67.5]             0.0893  N    N    N   removed_guard
#    0    6 total sulfur dioxi (67.5, inf]              0.1912  Y    N    Y   zero_impact
#    0    7 density            (-inf, 0.9888]           0.0846  N    N    N   removed_guard
#    0    7 density            (0.9888, 0.9968]         0.1928  Y    Y    Y   emitted
#    0    7 density            (0.9968, inf]            0.0752  N    N    N   removed_guard
#    0    8 pH                 (-inf, 2.89]             0.0549  N    N    N   removed_guard
#    0    8 pH                 (2.89, 2.905]            0.0611  N    N    N   removed_guard
#    0    8 pH                 (2.905, 3.715]           0.1693  Y    Y    Y   emitted
#    0    8 pH                 (3.715, inf]             0.0408  N    N    N   removed_guard
#    0    9 sulphates          (-inf, 0.875]            0.3448  Y    Y    Y   emitted
#    0    9 sulphates          (0.875, 1.065]           0.0925  N    N    N   removed_guard
# ... truncated 28 row(s)
# reason_counts: emitted=12, removed_guard=36, zero_impact=10
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown

# %% [markdown]
# Once we have the explanations, we can plot all of them using `plot`. Default, a regular plot, without uncertainty intervals included, is created. To include uncertainty intervals, change the parameter `uncertainty=True`.

# %%
factual_explanations.plot()
factual_explanations.plot(uncertainty=True)

# %% [markdown]
# You can also add and remove conjunctive rules.

# %%
factual_explanations.add_conjunctions().plot()
factual_explanations.remove_conjunctions().plot(uncertainty=True)

# %% [markdown]
# All explanations support indexing using integer indexing, slices or boolean indexing.

# %%
factual_explanations[0].plot(uncertainty=True)
factual_explanations[:1].plot(uncertainty=True)

# %% [markdown]
# #### Explore Alternative Explanations
# An alternative to factual rules is to extract alternative rules, which is done using `explore_alternatives` with `guarded_options=GuardedOptions()`. Alternative explanations provides insights on how predicted outcomes would change if specific input features were modified, including uncertainty estimates for these alternative outcomes.

# %%
alternative_explanations = classifier.explore_alternatives(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %% [markdown]
# Alternatives are also visualized using the `plot` function. Plotting an individual alternative explanation is easiest done using indexing. Adding or removing conjunctions is done as before.

# %%
alternative_explanations.plot()
alternative_explanations.add_conjunctions().plot()
alternative_explanations.add_conjunctions().plot(style="ensured")
print(alternative_explanations.to_narrative(output_format="text"))
# Out:
# ================================================================================
# Instance 0
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.321
# Prediction Interval: [0.294, 0.333]
#
# Alternatives to increase the calibrated probability for class 1:
# - If alcohol > 10.65                                                          then 0.839 [0.836, 0.855]
# - If (0.9888 < density <= 0.9927 AND alcohol > 10.65)                         then 0.774 [0.750, 0.855]
# - If (5.75 < fixed acidity <= 11.75 AND volatile acidity <= 0.225)            then 0.725 [0.720, 0.740]
# - If (chlorides <= 0.0455 AND volatile acidity <= 0.225)                      then 0.674 [0.667, 0.690]
# - If (67.5 < total sulfur dioxide <= 135.5 AND volatile acidity <= 0.225)     then 0.633 [0.600, 0.690]
# - If volatile acidity <= 0.225                                                then 0.633 [0.600, 0.690]
# - If (2.905 < pH <= 3.075 AND alcohol > 10.65)                                then 0.571 [0.556, 0.593]
# - If fixed acidity 5.75 < fixed acidity <= 11.75                              then 0.571 [0.556, 0.593]
# - If (67.5 < total sulfur dioxide <= 135.5 AND 5.75 < fixed acidity <= 11.75) then 0.571 [0.556, 0.593]
# - If (chlorides <= 0.0455 AND 5.75 < fixed acidity <= 11.75)                  then 0.571 [0.556, 0.593]
# - If (residual sugar <= 0.95 AND volatile acidity <= 0.225)                   then 0.571 [0.556, 0.593]
# - If density 0.9888 < density <= 0.9927                                       then 0.455 [0.438, 0.469]
# - If (2.905 < pH <= 3.075 AND volatile acidity <= 0.225)                      then 0.455 [0.438, 0.469]
# - If (5.75 < fixed acidity <= 11.75 AND 0.9888 < density <= 0.9927)           then 0.455 [0.438, 0.469]
# - If (67.5 < total sulfur dioxide <= 135.5 AND 0.9888 < density <= 0.9927)    then 0.455 [0.438, 0.469]
# - If (free sulfur dioxide <= 46.5 AND 5.75 < fixed acidity <= 11.75)          then 0.455 [0.438, 0.469]
# - If (residual sugar <= 0.95 AND 5.75 < fixed acidity <= 11.75)               then 0.455 [0.438, 0.469]
# - If (volatile acidity <= 0.225 AND 0.9888 < density <= 0.9927)               then 0.455 [0.438, 0.469]
# - If sulphates 0.835 < sulphates <= 0.875                                     then 0.425 [0.385, 0.455]
# - If total sulfur dioxide 67.5 < total sulfur dioxide <= 135.5                then 0.425 [0.385, 0.455]
# - If chlorides <= 0.0455                                                      then 0.425 [0.385, 0.455]
# - If (chlorides <= 0.0455 AND 0.9888 < density <= 0.9927)                     then 0.425 [0.385, 0.455]
# - If (free sulfur dioxide <= 46.5 AND 0.9888 < density <= 0.9927)             then 0.425 [0.385, 0.455]
# - If (free sulfur dioxide <= 46.5 AND volatile acidity <= 0.225)              then 0.425 [0.385, 0.455]
# - If (residual sugar <= 0.95 AND 0.9888 < density <= 0.9927)                  then 0.425 [0.385, 0.455]
# - If (sulphates <= 0.585 AND volatile acidity <= 0.225)                       then 0.425 [0.385, 0.455]
# - If (volatile acidity <= 0.225 AND 8.75 < alcohol <= 9.95)                   then 0.425 [0.385, 0.455]
#
# Alternatives to decrease the calibrated probability for class 1:
# - If (residual sugar <= 0.95 AND 8.75 < alcohol <= 9.95)                      then 0.114 [0.088, 0.118]
# - If (sulphates <= 0.585 AND 8.75 < alcohol <= 9.95)                          then 0.159 [0.118, 0.167]
# - If (67.5 < total sulfur dioxide <= 135.5 AND 8.75 < alcohol <= 9.95)        then 0.185 [0.118, 0.200]
# - If alcohol 8.75 < alcohol <= 9.95                                           then 0.185 [0.118, 0.200]
# - If (free sulfur dioxide <= 46.5 AND 8.75 < alcohol <= 9.95)                 then 0.222 [0.125, 0.250]
# - If density 0.9953 < density <= 0.9968                                       then 0.271 [0.262, 0.274]
# - If pH 2.905 < pH <= 3.075                                                   then 0.271 [0.262, 0.274]
# - If (5.75 < fixed acidity <= 11.75 AND 8.75 < alcohol <= 9.95)               then 0.271 [0.262, 0.274]
# - If (chlorides <= 0.0455 AND 8.75 < alcohol <= 9.95)                         then 0.271 [0.262, 0.274]
# - If sulphates <= 0.585                                                       then 0.271 [0.262, 0.274]
# - If (sulphates <= 0.585 AND 0.9888 < density <= 0.9927)                      then 0.271 [0.262, 0.274]
# - If total sulfur dioxide > 177.5                                             then 0.271 [0.262, 0.274]
# - If free sulfur dioxide <= 46.5                                              then 0.308 [0.273, 0.324]
# - If residual sugar <= 0.95                                                   then 0.308 [0.273, 0.324]
#
# Alternative Explanation (Beginner):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.321
#
# Alternatives to increase the calibrated probability for class 1:
# - alcohol > 10.65
# - (0.9888 < density <= 0.9927 AND alcohol > 10.65)
# - (5.75 < fixed acidity <= 11.75 AND volatile acidity <= 0.225)
# - (chlorides <= 0.0455 AND volatile acidity <= 0.225)
# - (67.5 < total sulfur dioxide <= 135.5 AND volatile acidity <= 0.225)
# - volatile acidity <= 0.225
# - (2.905 < pH <= 3.075 AND alcohol > 10.65)
# - fixed acidity 5.75 < fixed acidity <= 11.75
# - (67.5 < total sulfur dioxide <= 135.5 AND 5.75 < fixed acidity <= 11.75)
# - (chlorides <= 0.0455 AND 5.75 < fixed acidity <= 11.75)
# - (residual sugar <= 0.95 AND volatile acidity <= 0.225)
# - density 0.9888 < density <= 0.9927
# - (2.905 < pH <= 3.075 AND volatile acidity <= 0.225)
# - (5.75 < fixed acidity <= 11.75 AND 0.9888 < density <= 0.9927)
# - (67.5 < total sulfur dioxide <= 135.5 AND 0.9888 < density <= 0.9927)
# - (free sulfur dioxide <= 46.5 AND 5.75 < fixed acidity <= 11.75)
# - (residual sugar <= 0.95 AND 5.75 < fixed acidity <= 11.75)
# - (volatile acidity <= 0.225 AND 0.9888 < density <= 0.9927)
# - sulphates 0.835 < sulphates <= 0.875
# - total sulfur dioxide 67.5 < total sulfur dioxide <= 135.5
# - chlorides <= 0.0455
# - (chlorides <= 0.0455 AND 0.9888 < density <= 0.9927)
# - (free sulfur dioxide <= 46.5 AND 0.9888 < density <= 0.9927)
# - (free sulfur dioxide <= 46.5 AND volatile acidity <= 0.225)
# - (residual sugar <= 0.95 AND 0.9888 < density <= 0.9927)
# - (sulphates <= 0.585 AND volatile acidity <= 0.225)
# - (volatile acidity <= 0.225 AND 8.75 < alcohol <= 9.95)
#
# Alternatives to decrease the calibrated probability for class 1:
# - (residual sugar <= 0.95 AND 8.75 < alcohol <= 9.95)
# - (sulphates <= 0.585 AND 8.75 < alcohol <= 9.95)
# - (67.5 < total sulfur dioxide <= 135.5 AND 8.75 < alcohol <= 9.95)
# - alcohol 8.75 < alcohol <= 9.95
# - (free sulfur dioxide <= 46.5 AND 8.75 < alcohol <= 9.95)
# - density 0.9953 < density <= 0.9968
# - pH 2.905 < pH <= 3.075
# - (5.75 < fixed acidity <= 11.75 AND 8.75 < alcohol <= 9.95)
# - (chlorides <= 0.0455 AND 8.75 < alcohol <= 9.95)
# - sulphates <= 0.585
# - (sulphates <= 0.585 AND 0.9888 < density <= 0.9927)
# - total sulfur dioxide > 177.5
# - free sulfur dioxide <= 46.5
# - residual sugar <= 0.95
#
# ================================================================================
# Instance 1
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.271
# Prediction Interval: [0.262, 0.274]
#
# Alternatives to increase the calibrated probability for class 1:
# - If (density <= 0.9921 AND alcohol > 10.65)                                then 0.725 [0.720, 0.740]
# - If alcohol > 10.65                                                        then 0.674 [0.667, 0.690]
# - If (16.5 < free sulfur dioxide <= 83.5 AND alcohol > 10.65)               then 0.571 [0.556, 0.593]
# - If (16.5 < free sulfur dioxide <= 83.5 AND 5.75 < fixed acidity <= 11.75) then 0.455 [0.438, 0.469]
# - If (5.75 < fixed acidity <= 11.75 AND alcohol > 10.65)                    then 0.455 [0.438, 0.469]
# - If (residual sugar <= 0.95 AND 5.75 < fixed acidity <= 11.75)             then 0.455 [0.438, 0.469]
# - If (residual sugar <= 0.95 AND alcohol > 10.65)                           then 0.455 [0.438, 0.469]
# - If (sulphates <= 0.325 AND alcohol > 10.65)                               then 0.455 [0.438, 0.469]
# - If sulphates 0.585 < sulphates <= 0.875                                   then 0.425 [0.385, 0.455]
# - If fixed acidity 5.75 < fixed acidity <= 11.75                            then 0.425 [0.385, 0.455]
# - If free sulfur dioxide 16.5 < free sulfur dioxide <= 83.5                 then 0.321 [0.294, 0.333]
# - If residual sugar 7.025 < residual sugar <= 12.55                         then 0.321 [0.294, 0.333]
# - If density <= 0.9921                                                      then 0.321 [0.294, 0.333]
# - If residual sugar <= 0.95                                                 then 0.321 [0.294, 0.333]
#
# Alternatives to decrease the calibrated probability for class 1:
# - If density > 0.9927                                                       then 0.125 [0.088, 0.130]
# - If sulphates <= 0.325                                                     then 0.185 [0.118, 0.200]
#
# Alternative Explanation (Beginner):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.271
#
# Alternatives to increase the calibrated probability for class 1:
# - (density <= 0.9921 AND alcohol > 10.65)
# - alcohol > 10.65
# - (16.5 < free sulfur dioxide <= 83.5 AND alcohol > 10.65)
# - (16.5 < free sulfur dioxide <= 83.5 AND 5.75 < fixed acidity <= 11.75)
# - (5.75 < fixed acidity <= 11.75 AND alcohol > 10.65)
# - (residual sugar <= 0.95 AND 5.75 < fixed acidity <= 11.75)
# - (residual sugar <= 0.95 AND alcohol > 10.65)
# - (sulphates <= 0.325 AND alcohol > 10.65)
# - sulphates 0.585 < sulphates <= 0.875
# - fixed acidity 5.75 < fixed acidity <= 11.75
# - free sulfur dioxide 16.5 < free sulfur dioxide <= 83.5
# - residual sugar 7.025 < residual sugar <= 12.55
# - density <= 0.9921
# - residual sugar <= 0.95
#
# Alternatives to decrease the calibrated probability for class 1:
# - density > 0.9927
# - sulphates <= 0.325

# %% [markdown]
# `calibrated_explanations` supports multiclass which is demonstrated in [demo_multiclass](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_multiclass.ipynb). That notebook also demonstrates how both feature names and target and categorical labels can be added to improve the interpretability.
# ## Regression
# Extracting explanations for regression is very similar to how it is done for classification. First we load and divide the dataset. The target is divided by 1000, meaning that the target is in thousands of dollars.

# %%
dataset = fetch_openml(name="house_sales", version=3)

X = dataset.data.values.astype(float)
y = dataset.target.values / 1000
y_filter = y < 500
X = X[y_filter, :]
y = y[y_filter]

feature_names = dataset.feature_names
categorical_labels = {5: {0: "False", 1: "True"}}

x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=2, random_state=42, stratify=X[:, 5]
)

X_prop_train, x_cal, y_prop_train, y_cal = train_test_split(
    x_train, y_train, random_state=42, test_size=500, stratify=x_train[:, 5]
)

# %% [markdown]
# We now create our wrapper object, using a `RandomForestRegressor` as learner.

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = WrapCalibratedExplainer(RandomForestRegressor())
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=False, calibrated=False)

# %% [markdown]
# We now fit our model using the proper training set.

# %%
regressor.fit(X_prop_train, y_prop_train)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=False)

# %% [markdown]
# The `WrapCalibratedExplainer` class has a `predict` method that returns the predictions and probability estimates of the underlying classifier. If the model is not yet calibrated, then the underlying models `predict` method is used. If the model is calibrated, then the `predict` method of the calibration model is used.

# %%
prediction = regressor.predict(x_test)
print(f"Uncalibrated model prediction: \n{prediction}")
# Out:
# Uncalibrated model prediction:
# [294.1813  410.21392]
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_2868\1346691177.py:1: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated predictions.
#   prediction = regressor.predict(x_test)

# %% [markdown]
# Before we can generate explanations, we need to calibrate our model using the calibration set.

# %%
regressor.calibrate(
    x_cal, y_cal, feature_names=feature_names, categorical_labels=categorical_labels
)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, learner=RandomForestRegressor(), difficulty_estimator=None))

# %% [markdown]
# We can easily add a difficulty estimator by assigning a `DifficultyEstimator` to the `difficulty_estimator` attribute when calibrating the model.

# %%
from crepes.extras import DifficultyEstimator

de = DifficultyEstimator().fit(X=X_prop_train, learner=regressor.learner, scaler=True)
regressor.calibrate(
    x_cal,
    y_cal,
    feature_names=feature_names,
    difficulty_estimator=de,
    categorical_labels=categorical_labels,
)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# Once the model is calibrated, the `predict`  method produce calibrated predictions with uncertainties. The default confidence is 90 per cent, which can be altered using the `low_high_percentiles` parameter.

# %%
prediction, (low, high) = regressor.predict(
    x_test, uq_interval=True
)  # default low_high_percentiles=(5, 95)
print(f"Calibrated prediction: \n{prediction}")
print("Calibrated uncertainty interval:")
print([(low[i], high[i]) for i in range(len(low))])
# Out:
# Calibrated prediction:
# [295.49293262 410.90206079]
# Calibrated uncertainty interval:
# [(np.float64(238.8679564322598), np.float64(334.02541750625153)), (np.float64(381.1940806638215), np.float64(431.1179155631536))]

# %% [markdown]
# You can also get the probability of the prediction being below a certain threshold using `predict_proba` by assigning the `threshold` parameter.

# %%
import numpy as np

prediction = regressor.predict(x_test, threshold=200)
print("Calibrated probabilistic prediction:")
print(prediction)

proba, (low, high) = regressor.predict_proba(x_test, uq_interval=True, threshold=200)
print("Calibrated probabilistic probability estimate [y_hat > threshold, y_hat <= threshold]:")
print(proba)
print(
    "Calibrated probabilistic uncertainty interval for y_hat <= threshold ([lower_bound, upper_bound]):"
)
print(np.array([(low[i], high[i]) for i in range(len(low))]))
# Out:
# Calibrated probabilistic prediction:
# ['y_hat > 200', 'y_hat > 200']
# Calibrated probabilistic probability estimate [y_hat > threshold, y_hat <= threshold]:
# [[0.97619048 0.02380952]
#  [0.98630137 0.01369863]]
# Calibrated probabilistic uncertainty interval for y_hat <= threshold ([lower_bound, upper_bound]):
# [[0.016      0.024     ]
#  [0.         0.01388889]]

# %% [markdown]
# #### Factual Explanations
# Let us explain a test instance using our `WrapCalibratedExplainer` object. The method used to get factual explanations is `explain_factual` with `guarded_options=GuardedOptions()`.

# %%
factual_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions())
from calibrated_explanations.ce_agent_utils import print_guarded_audit_table

guarded_audit = factual_explanations.get_guarded_audit()
print_guarded_audit_table(guarded_audit, max_rows=20)
display(regressor)
# Out:
# Guarded Audit Summary
# instances=2 tested=264 conforming=238 removed_guard=26 emitted=35
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 bedrooms           (-inf, 1.5]                 0.5  Y    N    N   design_excluded
#    0    0 bedrooms           (1.5, 2.5]                0.878  Y    N    N   design_excluded
#    0    0 bedrooms           (2.5, 3.5]                0.986  Y    Y    N   emitted
#    0    0 bedrooms           (3.5, 4.5]                 0.95  Y    N    N   design_excluded
#    0    0 bedrooms           (4.5, 5.5]                0.692  Y    N    N   design_excluded
#    0    0 bedrooms           (5.5, inf]                 0.37  Y    N    N   design_excluded
#    0    1 bathrooms          (-inf, 0.875]              0.77  Y    N    N   design_excluded
#    0    1 bathrooms          (0.875, 1.25]             0.886  Y    N    N   design_excluded
#    0    1 bathrooms          (1.25, 1.625]              0.98  Y    N    N   design_excluded
#    0    1 bathrooms          (1.625, 1.875]            0.986  Y    N    N   design_excluded
#    0    1 bathrooms          (1.875, 2.375]             0.99  Y    Y    N   emitted
#    0    1 bathrooms          (2.375, inf]              0.956  Y    N    N   design_excluded
#    0    2 sqft_living        (-inf, 1075]               0.95  Y    N    N   design_excluded
#    0    2 sqft_living        (1075, 1145]               0.98  Y    N    N   design_excluded
#    0    2 sqft_living        (1145, 1545]               0.99  Y    Y    N   emitted
#    0    2 sqft_living        (1545, 1725]               0.98  Y    N    N   design_excluded
#    0    2 sqft_living        (1725, 2035]               0.98  Y    N    N   design_excluded
#    0    2 sqft_living        (2035, 2283]               0.96  Y    N    N   design_excluded
#    0    2 sqft_living        (2283, 2345]               0.94  Y    N    N   design_excluded
#    0    2 sqft_living        (2345, inf]               0.848  Y    N    N   design_excluded
# ... truncated 244 row(s)
# reason_counts: emitted=35, removed_guard=26, design_excluded=196, zero_impact=7
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# #### Merge adjacent conforming bins
# By default, guarded explanations keep each bin as a separate rule.  Passing `GuardedOptions(merge_adjacent=True)` allows adjacent conforming bins to be collapsed into a single wider rule.  The merged rule is re-tested by the guard; if the re-test fails, the original bins are kept.  The `mrg` column in the audit table shows which emitted rules came from a merge.

# %%
merged_factual = regressor.explain_factual(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
merged_audit = merged_factual.get_guarded_audit()
print_guarded_audit_table(merged_audit, max_rows=30)
# Out:
# Guarded Audit Summary
# instances=2 tested=68 conforming=42 removed_guard=26 emitted=28
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 bedrooms           (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0    1 bathrooms          (-inf, inf]                0.99  Y    Y    Y   emitted
#    0    2 sqft_living        (-inf, inf]                0.98  Y    Y    Y   emitted
#    0    3 sqft_lot           (-inf, inf]               0.986  Y    Y    Y   emitted
#    0    4 floors             (-inf, 2.75]              0.986  Y    N    Y   zero_impact
#    0    4 floors             (2.75, inf]               0.098  N    N    N   removed_guard
#    0    5 waterfront         (-inf, inf]               0.986  Y    N    N   zero_impact
#    0    5 waterfront         (-inf, inf]               0.004  N    N    N   removed_guard
#    0    6 view               (-inf, 2.5]               0.986  Y    N    N   zero_impact
#    0    6 view               (2.5, 3.5]                0.078  N    N    N   removed_guard
#    0    6 view               (3.5, inf]                0.042  N    N    N   removed_guard
#    0    7 condition          (-inf, inf]               0.846  Y    Y    Y   emitted
#    0    8 grade              (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0    9 sqft_above         (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   10 sqft_basement      (-inf, inf]               0.996  Y    Y    Y   emitted
#    0   11 yr_built           (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   12 yr_renovated       (-inf, 976.5]             0.986  Y    N    N   zero_impact
#    0   12 yr_renovated       (976.5, 1960.5]           0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1960.5, 1972.5]          0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1972.5, 1988]            0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1988, 1992]              0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1992, 2003.5]            0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (2003.5, inf]             0.038  N    N    N   removed_guard
#    0   13 zipcode            (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   14 lat                (-inf, inf]                0.96  Y    Y    Y   emitted
#    0   15 long               (-inf, inf]               0.976  Y    Y    Y   emitted
#    0   16 sqft_living15      (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   17 sqft_lot15         (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   18 date_year          (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0   19 date_month         (-inf, inf]               0.986  Y    Y    Y   emitted
# ... truncated 38 row(s)
# reason_counts: emitted=28, removed_guard=26, zero_impact=14
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown

# %% [markdown]
# Regression also offer both regular and uncertainty plots for factual explanations with or without conjunctive rules, in almost exactly the same way as for classification.

# %%
factual_explanations.plot()
factual_explanations.plot(uncertainty=True)

factual_explanations.add_conjunctions().plot(uncertainty=True)

# %% [markdown]
# Default, the confidence interval is set to a symmetric interval of 90% (defined as `low_high_percentiles=(5,95)`). The intervals can cover any user specified interval, including one-sided intervals. To define a one-sided upper-bounded 90% interval, set `low_high_percentiles=(-np.inf,90)`, and to define a one-sided lower-bounded 95% interval, set `low_high_percentiles=(5,np.inf)`. Percentiles can also be set to any other values in the range (0,100) (exclusive), and intervals do not have to be symmetric.

# %%
lower_bounded_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), low_high_percentiles=(5, np.inf))
asymmetric_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), low_high_percentiles=(5, 75))

# %% [markdown]
# #### Explore Alternative Explanations
# `explore_alternatives` with `guarded_options=GuardedOptions()` works exactly the same as for classification.

# %%
alternative_explanations = regressor.explore_alternatives(x_test, guarded_options=GuardedOptions())
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# Alternative plots work as for classification.

# %%
alternative_explanations.plot(rnk_metric="ensured", rnk_weight=0.9)
alternative_explanations.add_conjunctions().plot()

# %% [markdown]
# ## Probabilistic Regression
# The difference between probabilistic regression and regular regression is that the former returns a probability of the prediction being below a certain threshold. This could for example be useful when the prediction is a time to an event, such as time to death or time to failure.

# %%
probabilistic_factual_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), threshold=y_test + 20)
probabilistic_factual_explanations.plot()
probabilistic_factual_explanations.plot(uncertainty=True)

# %%
probabilistic_alternative_explanations = regressor.explore_alternatives(x_test, guarded_options=GuardedOptions(), threshold=y_test + 20)
probabilistic_alternative_explanations.plot()
probabilistic_alternative_explanations.plot(style="ensured")
print(probabilistic_alternative_explanations.to_narrative(expertise_level="advanced",output_format="text"))
# Out:
# ================================================================================
# Instance 0
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Calibrated Probability (target <= 310.000): 0.673
# Prediction Interval: [0.636, 0.750]
#
# Alternatives to increase the Calibrated Probability for target <= 310.000:
# - If lat 47.33 < lat <= 47.43                   then P(target <= 310.000) = 0.979 [0.979, 1.000]
# - If lat <= 47.33                               then P(target <= 310.000) = 0.979 [0.979, 1.000]
# - If sqft_living 1075 < sqft_living <= 1145     then P(target <= 310.000) = 0.938 [0.933, 1.000]
# - If sqft_living <= 1075                        then P(target <= 310.000) = 0.938 [0.933, 1.000]
# - If grade <= 4.5                               then P(target <= 310.000) = 0.846 [0.818, 1.000]
# - If date_day 4.5 < date_day <= 8.5             then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If grade 4.5 < grade <= 6.5                   then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If date_day 8.5 < date_day <= 10.5            then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If date_day <= 4.5                            then P(target <= 310.000) = 0.818 [0.800, 0.900]
#
# Alternatives to decrease the Calibrated Probability for target <= 310.000:
# - If lat 47.57 < lat <= 47.74                   then P(target <= 310.000) = 0.034 [0.000, 0.035]
# - If lat 47.53 < lat <= 47.54                   then P(target <= 310.000) = 0.039 [0.020, 0.040]
# - If lat 47.54 < lat <= 47.57                   then P(target <= 310.000) = 0.039 [0.020, 0.040]
# - If lat > 47.74                                then P(target <= 310.000) = 0.091 [0.067, 0.094]
# - If lat 47.52 < lat <= 47.53                   then P(target <= 310.000) = 0.238 [0.200, 0.250]
# - If long <= -122.4                             then P(target <= 310.000) = 0.238 [0.200, 0.250]
# - If sqft_living > 2345                         then P(target <= 310.000) = 0.294 [0.200, 0.333]
# - If long -122.4 < long <= -122.4               then P(target <= 310.000) = 0.593 [0.556, 0.647]
# - If sqft_living 1725 < sqft_living <= 2035     then P(target <= 310.000) = 0.593 [0.556, 0.647]
# - If zipcode 9.801e+04 < zipcode <= 9.802e+04   then P(target <= 310.000) = 0.593 [0.556, 0.647]
# - If zipcode 9.802e+04 < zipcode <= 9.803e+04   then P(target <= 310.000) = 0.593 [0.556, 0.647]
# - If zipcode 9.8e+04 < zipcode <= 9.801e+04     then P(target <= 310.000) = 0.593 [0.556, 0.647]
# - If zipcode 9.8e+04 < zipcode <= 9.8e+04       then P(target <= 310.000) = 0.593 [0.556, 0.647]
# - If zipcode 9.8e+04 < zipcode <= 9.8e+04       then P(target <= 310.000) = 0.593 [0.556, 0.647]
# - If zipcode <= 9.8e+04                         then P(target <= 310.000) = 0.593 [0.556, 0.647]
# - If floors 1.75 < floors <= 2.25               then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_above 1545 < sqft_above <= 2125       then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_living 1545 < sqft_living <= 1725     then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If floors 2.25 < floors <= 2.75               then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_above 2125 < sqft_above <= 2365       then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_living15 2305 < sqft_living15 <= 2765 then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_above 2365 < sqft_above <= 3186       then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_above 3186 < sqft_above <= 3452       then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_lot 4082 < sqft_lot <= 6591           then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If grade 7.5 < grade <= 8.5                   then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If grade 8.5 < grade <= 9.5                   then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If bedrooms > 5.5                             then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If condition > 4.5                            then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If date_month <= 2.5                          then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If date_year > 2014                           then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If grade > 9.5                                then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_above > 3452                          then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_living15 > 2765                       then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_lot15 > 1.512e+04                     then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If yr_built <= 1914                           then P(target <= 310.000) = 0.631 [0.618, 0.654]
# - If sqft_lot 1338 < sqft_lot <= 4082           then P(target <= 310.000) = 0.662 [0.618, 0.750]
# - If yr_built 1914 < yr_built <= 1918           then P(target <= 310.000) = 0.662 [0.618, 0.750]
# - If yr_built 1998 < yr_built <= 2000           then P(target <= 310.000) = 0.662 [0.618, 0.750]
# - If date_month 2.5 < date_month <= 7.5         then P(target <= 310.000) = 0.662 [0.618, 0.750]
# - If long > -122.1                              then P(target <= 310.000) = 0.662 [0.618, 0.750]
#
# ================================================================================
# Instance 1
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Calibrated Probability (target <= 417.500): 0.662
# Prediction Interval: [0.606, 0.773]
#
# Alternatives to increase the Calibrated Probability for target <= 417.500:
# - If lat 47.33 < lat <= 47.43                       then P(target <= 417.500) = 0.989 [0.989, 1.000]
# - If lat 47.43 < lat <= 47.52                       then P(target <= 417.500) = 0.989 [0.989, 1.000]
# - If lat <= 47.33                                   then P(target <= 417.500) = 0.989 [0.989, 1.000]
# - If lat 47.52 < lat <= 47.53                       then P(target <= 417.500) = 0.941 [0.938, 1.000]
# - If lat > 47.74                                    then P(target <= 417.500) = 0.852 [0.833, 0.958]
# - If sqft_living 1075 < sqft_living <= 1145         then P(target <= 417.500) = 0.739 [0.727, 0.773]
# - If lat 47.53 < lat <= 47.54                       then P(target <= 417.500) = 0.739 [0.727, 0.773]
# - If date_month 9.5 < date_month <= 11.5            then P(target <= 417.500) = 0.739 [0.727, 0.773]
# - If lat 47.54 < lat <= 47.57                       then P(target <= 417.500) = 0.699 [0.667, 0.773]
# - If date_month > 11.5                              then P(target <= 417.500) = 0.699 [0.667, 0.773]
# - If sqft_living <= 1075                            then P(target <= 417.500) = 0.699 [0.667, 0.773]
# - If sqft_living15 1359 < sqft_living15 <= 1365     then P(target <= 417.500) = 0.669 [0.618, 0.773]
# - If yr_built 1922 < yr_built <= 1998               then P(target <= 417.500) = 0.669 [0.618, 0.773]
# - If zipcode 9.801e+04 < zipcode <= 9.802e+04       then P(target <= 417.500) = 0.669 [0.618, 0.773]
# - If zipcode 9.8e+04 < zipcode <= 9.801e+04         then P(target <= 417.500) = 0.669 [0.618, 0.773]
# - If zipcode 9.8e+04 < zipcode <= 9.8e+04           then P(target <= 417.500) = 0.669 [0.618, 0.773]
# - If zipcode 9.8e+04 < zipcode <= 9.8e+04           then P(target <= 417.500) = 0.669 [0.618, 0.773]
# - If bathrooms > 2.375                              then P(target <= 417.500) = 0.669 [0.618, 0.773]
# - If zipcode <= 9.8e+04                             then P(target <= 417.500) = 0.669 [0.618, 0.773]
#
# Alternatives to decrease the Calibrated Probability for target <= 417.500:
# - If sqft_living > 2345                             then P(target <= 417.500) = 0.526 [0.500, 0.556] [⚠️ uncertain]
# - If long -122.1 < long <= -122.1                   then P(target <= 417.500) = 0.539 [0.519, 0.562]
# - If long -122.1 < long <= -122.1                   then P(target <= 417.500) = 0.539 [0.519, 0.562]
# - If long -122.1 < long <= -122.1                   then P(target <= 417.500) = 0.539 [0.519, 0.562]
# - If sqft_living 1725 < sqft_living <= 2035         then P(target <= 417.500) = 0.539 [0.519, 0.562]
# - If sqft_lot15 3436 < sqft_lot15 <= 6044           then P(target <= 417.500) = 0.539 [0.519, 0.562]
# - If long <= -122.4                                 then P(target <= 417.500) = 0.539 [0.519, 0.562]
# - If sqft_lot15 1.011e+04 < sqft_lot15 <= 1.026e+04 then P(target <= 417.500) = 0.543 [0.519, 0.571]
# - If sqft_lot15 1.026e+04 < sqft_lot15 <= 1.512e+04 then P(target <= 417.500) = 0.543 [0.519, 0.571]
# - If sqft_lot15 6044 < sqft_lot15 <= 1.011e+04      then P(target <= 417.500) = 0.543 [0.519, 0.571]
# - If sqft_lot 9858 < sqft_lot <= 1.001e+04          then P(target <= 417.500) = 0.543 [0.519, 0.571]
# - If long > -122.1                                  then P(target <= 417.500) = 0.543 [0.519, 0.571]
# - If sqft_lot 6591 < sqft_lot <= 9858               then P(target <= 417.500) = 0.569 [0.519, 0.636]
# - If sqft_lot > 1.001e+04                           then P(target <= 417.500) = 0.569 [0.519, 0.636]
# - If sqft_lot15 > 1.512e+04                         then P(target <= 417.500) = 0.569 [0.519, 0.636]
# - If sqft_living 1545 < sqft_living <= 1725         then P(target <= 417.500) = 0.578 [0.536, 0.636]
# - If sqft_living15 2305 < sqft_living15 <= 2765     then P(target <= 417.500) = 0.578 [0.536, 0.636]
# - If sqft_lot 4082 < sqft_lot <= 6591               then P(target <= 417.500) = 0.578 [0.536, 0.636]
# - If long -122.4 < long <= -122.4                   then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If long -122.4 < long <= -122.4                   then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If bathrooms 0.875 < bathrooms <= 1.25            then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If floors 1.25 < floors <= 1.75                   then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_living15 1035 < sqft_living15 <= 1359     then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_above 1075 < sqft_above <= 1135           then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_living15 1475 < sqft_living15 <= 2305     then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If date_day 15.5 < date_day <= 16.5               then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_above 1545 < sqft_above <= 2125           then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If date_day 16.5 < date_day <= 18.5               then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If date_month 2.5 < date_month <= 7.5             then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_above 2125 < sqft_above <= 2365           then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_above 2365 < sqft_above <= 3186           then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_basement 245 < sqft_basement <= 665       then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If bedrooms 3.5 < bedrooms <= 4.5                 then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_above 3186 < sqft_above <= 3452           then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If bedrooms 4.5 < bedrooms <= 5.5                 then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If grade 4.5 < grade <= 6.5                       then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If grade 6.5 < grade <= 7.5                       then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_basement 665 < sqft_basement <= 965       then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_lot 692 < sqft_lot <= 1216                then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_living15 955 < sqft_living15 <= 1035      then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_basement 965 < sqft_basement <= 1230      then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If bathrooms <= 0.875                             then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If condition <= 2.5                               then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If date_day <= 4.5                                then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If date_day > 27.5                                then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If date_month <= 2.5                              then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If grade <= 4.5                                   then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_above <= 1075                             then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_living15 <= 955                           then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_living15 > 2765                           then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If sqft_lot <= 692                                then P(target <= 417.500) = 0.618 [0.606, 0.636]
# - If bathrooms 1.25 < bathrooms <= 1.625            then P(target <= 417.500) = 0.629 [0.606, 0.667]
# - If bathrooms 1.625 < bathrooms <= 1.875           then P(target <= 417.500) = 0.629 [0.606, 0.667]
# - If floors 2.25 < floors <= 2.75                   then P(target <= 417.500) = 0.629 [0.606, 0.667]
# - If yr_built 2000 < yr_built <= 2004               then P(target <= 417.500) = 0.629 [0.606, 0.667]
# - If floors <= 1.25                                 then P(target <= 417.500) = 0.629 [0.606, 0.667]

# %% [markdown]
# Regression offers many more options but to learn more about them, see the [demo_regression](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_regression.ipynb) or the [demo_probabilistic_regression](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_probabilistic_regression.ipynb) notebooks.
#
# A `WrapCalibratedExplainer` can also be initialized with a trained model or with a `WrapCalibratedExplainer` object, as is examplified below. We use the `learner` and `explainer` from the previously initialized `classifier` and `regressor` instances, as we know that these are fitted and calibrated.

# %%
new_classifier = WrapCalibratedExplainer(classifier.learner)
display(new_classifier)
new_classifier_explainer = WrapCalibratedExplainer(classifier.explainer)
display(new_classifier_explainer)

new_regressor = WrapCalibratedExplainer(regressor.learner)
display(new_regressor)
new_regressor_explainer = WrapCalibratedExplainer(regressor.explainer)
display(new_regressor_explainer)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=False)
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=False)
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# When a calibrated explainer is re-fitted, the explainer is reinitialized.
