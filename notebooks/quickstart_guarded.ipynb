# %% [markdown]
# ## Learning objectives
# - Learn how to use `WrapCalibratedExplainer` to wrap a model and produce calibrated predictions;
# - Generate factual and alternative explanations and plot uncertainty;
# - Understand when OOB vs explicit calibration is appropriate.
#
# ## Time to run
# ~2–10 min depending on dataset and environment (use smaller datasets for a faster run).

# %% [markdown]
# # Getting started with calibrated-explanations - using the WrapCalibratedExplainer class
# Author: Tuwe Löfström (tuwe.lofstrom@ju.se)
# Copyright 2023 Tuwe Löfström
# License: BSD 3 clause
# ## Classification
# Let us illustrate how we may use `calibrated_explanations` to generate explanations from a classifier trained on a dataset from
# [www.openml.org](https://www.openml.org), which we first split into a
# training and a test set using `train_test_split` from
# [sklearn](https://scikit-learn.org), and then further split the
# training set into a proper training set and a calibration set:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

dataset = fetch_openml(name="wine", version=7, as_frame=True, parser="auto")

X = dataset.data.values.astype(float)
y = (dataset.target.values == "True").astype(int)

feature_names = dataset.feature_names

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=2, stratify=y)

X_prop_train, x_cal, y_prop_train, y_cal = train_test_split(x_train, y_train, test_size=0.25)

# %% [markdown]
# We now create our wrapper object, using a `RandomForestClassifier` as learner.

# %%
from sklearn.ensemble import RandomForestClassifier

from calibrated_explanations import WrapCalibratedExplainer, __version__

print(f"calibrated_explanations {__version__}")

classifier = WrapCalibratedExplainer(RandomForestClassifier())
display(classifier)
# Out:
# calibrated_explanations 0.11.6
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=False, calibrated=False)

# %% [markdown]
# We now fit our model using the proper training set.

# %%
classifier.fit(X_prop_train, y_prop_train)
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=False)

# %% [markdown]
# The `WrapCalibratedExplainer` class has a `predict` and a `predict_proba` method that returns the predictions and probability estimates of the underlying classifier. If the model is not yet calibrated, then the underlying models `predict` and `predict_proba` methods are used. If the model is calibrated, then the `predict` and `predict_proba` method of the calibration model is used.

# %%
prediction = classifier.predict(x_test)
proba = classifier.predict_proba(x_test)
print("Uncalibrated prediction (probability estimates):")
print(f"{prediction} ({proba})")
# Out:
# Uncalibrated prediction (probability estimates):
# [1 0] ([[0.11 0.89]
#  [0.86 0.14]])
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_35696\1092592062.py:1: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated predictions.
#   prediction = classifier.predict(x_test)
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_35696\1092592062.py:2: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated probabilities.
#   proba = classifier.predict_proba(x_test)

# %% [markdown]
# Before we can generate explanations, we need to calibrate our model using the calibration set.

# %%
classifier.calibrate(x_cal, y_cal, feature_names=feature_names)
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, learner=RandomForestClassifier()))

# %% [markdown]
# Once the model is calibrated, the `predict` and `predict_proba` methods produce calibrated predictions and probability estimates.

# %%
prediction = classifier.predict(x_test)
proba, (low, high) = classifier.predict_proba(x_test, uq_interval=True)
print("Calibrated prediction (probability estimates):")
print(f"{prediction} ({proba})")
print("Calibrated uncertainty interval for the positive class:")
print([(low[i], high[i]) for i in range(len(low))])
# Out:
# Calibrated prediction (probability estimates):
# [1 0] ([[0.09638554 0.90361446]
#  [0.88571429 0.11428571]])
# Calibrated uncertainty interval for the positive class:
# [(np.float64(0.8974358974358975), np.float64(0.9615384615384616)), (np.float64(0.08823529411764706), np.float64(0.11764705882352941))]

# %% [markdown]
# #### Factual Explanations
# Let us explain a test instance using our `WrapCalibratedExplainer` object. The method used to get factual explanations is `explain_factual` with `guarded_options=GuardedOptions()`.

# %%
from calibrated_explanations import GuardedOptions

factual_explanations = classifier.explain_factual(x_test, guarded_options=GuardedOptions())
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %%
from calibrated_explanations.ce_agent_utils import print_guarded_audit_table

guarded_audit = factual_explanations.get_guarded_audit()
print_guarded_audit_table(guarded_audit, max_rows=20)
display(classifier)
# Out:
# Guarded Audit Summary
# instances=2 tested=164 conforming=121 removed_guard=43 emitted=21
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 fixed acidity      (-inf, 4.65]             0.3746  Y    N    N   design_excluded
#    0    0 fixed acidity      (4.65, 5.1]              0.4969  Y    N    N   design_excluded
#    0    0 fixed acidity      (5.1, 5.65]               0.616  Y    Y    N   emitted
#    0    0 fixed acidity      (5.65, 6.85]             0.7038  Y    N    N   design_excluded
#    0    0 fixed acidity      (6.85, 13.6]             0.5893  Y    N    N   design_excluded
#    0    0 fixed acidity      (13.6, 14.4]             0.0063  N    N    N   removed_guard
#    0    0 fixed acidity      (14.4, inf]              0.0047  N    N    N   removed_guard
#    0    1 volatile acidity   (-inf, 0.195]            0.8323  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.195, 0.505]           0.8934  Y    Y    N   emitted
#    0    1 volatile acidity   (0.505, 0.515]           0.4185  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.515, 0.525]           0.3981  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.525, 0.835]           0.2398  Y    N    N   design_excluded
#    0    1 volatile acidity   (0.835, 0.8525]          0.0361  N    N    N   removed_guard
#    0    1 volatile acidity   (0.8525, inf]            0.0157  N    N    N   removed_guard
#    0    2 citric acid        (-inf, 0.155]            0.1567  Y    N    N   design_excluded
#    0    2 citric acid        (0.155, 0.185]           0.5329  Y    N    N   design_excluded
#    0    2 citric acid        (0.185, 0.225]           0.6897  Y    N    N   design_excluded
#    0    2 citric acid        (0.225, 0.235]             0.71  Y    N    N   design_excluded
#    0    2 citric acid        (0.235, 0.265]           0.7179  Y    N    N   design_excluded
#    0    2 citric acid        (0.265, 0.415]           0.6379  Y    Y    N   emitted
# ... truncated 144 row(s)
# reason_counts: emitted=21, removed_guard=43, design_excluded=99, zero_impact=1
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %% [markdown]
# #### Merge adjacent conforming bins
# Passing `merge_adjacent=True` collapses adjacent conforming bins into wider rules (re-tested by the guard).  Rows with `mrg=Y` in the audit table came from a merge; the displayed interval shows the emitted bounds.

# %%
merged_factual_cls = classifier.explain_factual(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
merged_audit_cls = merged_factual_cls.get_guarded_audit()
print_guarded_audit_table(merged_audit_cls, max_rows=30)
# Out:
# Guarded Audit Summary
# instances=2 tested=65 conforming=22 removed_guard=43 emitted=16
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 fixed acidity      (-inf, 13.6]             0.6003  Y    Y    Y   emitted
#    0    0 fixed acidity      (13.6, 14.4]             0.0063  N    N    N   removed_guard
#    0    0 fixed acidity      (14.4, inf]              0.0047  N    N    N   removed_guard
#    0    1 volatile acidity   (-inf, 0.835]            0.8934  Y    Y    Y   emitted
#    0    1 volatile acidity   (0.835, 0.8525]          0.0361  N    N    N   removed_guard
#    0    1 volatile acidity   (0.8525, inf]            0.0157  N    N    N   removed_guard
#    0    2 citric acid        (-inf, 0.77]             0.6646  Y    Y    Y   emitted
#    0    2 citric acid        (0.77, inf]              0.0094  N    N    N   removed_guard
#    0    3 residual sugar     (-inf, 12.75]            0.6332  Y    N    Y   zero_impact
#    0    3 residual sugar     (12.75, 15.25]           0.0376  N    N    N   removed_guard
#    0    3 residual sugar     (15.25, 17.525]          0.0282  N    N    N   removed_guard
#    0    3 residual sugar     (17.525, 17.625]          0.011  N    N    N   removed_guard
#    0    3 residual sugar     (17.625, inf]            0.0094  N    N    N   removed_guard
#    0    4 chlorides          (-inf, inf]              0.7508  Y    Y    Y   emitted
#    0    5 free sulfur dioxid (-inf, 110]              0.6003  Y    Y    Y   emitted
#    0    5 free sulfur dioxid (110, inf]               0.0799  N    N    N   removed_guard
#    0    6 total sulfur dioxi (-inf, inf]              0.6818  Y    Y    Y   emitted
#    0    7 density            (-inf, 0.9944]           0.4107  Y    Y    Y   emitted
#    0    7 density            (0.9944, 0.9975]          0.047  N    N    N   removed_guard
#    0    7 density            (0.9975, inf]            0.0157  N    N    N   removed_guard
#    0    8 pH                 (-inf, 3.695]             0.616  Y    Y    Y   emitted
#    0    8 pH                 (3.695, inf]             0.0752  N    N    N   removed_guard
#    0    9 sulphates          (-inf, 1.19]             0.6646  Y    Y    Y   emitted
#    0    9 sulphates          (1.19, inf]              0.0063  N    N    N   removed_guard
#    0   10 alcohol            (-inf, 9.15]             0.0643  N    N    N   removed_guard
#    0   10 alcohol            (9.15, inf]              0.3715  Y    Y    Y   emitted
#    1    0 fixed acidity      (-inf, 4.65]             0.0658  N    N    N   removed_guard
#    1    0 fixed acidity      (4.65, 5.1]               0.094  N    N    N   removed_guard
#    1    0 fixed acidity      (5.1, 13.6]              0.2853  Y    Y    Y   emitted
#    1    0 fixed acidity      (13.6, 14.4]             0.0063  N    N    N   removed_guard
# ... truncated 35 row(s)
# reason_counts: emitted=16, removed_guard=43, zero_impact=6
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown

# %% [markdown]
# Once we have the explanations, we can plot all of them using `plot`. Default, a regular plot, without uncertainty intervals included, is created. To include uncertainty intervals, change the parameter `uncertainty=True`.

# %%
factual_explanations.plot()
factual_explanations.plot(uncertainty=True)

# %% [markdown]
# You can also add and remove conjunctive rules.

# %%
factual_explanations.add_conjunctions().plot()
factual_explanations.remove_conjunctions().plot(uncertainty=True)

# %% [markdown]
# All explanations support indexing using integer indexing, slices or boolean indexing.

# %%
factual_explanations[0].plot(uncertainty=True)
factual_explanations[:1].plot(uncertainty=True)

# %% [markdown]
# #### Explore Alternative Explanations
# An alternative to factual rules is to extract alternative rules, which is done using `explore_alternatives` with `guarded_options=GuardedOptions()`. Alternative explanations provides insights on how predicted outcomes would change if specific input features were modified, including uncertainty estimates for these alternative outcomes.

# %%
alternative_explanations = classifier.explore_alternatives(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
display(classifier)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))

# %% [markdown]
# Alternatives are also visualized using the `plot` function. Plotting an individual alternative explanation is easiest done using indexing. Adding or removing conjunctions is done as before.

# %%
alternative_explanations.plot()
alternative_explanations.add_conjunctions().plot()
alternative_explanations.add_conjunctions().plot(style="ensured")
print(alternative_explanations.to_narrative(output_format="text"))
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# ================================================================================
# Instance 0
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.904
# Prediction Interval: [0.897, 0.962]
#
# Alternatives to increase the calibrated probability for class 1:
# - If sulphates 0.415 < sulphates <= 1.19                                 then 0.950 [0.947, 1.000]
# - If fixed acidity 5.65 < fixed acidity <= 13.6                          then 0.950 [0.947, 1.000]
# - If volatile acidity <= 0.195                                           then 0.941 [0.938, 1.000]
# - If alcohol > 12.95                                                     then 0.926 [0.923, 0.962]
# - If sulphates <= 0.325                                                  then 0.914 [0.909, 0.962]
#
# Alternatives to decrease the calibrated probability for class 1:
# - If (0.9895 < density <= 0.9944 AND 9.15 < alcohol <= 11.55)            then 0.211 [0.189, 0.216]
# - If (chlorides > 0.0345 AND 9.15 < alcohol <= 11.55)                    then 0.211 [0.189, 0.216]
# - If (volatile acidity <= 0.195 AND 9.15 < alcohol <= 11.55)             then 0.211 [0.189, 0.216]
# - If alcohol 9.15 < alcohol <= 11.55                                     then 0.215 [0.189, 0.222]
# - If (citric acid <= 0.265 AND 9.15 < alcohol <= 11.55)                  then 0.215 [0.189, 0.222]
# - If (fixed acidity <= 5.1 AND 9.15 < alcohol <= 11.55)                  then 0.215 [0.189, 0.222]
# - If (free sulfur dioxide <= 27.5 AND 9.15 < alcohol <= 11.55)           then 0.215 [0.189, 0.222]
# - If (sulphates <= 0.325 AND 9.15 < alcohol <= 11.55)                    then 0.215 [0.189, 0.222]
# - If (pH <= 2.945 AND 9.15 < alcohol <= 11.55)                           then 0.273 [0.250, 0.282]
# - If (total sulfur dioxide <= 69.5 AND 9.15 < alcohol <= 11.55)          then 0.273 [0.250, 0.282]
# - If (0.9895 < density <= 0.9944 AND chlorides > 0.0345)                 then 0.560 [0.551, 0.571]
# - If chlorides > 0.0345                                                  then 0.560 [0.551, 0.571]
# - If (chlorides > 0.0345 AND pH <= 2.945)                                then 0.560 [0.551, 0.571]
# - If (chlorides > 0.0345 AND total sulfur dioxide <= 69.5)               then 0.560 [0.551, 0.571]
# - If (citric acid <= 0.265 AND chlorides > 0.0345)                       then 0.560 [0.551, 0.571]
# - If (fixed acidity <= 5.1 AND chlorides > 0.0345)                       then 0.560 [0.551, 0.571]
# - If (free sulfur dioxide <= 27.5 AND 0.505 < volatile acidity <= 0.835) then 0.560 [0.551, 0.571]
# - If (free sulfur dioxide <= 27.5 AND chlorides > 0.0345)                then 0.560 [0.551, 0.571]
# - If (sulphates <= 0.325 AND chlorides > 0.0345)                         then 0.560 [0.551, 0.571]
# - If (0.9895 < density <= 0.9944 AND total sulfur dioxide <= 69.5)       then 0.580 [0.557, 0.611]
# - If (volatile acidity <= 0.195 AND chlorides > 0.0345)                  then 0.580 [0.557, 0.611]
# - If (citric acid <= 0.265 AND total sulfur dioxide <= 69.5)             then 0.603 [0.561, 0.667]
# - If volatile acidity 0.505 < volatile acidity <= 0.835                  then 0.700 [0.695, 0.712]
# - If (0.9895 < density <= 0.9944 AND 0.505 < volatile acidity <= 0.835)  then 0.700 [0.695, 0.712]
# - If (0.9895 < density <= 0.9944 AND pH <= 2.945)                        then 0.700 [0.695, 0.712]
# - If (citric acid <= 0.265 AND 0.505 < volatile acidity <= 0.835)        then 0.700 [0.695, 0.712]
# - If (fixed acidity <= 5.1 AND 0.505 < volatile acidity <= 0.835)        then 0.700 [0.695, 0.712]
# - If (fixed acidity <= 5.1 AND total sulfur dioxide <= 69.5)             then 0.700 [0.695, 0.712]
# - If (free sulfur dioxide <= 27.5 AND pH <= 2.945)                       then 0.700 [0.695, 0.712]
# - If (free sulfur dioxide <= 27.5 AND total sulfur dioxide <= 69.5)      then 0.700 [0.695, 0.712]
# - If (sulphates <= 0.325 AND 0.505 < volatile acidity <= 0.835)          then 0.700 [0.695, 0.712]
# - If (sulphates <= 0.325 AND total sulfur dioxide <= 69.5)               then 0.700 [0.695, 0.712]
# - If total sulfur dioxide <= 69.5                                        then 0.700 [0.695, 0.712]
# - If (total sulfur dioxide <= 69.5 AND pH <= 2.945)                      then 0.700 [0.695, 0.712]
# - If (citric acid <= 0.265 AND pH <= 2.945)                              then 0.759 [0.750, 0.786]
# - If (volatile acidity <= 0.195 AND total sulfur dioxide <= 69.5)        then 0.759 [0.750, 0.786]
# - If citric acid 0.415 < citric acid <= 0.77                             then 0.846 [0.842, 0.868]
# - If density 0.9895 < density <= 0.9944                                  then 0.846 [0.842, 0.868]
# - If (fixed acidity <= 5.1 AND pH <= 2.945)                              then 0.846 [0.842, 0.868]
# - If free sulfur dioxide <= 27.5                                         then 0.846 [0.842, 0.868]
# - If pH <= 2.945                                                         then 0.846 [0.842, 0.868]
# - If (sulphates <= 0.325 AND pH <= 2.945)                                then 0.846 [0.842, 0.868]
# - If citric acid <= 0.265                                                then 0.865 [0.857, 0.914]
# - If (volatile acidity <= 0.195 AND pH <= 2.945)                         then 0.865 [0.857, 0.914]
# - If fixed acidity <= 5.1                                                then 0.873 [0.867, 0.914]
#
# Alternative Explanation (Beginner):
# --------------------------------------------------------------------------------
# Prediction: 1
# Calibrated probability: 0.904
#
# Alternatives to increase the calibrated probability for class 1:
# - sulphates 0.415 < sulphates <= 1.19
# - fixed acidity 5.65 < fixed acidity <= 13.6
# - volatile acidity <= 0.195
# - alcohol > 12.95
# - sulphates <= 0.325
#
# Alternatives to decrease the calibrated probability for class 1:
# - (0.9895 < density <= 0.9944 AND 9.15 < alcohol <= 11.55)
# - (chlorides > 0.0345 AND 9.15 < alcohol <= 11.55)
# - (volatile acidity <= 0.195 AND 9.15 < alcohol <= 11.55)
# - alcohol 9.15 < alcohol <= 11.55
# - (citric acid <= 0.265 AND 9.15 < alcohol <= 11.55)
# - (fixed acidity <= 5.1 AND 9.15 < alcohol <= 11.55)
# - (free sulfur dioxide <= 27.5 AND 9.15 < alcohol <= 11.55)
# - (sulphates <= 0.325 AND 9.15 < alcohol <= 11.55)
# - (pH <= 2.945 AND 9.15 < alcohol <= 11.55)
# - (total sulfur dioxide <= 69.5 AND 9.15 < alcohol <= 11.55)
# - (0.9895 < density <= 0.9944 AND chlorides > 0.0345)
# - chlorides > 0.0345
# - (chlorides > 0.0345 AND pH <= 2.945)
# - (chlorides > 0.0345 AND total sulfur dioxide <= 69.5)
# - (citric acid <= 0.265 AND chlorides > 0.0345)
# - (fixed acidity <= 5.1 AND chlorides > 0.0345)
# - (free sulfur dioxide <= 27.5 AND 0.505 < volatile acidity <= 0.835)
# - (free sulfur dioxide <= 27.5 AND chlorides > 0.0345)
# - (sulphates <= 0.325 AND chlorides > 0.0345)
# - (0.9895 < density <= 0.9944 AND total sulfur dioxide <= 69.5)
# - (volatile acidity <= 0.195 AND chlorides > 0.0345)
# - (citric acid <= 0.265 AND total sulfur dioxide <= 69.5)
# - volatile acidity 0.505 < volatile acidity <= 0.835
# - (0.9895 < density <= 0.9944 AND 0.505 < volatile acidity <= 0.835)
# - (0.9895 < density <= 0.9944 AND pH <= 2.945)
# - (citric acid <= 0.265 AND 0.505 < volatile acidity <= 0.835)
# - (fixed acidity <= 5.1 AND 0.505 < volatile acidity <= 0.835)
# - (fixed acidity <= 5.1 AND total sulfur dioxide <= 69.5)
# - (free sulfur dioxide <= 27.5 AND pH <= 2.945)
# - (free sulfur dioxide <= 27.5 AND total sulfur dioxide <= 69.5)
# - (sulphates <= 0.325 AND 0.505 < volatile acidity <= 0.835)
# - (sulphates <= 0.325 AND total sulfur dioxide <= 69.5)
# - total sulfur dioxide <= 69.5
# - (total sulfur dioxide <= 69.5 AND pH <= 2.945)
# - (citric acid <= 0.265 AND pH <= 2.945)
# - (volatile acidity <= 0.195 AND total sulfur dioxide <= 69.5)
# - citric acid 0.415 < citric acid <= 0.77
# - density 0.9895 < density <= 0.9944
# - (fixed acidity <= 5.1 AND pH <= 2.945)
# - free sulfur dioxide <= 27.5
# - pH <= 2.945
# - (sulphates <= 0.325 AND pH <= 2.945)
# - citric acid <= 0.265
# - (volatile acidity <= 0.195 AND pH <= 2.945)
# - fixed acidity <= 5.1
#
# ================================================================================
# Instance 1
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Prediction: 0
# Calibrated probability: 0.114
# Prediction Interval: [0.088, 0.118]
#
# Alternatives to increase the calibrated probability for class 1:
# - If (0.575 < sulphates <= 1.19 AND volatile acidity <= 0.195)      then 0.211 [0.189, 0.216]
# - If (citric acid <= 0.415 AND volatile acidity <= 0.195)           then 0.211 [0.189, 0.216]
# - If (volatile acidity <= 0.195 AND 9.15 < alcohol <= 11.35)        then 0.211 [0.189, 0.216]
# - If (volatile acidity <= 0.195 AND pH <= 2.945)                    then 0.211 [0.189, 0.216]
# - If (0.575 < sulphates <= 1.19 AND 5.1 < fixed acidity <= 5.65)    then 0.186 [0.176, 0.188]
# - If (0.575 < sulphates <= 1.19 AND 9.15 < alcohol <= 11.35)        then 0.186 [0.176, 0.188]
# - If (0.575 < sulphates <= 1.19 AND pH <= 2.945)                    then 0.186 [0.176, 0.188]
# - If (0.9944 < density <= 0.9975 AND 5.1 < fixed acidity <= 5.65)   then 0.186 [0.176, 0.188]
# - If (0.9944 < density <= 0.9975 AND 9.15 < alcohol <= 11.35)       then 0.186 [0.176, 0.188]
# - If (0.9944 < density <= 0.9975 AND volatile acidity <= 0.195)     then 0.186 [0.176, 0.188]
# - If (3.05 < residual sugar <= 12.75 AND 9.15 < alcohol <= 11.35)   then 0.186 [0.176, 0.188]
# - If (3.05 < residual sugar <= 12.75 AND volatile acidity <= 0.195) then 0.186 [0.176, 0.188]
# - If fixed acidity 5.1 < fixed acidity <= 5.65                      then 0.186 [0.176, 0.188]
# - If (5.1 < fixed acidity <= 5.65 AND 9.15 < alcohol <= 11.35)      then 0.186 [0.176, 0.188]
# - If (5.1 < fixed acidity <= 5.65 AND pH <= 2.945)                  then 0.186 [0.176, 0.188]
# - If (5.1 < fixed acidity <= 5.65 AND volatile acidity <= 0.195)    then 0.186 [0.176, 0.188]
# - If fixed acidity 6.85 < fixed acidity <= 13.6                     then 0.186 [0.176, 0.188]
# - If alcohol 9.15 < alcohol <= 11.35                                then 0.186 [0.176, 0.188]
# - If (chlorides > 0.0755 AND 9.15 < alcohol <= 11.35)               then 0.186 [0.176, 0.188]
# - If (chlorides > 0.0755 AND volatile acidity <= 0.195)             then 0.186 [0.176, 0.188]
# - If (citric acid <= 0.415 AND 9.15 < alcohol <= 11.35)             then 0.186 [0.176, 0.188]
# - If (citric acid <= 0.415 AND pH <= 2.945)                         then 0.186 [0.176, 0.188]
# - If pH <= 2.945                                                    then 0.186 [0.176, 0.188]
# - If (pH <= 2.945 AND 9.15 < alcohol <= 11.35)                      then 0.186 [0.176, 0.188]
# - If volatile acidity <= 0.195                                      then 0.186 [0.176, 0.188]
# - If sulphates 0.575 < sulphates <= 1.19                            then 0.135 [0.088, 0.143]
# - If density 0.9944 < density <= 0.9975                             then 0.135 [0.088, 0.143]
# - If (0.9944 < density <= 0.9975 AND pH <= 2.945)                   then 0.135 [0.088, 0.143]
#
# Alternatives to decrease the calibrated probability for class 1:
# - If residual sugar 3.05 < residual sugar <= 12.75                  then 0.048 [0.032, 0.048]
# - If residual sugar > 15.25                                         then 0.049 [0.032, 0.050]
# - If chlorides > 0.0755                                             then 0.079 [0.032, 0.083]
# - If citric acid <= 0.415                                           then 0.096 [0.032, 0.103]
#
# Alternative Explanation (Beginner):
# --------------------------------------------------------------------------------
# Prediction: 0
# Calibrated probability: 0.114
#
# Alternatives to increase the calibrated probability for class 1:
# - (0.575 < sulphates <= 1.19 AND volatile acidity <= 0.195)
# - (citric acid <= 0.415 AND volatile acidity <= 0.195)
# - (volatile acidity <= 0.195 AND 9.15 < alcohol <= 11.35)
# - (volatile acidity <= 0.195 AND pH <= 2.945)
# - (0.575 < sulphates <= 1.19 AND 5.1 < fixed acidity <= 5.65)
# - (0.575 < sulphates <= 1.19 AND 9.15 < alcohol <= 11.35)
# - (0.575 < sulphates <= 1.19 AND pH <= 2.945)
# - (0.9944 < density <= 0.9975 AND 5.1 < fixed acidity <= 5.65)
# - (0.9944 < density <= 0.9975 AND 9.15 < alcohol <= 11.35)
# - (0.9944 < density <= 0.9975 AND volatile acidity <= 0.195)
# - (3.05 < residual sugar <= 12.75 AND 9.15 < alcohol <= 11.35)
# - (3.05 < residual sugar <= 12.75 AND volatile acidity <= 0.195)
# - fixed acidity 5.1 < fixed acidity <= 5.65
# - (5.1 < fixed acidity <= 5.65 AND 9.15 < alcohol <= 11.35)
# - (5.1 < fixed acidity <= 5.65 AND pH <= 2.945)
# - (5.1 < fixed acidity <= 5.65 AND volatile acidity <= 0.195)
# - fixed acidity 6.85 < fixed acidity <= 13.6
# - alcohol 9.15 < alcohol <= 11.35
# - (chlorides > 0.0755 AND 9.15 < alcohol <= 11.35)
# - (chlorides > 0.0755 AND volatile acidity <= 0.195)
# - (citric acid <= 0.415 AND 9.15 < alcohol <= 11.35)
# - (citric acid <= 0.415 AND pH <= 2.945)
# - pH <= 2.945
# - (pH <= 2.945 AND 9.15 < alcohol <= 11.35)
# - volatile acidity <= 0.195
# - sulphates 0.575 < sulphates <= 1.19
# - density 0.9944 < density <= 0.9975
# - (0.9944 < density <= 0.9975 AND pH <= 2.945)
#
# Alternatives to decrease the calibrated probability for class 1:
# - residual sugar 3.05 < residual sugar <= 12.75
# - residual sugar > 15.25
# - chlorides > 0.0755
# - citric acid <= 0.415

# %% [markdown]
# `calibrated_explanations` supports multiclass which is demonstrated in [demo_multiclass](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_multiclass.ipynb). That notebook also demonstrates how both feature names and target and categorical labels can be added to improve the interpretability.
# ## Regression
# Extracting explanations for regression is very similar to how it is done for classification. First we load and divide the dataset. The target is divided by 1000, meaning that the target is in thousands of dollars.

# %%
dataset = fetch_openml(name="house_sales", version=3)

X = dataset.data.values.astype(float)
y = dataset.target.values / 1000
y_filter = y < 500
X = X[y_filter, :]
y = y[y_filter]

feature_names = dataset.feature_names
categorical_labels = {5: {0: "False", 1: "True"}}

x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=2, random_state=42, stratify=X[:, 5]
)

X_prop_train, x_cal, y_prop_train, y_cal = train_test_split(
    x_train, y_train, random_state=42, test_size=500, stratify=x_train[:, 5]
)

# %% [markdown]
# We now create our wrapper object, using a `RandomForestRegressor` as learner.

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = WrapCalibratedExplainer(RandomForestRegressor())
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=False, calibrated=False)

# %% [markdown]
# We now fit our model using the proper training set.

# %%
regressor.fit(X_prop_train, y_prop_train)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=False)

# %% [markdown]
# The `WrapCalibratedExplainer` class has a `predict` method that returns the predictions and probability estimates of the underlying classifier. If the model is not yet calibrated, then the underlying models `predict` method is used. If the model is calibrated, then the `predict` method of the calibration model is used.

# %%
prediction = regressor.predict(x_test)
print(f"Uncalibrated model prediction: \n{prediction}")
# Out:
# Uncalibrated model prediction:
# [303.2165 413.9131]
# C:\Users\loftuw\AppData\Local\Temp\ipykernel_35696\1346691177.py:1: UserWarning: The WrapCalibratedExplainer must be calibrated to get calibrated predictions.
#   prediction = regressor.predict(x_test)

# %% [markdown]
# Before we can generate explanations, we need to calibrate our model using the calibration set.

# %%
regressor.calibrate(
    x_cal, y_cal, feature_names=feature_names, categorical_labels=categorical_labels
)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, learner=RandomForestRegressor(), difficulty_estimator=None))

# %% [markdown]
# We can easily add a difficulty estimator by assigning a `DifficultyEstimator` to the `difficulty_estimator` attribute when calibrating the model.

# %%
from crepes.extras import DifficultyEstimator

de = DifficultyEstimator().fit(X=X_prop_train, learner=regressor.learner, scaler=True)
regressor.calibrate(
    x_cal,
    y_cal,
    feature_names=feature_names,
    difficulty_estimator=de,
    categorical_labels=categorical_labels,
)
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# Once the model is calibrated, the `predict`  method produce calibrated predictions with uncertainties. The default confidence is 90 per cent, which can be altered using the `low_high_percentiles` parameter.

# %%
prediction, (low, high) = regressor.predict(
    x_test, uq_interval=True
)  # default low_high_percentiles=(5, 95)
print(f"Calibrated prediction: \n{prediction}")
print("Calibrated uncertainty interval:")
print([(low[i], high[i]) for i in range(len(low))])
# Out:
# Calibrated prediction:
# [303.82418202 414.40254709]
# Calibrated uncertainty interval:
# [(np.float64(258.8450347463822), np.float64(333.8002828067036)), (np.float64(378.17486234311883), np.float64(438.5462846862618))]

# %% [markdown]
# You can also get the probability of the prediction being below a certain threshold using `predict_proba` by assigning the `threshold` parameter.

# %%
import numpy as np

prediction = regressor.predict(x_test, threshold=200)
print("Calibrated probabilistic prediction:")
print(prediction)

proba, (low, high) = regressor.predict_proba(x_test, uq_interval=True, threshold=200)
print("Calibrated probabilistic probability estimate [y_hat > threshold, y_hat <= threshold]:")
print(proba)
print(
    "Calibrated probabilistic uncertainty interval for y_hat <= threshold ([lower_bound, upper_bound]):"
)
print(np.array([(low[i], high[i]) for i in range(len(low))]))
# Out:
# Calibrated probabilistic prediction:
# ['y_hat > 200', 'y_hat > 200']
# Calibrated probabilistic probability estimate [y_hat > threshold, y_hat <= threshold]:
# [[0.98051948 0.01948052]
#  [0.98611111 0.01388889]]
# Calibrated probabilistic uncertainty interval for y_hat <= threshold ([lower_bound, upper_bound]):
# [[0.         0.01986755]
#  [0.         0.01408451]]

# %% [markdown]
# #### Factual Explanations
# Let us explain a test instance using our `WrapCalibratedExplainer` object. The method used to get factual explanations is `explain_factual` with `guarded_options=GuardedOptions()`.

# %%
factual_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions())
from calibrated_explanations.ce_agent_utils import print_guarded_audit_table

guarded_audit = factual_explanations.get_guarded_audit()
print_guarded_audit_table(guarded_audit, max_rows=20)
display(regressor)
# Out:
# Guarded Audit Summary
# instances=2 tested=262 conforming=237 removed_guard=25 emitted=34
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 bedrooms           (-inf, 1.5]                 0.5  Y    N    N   design_excluded
#    0    0 bedrooms           (1.5, 2.5]                0.878  Y    N    N   design_excluded
#    0    0 bedrooms           (2.5, 3.5]                0.986  Y    Y    N   emitted
#    0    0 bedrooms           (3.5, 4.5]                 0.95  Y    N    N   design_excluded
#    0    0 bedrooms           (4.5, 5.5]                0.692  Y    N    N   design_excluded
#    0    0 bedrooms           (5.5, inf]                 0.37  Y    N    N   design_excluded
#    0    1 bathrooms          (-inf, 0.875]              0.77  Y    N    N   design_excluded
#    0    1 bathrooms          (0.875, 1.25]             0.886  Y    N    N   design_excluded
#    0    1 bathrooms          (1.25, 1.625]              0.98  Y    N    N   design_excluded
#    0    1 bathrooms          (1.625, 1.875]            0.986  Y    N    N   design_excluded
#    0    1 bathrooms          (1.875, 2.375]             0.99  Y    Y    N   emitted
#    0    1 bathrooms          (2.375, inf]              0.956  Y    N    N   design_excluded
#    0    2 sqft_living        (-inf, 1075]               0.95  Y    N    N   design_excluded
#    0    2 sqft_living        (1075, 1145]               0.98  Y    N    N   design_excluded
#    0    2 sqft_living        (1145, 1545]               0.99  Y    Y    N   emitted
#    0    2 sqft_living        (1545, 1785]               0.98  Y    N    N   design_excluded
#    0    2 sqft_living        (1785, 2045]              0.984  Y    N    N   design_excluded
#    0    2 sqft_living        (2045, 2283]               0.96  Y    N    N   design_excluded
#    0    2 sqft_living        (2283, 2990]              0.886  Y    N    N   design_excluded
#    0    2 sqft_living        (2990, inf]                 0.5  Y    N    N   design_excluded
# ... truncated 242 row(s)
# reason_counts: emitted=34, removed_guard=25, design_excluded=195, zero_impact=8
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# #### Merge adjacent conforming bins
# By default, guarded explanations keep each bin as a separate rule.  Passing `GuardedOptions(merge_adjacent=True)` allows adjacent conforming bins to be collapsed into a single wider rule.  The merged rule is re-tested by the guard; if the re-test fails, the original bins are kept.  The `mrg` column in the audit table shows which emitted rules came from a merge.

# %%
merged_factual = regressor.explain_factual(x_test, guarded_options=GuardedOptions(merge_adjacent=True))
merged_audit = merged_factual.get_guarded_audit()
print_guarded_audit_table(merged_audit, max_rows=30)
# Out:
# Guarded Audit Summary
# instances=2 tested=67 conforming=42 removed_guard=25 emitted=27
# inst feat name                interval                  p      conf emit mrg  reason
# ------------------------------------------------------------------------------------
#    0    0 bedrooms           (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0    1 bathrooms          (-inf, inf]                0.99  Y    Y    Y   emitted
#    0    2 sqft_living        (-inf, inf]                0.98  Y    Y    Y   emitted
#    0    3 sqft_lot           (-inf, inf]               0.986  Y    Y    Y   emitted
#    0    4 floors             (-inf, 2.75]              0.986  Y    N    Y   zero_impact
#    0    4 floors             (2.75, inf]               0.098  N    N    N   removed_guard
#    0    5 waterfront         (-inf, inf]               0.986  Y    N    N   zero_impact
#    0    5 waterfront         (-inf, inf]               0.004  N    N    N   removed_guard
#    0    6 view               (-inf, 2.5]               0.986  Y    N    N   zero_impact
#    0    6 view               (2.5, 3.5]                0.078  N    N    N   removed_guard
#    0    6 view               (3.5, inf]                0.042  N    N    N   removed_guard
#    0    7 condition          (-inf, inf]               0.846  Y    Y    Y   emitted
#    0    8 grade              (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0    9 sqft_above         (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   10 sqft_basement      (-inf, inf]               0.996  Y    Y    Y   emitted
#    0   11 yr_built           (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   12 yr_renovated       (-inf, 976.5]             0.986  Y    N    N   zero_impact
#    0   12 yr_renovated       (976.5, 1960.5]           0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1960.5, 1972.5]          0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1972.5, 1988]            0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1988, 1992]              0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (1992, 2003.5]            0.038  N    N    N   removed_guard
#    0   12 yr_renovated       (2003.5, inf]             0.038  N    N    N   removed_guard
#    0   13 zipcode            (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   14 lat                (-inf, inf]                0.96  Y    Y    Y   emitted
#    0   15 long               (-inf, inf]               0.976  Y    Y    Y   emitted
#    0   16 sqft_living15      (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   17 sqft_lot15         (-inf, inf]               0.986  Y    Y    Y   emitted
#    0   18 date_year          (-inf, inf]               0.986  Y    N    Y   zero_impact
#    0   19 date_month         (-inf, inf]               0.986  Y    Y    Y   emitted
# ... truncated 37 row(s)
# reason_counts: emitted=27, removed_guard=25, zero_impact=15
# legend: emitted=rule kept; removed_guard=non-conforming; design_excluded=not eligible in this mode; baseline_equal=no prediction change; zero_impact=factual equals base; ignored_feature=explicitly ignored; mrg=Y: merged adjacent bins; emitted bounds shown

# %% [markdown]
# Regression also offer both regular and uncertainty plots for factual explanations with or without conjunctive rules, in almost exactly the same way as for classification.

# %%
factual_explanations.plot()
factual_explanations.plot(uncertainty=True)

factual_explanations.add_conjunctions().plot(uncertainty=True)

# %% [markdown]
# Default, the confidence interval is set to a symmetric interval of 90% (defined as `low_high_percentiles=(5,95)`). The intervals can cover any user specified interval, including one-sided intervals. To define a one-sided upper-bounded 90% interval, set `low_high_percentiles=(-np.inf,90)`, and to define a one-sided lower-bounded 95% interval, set `low_high_percentiles=(5,np.inf)`. Percentiles can also be set to any other values in the range (0,100) (exclusive), and intervals do not have to be symmetric.

# %%
lower_bounded_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), low_high_percentiles=(5, np.inf))
asymmetric_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), low_high_percentiles=(5, 75))

# %% [markdown]
# #### Explore Alternative Explanations
# `explore_alternatives` with `guarded_options=GuardedOptions()` works exactly the same as for classification.

# %%
alternative_explanations = regressor.explore_alternatives(x_test, guarded_options=GuardedOptions())
display(regressor)
# Out:
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# Alternative plots work as for classification.

# %%
alternative_explanations.plot(rnk_metric="ensured", rnk_weight=0.9)
alternative_explanations.add_conjunctions().plot()
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(

# %% [markdown]
# ## Probabilistic Regression
# The difference between probabilistic regression and regular regression is that the former returns a probability of the prediction being below a certain threshold. This could for example be useful when the prediction is a time to an event, such as time to death or time to failure.

# %%
probabilistic_factual_explanations = regressor.explain_factual(x_test, guarded_options=GuardedOptions(), threshold=y_test + 20)
probabilistic_factual_explanations.plot()
probabilistic_factual_explanations.plot(uncertainty=True)

# %%
probabilistic_alternative_explanations = regressor.explore_alternatives(x_test, guarded_options=GuardedOptions(), threshold=y_test + 20)
probabilistic_alternative_explanations.plot()
probabilistic_alternative_explanations.plot(style="ensured")
print(probabilistic_alternative_explanations.to_narrative(expertise_level="advanced",output_format="text"))
# Out:
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# C:\Users\loftuw\Documents\Github\moffran\calibrated_explanations\src\calibrated_explanations\explanations\explanations.py:1531: UserWarning: GuardedAlternativeExplanation.plot forwarding plot keyword arguments to downstream renderers/plugins: ['uncertainty']. If this is a typo of a built-in argument (['bins', 'low_high_percentiles', 'renderer', 'return_plot_spec', 'style']), it will be silently ignored by the renderer.
#   explanation.plot(
# ================================================================================
# Instance 0
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Calibrated Probability (target <= 310.000): 0.643
# Prediction Interval: [0.630, 0.667]
#
# Alternatives to increase the Calibrated Probability for target <= 310.000:
# - If lat 47.31 < lat <= 47.34                   then P(target <= 310.000) = 0.980 [0.979, 1.000]
# - If lat 47.34 < lat <= 47.43                   then P(target <= 310.000) = 0.980 [0.979, 1.000]
# - If lat <= 47.31                               then P(target <= 310.000) = 0.980 [0.979, 1.000]
# - If sqft_living <= 1075                        then P(target <= 310.000) = 0.962 [0.960, 1.000]
# - If sqft_living 1075 < sqft_living <= 1145     then P(target <= 310.000) = 0.958 [0.957, 1.000]
# - If date_day 10.5 < date_day <= 15.5           then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If date_day 15.5 < date_day <= 16.5           then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If date_day 4.5 < date_day <= 8.5             then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If grade 4.5 < grade <= 6.5                   then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If date_day 8.5 < date_day <= 10.5            then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If grade <= 4.5                               then P(target <= 310.000) = 0.818 [0.800, 0.900]
# - If sqft_living15 1035 < sqft_living15 <= 1195 then P(target <= 310.000) = 0.694 [0.647, 0.800]
# - If condition 2.5 < condition <= 3.5           then P(target <= 310.000) = 0.694 [0.647, 0.800]
# - If date_month 9.5 < date_month <= 11.5        then P(target <= 310.000) = 0.694 [0.647, 0.800]
# - If sqft_lot 9858 < sqft_lot <= 1.001e+04      then P(target <= 310.000) = 0.694 [0.647, 0.800]
# - If condition <= 2.5                           then P(target <= 310.000) = 0.694 [0.647, 0.800]
# - If long -122.1 < long <= -122.1               then P(target <= 310.000) = 0.693 [0.645, 0.800]
# - If long -122.1 < long <= -122.1               then P(target <= 310.000) = 0.686 [0.633, 0.800]
# - If bathrooms 1.25 < bathrooms <= 1.625        then P(target <= 310.000) = 0.686 [0.633, 0.800]
# - If sqft_lot 2088 < sqft_lot <= 2985           then P(target <= 310.000) = 0.686 [0.633, 0.800]
# - If sqft_lot15 3436 < sqft_lot15 <= 6030       then P(target <= 310.000) = 0.686 [0.633, 0.800]
# - If sqft_lot 692 < sqft_lot <= 2088            then P(target <= 310.000) = 0.686 [0.633, 0.800]
# - If date_month > 11.5                          then P(target <= 310.000) = 0.686 [0.633, 0.800]
# - If sqft_lot <= 692                            then P(target <= 310.000) = 0.686 [0.633, 0.800]
# - If sqft_lot15 <= 3436                         then P(target <= 310.000) = 0.686 [0.633, 0.800]
# - If long -122.1 < long <= -122.1               then P(target <= 310.000) = 0.672 [0.633, 0.750]
# - If sqft_living15 1195 < sqft_living15 <= 1205 then P(target <= 310.000) = 0.672 [0.633, 0.750]
# - If yr_built 1908 < yr_built <= 1918           then P(target <= 310.000) = 0.672 [0.633, 0.750]
# - If sqft_living15 2075 < sqft_living15 <= 2765 then P(target <= 310.000) = 0.672 [0.633, 0.750]
# - If bedrooms 4.5 < bedrooms <= 5.5             then P(target <= 310.000) = 0.672 [0.633, 0.750]
#
# Alternatives to decrease the Calibrated Probability for target <= 310.000:
# - If lat 47.57 < lat <= 47.69                   then P(target <= 310.000) = 0.031 [0.000, 0.032]
# - If lat 47.54 < lat <= 47.57                   then P(target <= 310.000) = 0.043 [0.022, 0.044]
# - If lat > 47.69                                then P(target <= 310.000) = 0.057 [0.022, 0.059]
# - If lat 47.53 < lat <= 47.54                   then P(target <= 310.000) = 0.085 [0.022, 0.091]
# - If sqft_living > 2990                         then P(target <= 310.000) = 0.194 [0.111, 0.214]
# - If long <= -122.4                             then P(target <= 310.000) = 0.222 [0.167, 0.238]
# - If long -122.4 < long <= -122.4               then P(target <= 310.000) = 0.247 [0.167, 0.273]
# - If sqft_living 2283 < sqft_living <= 2990     then P(target <= 310.000) = 0.273 [0.200, 0.300]
# - If long -122.4 < long <= -122.4               then P(target <= 310.000) = 0.448 [0.385, 0.500] [[!] uncertain]
# - If sqft_above 2125 < sqft_above <= 2365       then P(target <= 310.000) = 0.448 [0.385, 0.500] [[!] uncertain]
# - If sqft_above 2365 < sqft_above <= 3000       then P(target <= 310.000) = 0.448 [0.385, 0.500] [[!] uncertain]
# - If sqft_above 3000 < sqft_above <= 3186       then P(target <= 310.000) = 0.448 [0.385, 0.500] [[!] uncertain]
# - If sqft_above > 3186                          then P(target <= 310.000) = 0.448 [0.385, 0.500] [[!] uncertain]
#
# ================================================================================
# Instance 1
# ================================================================================
#
# Alternative Explanation (Advanced):
# --------------------------------------------------------------------------------
# Calibrated Probability (target <= 417.500): 0.628
# Prediction Interval: [0.619, 0.643]
#
# Alternatives to increase the Calibrated Probability for target <= 417.500:
# - If lat 47.31 < lat <= 47.34                   then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat 47.34 < lat <= 47.43                   then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat 47.43 < lat <= 47.53                   then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If lat <= 47.31                               then P(target <= 417.500) = 0.991 [0.991, 1.000]
# - If sqft_living 1075 < sqft_living <= 1145     then P(target <= 417.500) = 0.767 [0.759, 0.793]
# - If lat 47.53 < lat <= 47.54                   then P(target <= 417.500) = 0.767 [0.759, 0.793]
# - If sqft_living <= 1075                        then P(target <= 417.500) = 0.767 [0.759, 0.793]
# - If lat 47.54 < lat <= 47.57                   then P(target <= 417.500) = 0.735 [0.714, 0.793]
#
# Alternatives to decrease the Calibrated Probability for target <= 417.500:
# - If lat 47.57 < lat <= 47.69                   then P(target <= 417.500) = 0.229 [0.158, 0.250]
# - If sqft_living 2045 < sqft_living <= 2283     then P(target <= 417.500) = 0.375 [0.333, 0.400]
# - If long -122.1 < long <= -122.1               then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If long -122.1 < long <= -122.1               then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_living 1785 < sqft_living <= 2045     then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_living15 2075 < sqft_living15 <= 2765 then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_living 2283 < sqft_living <= 2990     then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_basement 245 < sqft_basement <= 665   then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_lot15 3436 < sqft_lot15 <= 6030       then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_lot15 6030 < sqft_lot15 <= 6044       then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_lot15 7150 < sqft_lot15 <= 1.033e+04  then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_living > 2990                         then P(target <= 417.500) = 0.563 [0.500, 0.643] [[!] uncertain]
# - If sqft_lot15 6044 < sqft_lot15 <= 7150       then P(target <= 417.500) = 0.616 [0.600, 0.643]
# - If long <= -122.4                             then P(target <= 417.500) = 0.616 [0.600, 0.643]

# %% [markdown]
# Regression offers many more options but to learn more about them, see the [demo_regression](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_regression.ipynb) or the [demo_probabilistic_regression](https://github.com/Moffran/calibrated_explanations/blob/main/notebooks/demo_probabilistic_regression.ipynb) notebooks.
#
# A `WrapCalibratedExplainer` can also be initialized with a trained model or with a `WrapCalibratedExplainer` object, as is examplified below. We use the `learner` and `explainer` from the previously initialized `classifier` and `regressor` instances, as we know that these are fitted and calibrated.

# %%
new_classifier = WrapCalibratedExplainer(classifier.learner)
display(new_classifier)
new_classifier_explainer = WrapCalibratedExplainer(classifier.explainer)
display(new_classifier_explainer)

new_regressor = WrapCalibratedExplainer(regressor.learner)
display(new_regressor)
new_regressor_explainer = WrapCalibratedExplainer(regressor.explainer)
display(new_regressor_explainer)
# Out:
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=False)
# WrapCalibratedExplainer(learner=RandomForestClassifier(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=classification, discretizer=EntropyDiscretizer(), learner=RandomForestClassifier()))
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=False)
# WrapCalibratedExplainer(learner=RandomForestRegressor(), fitted=True, calibrated=True,
# 		explainer=CalibratedExplainer(mode=regression, discretizer=RegressorDiscretizer(), learner=RandomForestRegressor(), difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)))

# %% [markdown]
# When a calibrated explainer is re-fitted, the explainer is reinitialized.
